# %% [markdown]
# ## Indexing Brick Ontology

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
pd.set_option("max_rows", 600)
from pathlib import Path  
import glob
from sklearn.metrics.pairwise import cosine_similarity
import numpy

# %%
from rdflib import Graph
from flashtext import KeywordProcessor
import re

# Loadinb Brick Schema
g = Graph()
g.parse("/Users/slz/git_repo/vizbrick/Brick.ttl", format="turtle")
# Out:
# <Graph identifier=N8141944eb0c44561adbb862f6182515e (<class 'rdflib.graph.Graph'>)>

# %%
def get_relationships():
    rel_list = []
    for triple in g:
        if "brick" in triple[0] and "22-rdf-syntax-ns#type" in triple[1] and ("AsymmetricProperty" in triple[2] or "ObjectProperty" in triple[2]):
            rel_list.append(triple[0].replace("https://brickschema.org/schema/Brick#",""))
    print("*done")
    return rel_list

# %%
def vectorize(list_of_docs):
    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform(list_of_docs)
    feature_names = vectorizer.get_feature_names_out()
    dense = vectors.todense()
    denselist = dense.tolist()
    df = pd.DataFrame(denselist, columns=feature_names)
    return df, vectorizer

# %%
def indexing_brick():
    definitions = {}
    
    for triple in g:
        if "definition" in triple[1]:
            class_name = triple[0].replace("https://brickschema.org/schema/Brick#","")
            definition = triple[2]
            class_name = class_name.replace("_"," ")
            definitions[class_name] = definition+" "+ class_name
        
        elif "#Location" in triple[2]:
            class_name = triple[0].replace("https://brickschema.org/schema/Brick#","")
            definition = class_name
            class_name = class_name.replace("_"," ")
            definitions[class_name] = definition +" " + class_name
    
    for key in definitions.keys():
        if str(definitions[key]).startswith("See"):
            definitions[key] = definitions[definitions[key].split(" ")[1].replace("_"," ")]
            #print("->",definitions[key])
    
    #print(definitions)
    list_of_classname = []
    list_of_definitions = []
    
    for key in definitions.keys():
        list_of_classname.append(key)
        list_of_definitions.append(definitions[key])

    print(len(list_of_classname), len(list_of_definitions))
    
    df_class, vectorizer_class = vectorize(list_of_classname)
    df_def, vectorizer_def = vectorize(list_of_definitions)

    return df_class, df_def, vectorizer_class, vectorizer_def, list_of_classname, list_of_definitions
        
df_class, df_def, vectorizer_class, vectorizer_def, list_of_classname, list_of_definitions = indexing_brick()
print("* Done")
# Out:
# 1027 1027
# * Done

# %%
list_of_definitions[list_of_classname.index("HVAC System")]
# Out:
# rdflib.term.Literal('The equipment, distribution systems and terminals that provide, either collectively or individually, the processes of heating, ventilating or air conditioning to a building or portion of a building Heating Ventilation Air Conditioning System', lang='en')

# %% [markdown]
# ## Keyword Search Test for Suggestions

# %%
def search(query, hint="", topk=5):
    return_list = []
    '''
    parsed_query = query.split(" ")
    for classname in list_of_classname:
        cnt = 0
        for term in parsed_query:
            if term in classname:
                cnt+=1
        if cnt==len(parsed_query):
            return_list.append((classname,cnt))
    '''
    
    
    search_result = {}
    idx = 0
    
    query_vec = vectorizer_def.transform([query])
    
    for index, row in df_def.iterrows():
        class_name = list_of_classname[idx]
        similarity = cosine_similarity(row.values.reshape(1,len(row.values)), query_vec.toarray())[0][0]
        search_result[class_name]=similarity
        idx+=1

    idx = 0
    query_vec = vectorizer_class.transform([query])
    
    for index, row in df_class.iterrows():
        class_name = list_of_classname[idx]
        similarity = cosine_similarity(row.values.reshape(1,len(row.values)), query_vec.toarray())[0][0]
        search_result[class_name]+=similarity
        idx+=1

    search_result = dict(sorted(search_result.items(), key=lambda item: item[1], reverse=True))
    
    rank=1
    for key in search_result.keys():
        return_list.append((key,search_result[key]))
        if rank==topk: break
        rank+=1
    return return_list

# %%
query = "]'DHW_ClothesWasherColdFlow The cumulative volume of cold water flowing into the clothes washer starting at midnigh"
query+="water usage sensor"
search(query, topk=10)
# Out:
# [('Water Usage Sensor', 0.7749837513546974),
#  ('volume', 0.7547574114418181),
#  ('Hot Water Usage Sensor', 0.6807491741640774),
#  ('Usage Sensor', 0.6415175181403583),
#  ('Energy Usage Sensor', 0.5447254801890808),
#  ('Cold Box', 0.5273226850442712),
#  ('Steam Usage Sensor', 0.5115996614241947),
#  ('Variable Air Volume Box', 0.4782982950606183),
#  ('Water Temperature Sensor', 0.44077627683758014),
#  ('Water Flow Sensor', 0.41277219200805126)]

# %%
query = "DHW Clothes Washer Cold Flow The cumulative volume of cold water flowing into the clothes washer starting at midnight"
search(query, topk=20)
# Out:
# [('Cold Box', 0.8200476378402841),
#  ('volume', 0.6123005070969189),
#  ('Water Flow Sensor', 0.46693017168654116),
#  ('Water Flow Setpoint', 0.4342440413453723),
#  ('Variable Air Volume Box', 0.39003658358689575),
#  ('Discharge Water Flow Sensor', 0.37546719691675334),
#  ('Supply Water Flow Sensor', 0.3725053125532621),
#  ('Supply Water Flow Setpoint', 0.36409999914116253),
#  ('Discharge Water Flow Setpoint', 0.35411980548809796),
#  ('Cooling Valve', 0.35119293064661994),
#  ('Hot Water Flow Setpoint', 0.3497345226602519),
#  ('Hot Water Flow Sensor', 0.34475471288277826),
#  ('Chilled Water Flow Setpoint', 0.3336340458260073),
#  ('Chilled Water Flow Sensor', 0.32937639090139575),
#  ('Freezer', 0.3242294639406801),
#  ('Hot Water Supply Flow Sensor', 0.3235921392453537),
#  ('Hot Water Discharge Flow Sensor', 0.3198481022003142),
#  ('Outside Air Flow Sensor', 0.318999470581222),
#  ('Bypass Water Flow Sensor', 0.3161083134570281),
#  ('Flow Setpoint', 0.3114351077642703)]

# %% [markdown]
# ## Loading an input metadata table, cleaning metadata table

# %%
dataset = pd.read_csv("NIST_meta.csv").fillna("")

# %%
dataset
# Out:
#                                Data Label    Subsystem Measurement Location  \
# 0               DHW_ClothesWasherColdFlow          DHW              Utility
# 1                DHW_ClothesWasherHotFlow          DHW              Utility
# 2                   DHW_DishwasherHotFlow          DHW              Kitchen
# 3                     DHW_SHWGlycolTempIn          DHW             Basement
# 4                    DHW_SHWGlycolTempOut          DHW             Basement
# 5      DHW_HeatPumpWaterHeaterEnergyTotal          DHW             Basement
# 6       DHW_HeatPumpWaterHeaterPowerTotal          DHW             Basement
# 7                    DHW_ManifoldColdFlow          DHW             Basement
# 8                     DHW_ManifoldHotFlow          DHW             Basement
# 9                    DHW_MixValveColdFlow          DHW             Basement
# 10               DHW_RoomTempBasementHPWH          DHW             Basement
# 11          DHW_SHWPumpsEnergywithStandby          DHW             Basement
# 12           DHW_SHWPumpsPowerwithStandby          DHW             Basement
# 13           DHW_StatusSolenoidColdMBATub          DHW                MBath
# 14        DHW_StatusSolenoidColdMBAShower          DHW                MBath
# 15      DHW_StatusSolenoidColdKitchenSink          DHW              Kitchen
# 16       DHW_StatusSolenoidHotKitchenSink          DHW              Kitchen
# 17            DHW_StatusSolenoidHotMBATub          DHW                MBath
# 18         DHW_StatusSolenoidHotMBAShower          DHW                MBath
# 19             DHW_WaterTempBAShowerMixed          DHW                Bath2
# 20                 DHW_WaterTempBAShwCold          DHW                Bath2
# 21                  DHW_WaterTempBAShwHot          DHW                Bath2
# 22                DHW_WaterTempBASinkCold          DHW                Bath2
# 23                 DHW_WaterTempBASinkHot          DHW                Bath2
# 24               DHW_WaterTempBASinkMixed          DHW                Bath2
# 25                DHW_WaterTempDishwasher          DHW              Kitchen
# 26                    DHW_WaterTempHPWHIn          DHW             Basement
# 27                   DHW_WaterTempHPWHOut          DHW             Basement
# 28                 DHW_WaterTempKSinkCold          DHW              Kitchen
# 29                  DHW_WaterTempKSinkHot          DHW              Kitchen
# 30                  DHW_WaterTempKSinkMix          DHW              Kitchen
# 31            DHW_WaterTempManifoldColdIn          DHW             Basement
# 32             DHW_WaterTempManifoldHotIn          DHW             Basement
# 33                DHW_WaterTempMBAShwCold          DHW                MBath
# 34                 DHW_WaterTempMBAShwHot          DHW                MBath
# 35                 DHW_WaterTempMBAShwMix          DHW                MBath
# 36             DHW_WaterTempMBASinkRMixed          DHW                MBath
# 37              DHW_WaterTempMBASinkRCold          DHW                MBath
# 38               DHW_WaterTempMBASinkRHot          DHW                MBath
# 39                DHW_WaterTempMBATubCold          DHW                MBath
# 40                 DHW_WaterTempMBATubHot          DHW                MBath
# 41                 DHW_WaterTempMBATubMix          DHW                MBath
# 42            DHW_WaterTempMixValveColdIn          DHW             Basement
# 43             DHW_WaterTempMixValveHotIn          DHW             Basement
# 44              DHW_WaterTempSHWHX80galIn          DHW             Basement
# 45             DHW_WaterTempSHWHX80galOut          DHW             Basement
# 46            DHW_WaterTempSHWTank80galIn          DHW             Basement
# 47           DHW_WaterTempSHWTank80galOut          DHW             Basement
# 48                DHW_WaterTempWasherCold          DHW              Utility
# 49                 DHW_WaterTempWasherHot          DHW              Utility
# 50              Elec_EnergyHeatPumpWH1of2          DHW             Basement
# 51              Elec_EnergyHeatPumpWH2of2          DHW             Basement
# 52               Elec_PowerHeatPumpWH1of2          DHW             Basement
# 53               Elec_PowerHeatPumpWH2of2          DHW             Basement
# 54      Elec_EnergyPlugsBaseAHeliodyneHXs         Elec             Basement
# 55                     Elec_EnergyPlugsDR   Electrical          Dining Room
# 56                    Elec_EnergyPlugsBR4   Electrical             Bedroom4
# 57              Elec_EnergyPlugsEntryHall   Electrical        Entry Hallway
# 58                     Elec_EnergyPlugsLR   Electrical          Living Room
# 59               Elec_EnergyClothesWasher   Electrical              Utility
# 60                   Elec_EnergyDryer1of2   Electrical              Utility
# 61                   Elec_EnergyDryer2of2   Electrical              Utility
# 62                  Elec_EnergyPlugsBaseB   Electrical             Basement
# 63                  Elec_EnergyPlugsBaseC   Electrical             Basement
# 64                    Elec_EnergySumpPump   Electrical             Basement
# 65                      Elec_EnergySpare1  Electrical              Basement
# 66                    Elec_EnergyPlugsBA1   Electrical                Bath1
# 67             Elec_EnergyGarbageDisposal  Electrical               Kitchen
# 68               Elec_EnergyPlugsKitRange  Electrical               Kitchen
# 69           Elec_EnergyPlugsKitPeninsula  Electrical               Kitchen
# 70                   Elec_EnergyMicrowave  Electrical               Kitchen
# 71               Elec_EnergyPlugs2ndFloor   Electrical                Bath2
# 72                      Elec_EnergySpare2   Electrical             Basement
# 73                    Elec_EnergyPlugsBR2   Electrical             Bedroom2
# 74                    Elec_EnergyPlugsMBR   Electrical             MBedroom
# 75                Elec_EnergyPlugsMBAEast   Electrical                MBath
# 76                  Elec_EnergyDishwasher   Electrical              Kitchen
# 77               Elec_EnergyPlugsBA2South   Electrical                Bath2
# 78                Elec_EnergyPlugsMBAWest   Electrical                MBath
# 79               Elec_EnergyPlugsBA2North   Electrical                Bath2
# 80                    Elec_EnergyPlugsBR3   Electrical             Bedroom3
# 81                Elec_EnergyRefrigerator   Electrical              Kitchen
# 82                Elec_EnergyPlugsKitSink  Electrical               Kitchen
# 83                    Elec_EnergyPlugsDRB   Electrical          Dining Room
# 84                  Elec_EnergyPlugsAttic   Electrical                Attic
# 85                      Elec_PowerPlugsDR   Electrical          Dining Room
# 86                     Elec_PowerPlugsBR4   Electrical             Bedroom4
# 87               Elec_PowerPlugsEntryHall   Electrical        Entry Hallway
# 88                      Elec_PowerPlugsLR   Electrical          Living Room
# 89                Elec_PowerClothesWasher   Electrical              Utility
# 90                    Elec_PowerDryer1of2   Electrical              Utility
# 91                    Elec_PowerDryer2of2   Electrical              Utility
# 92                   Elec_PowerPlugsBaseB   Electrical             Basement
# 93                   Elec_PowerPlugsBaseC   Electrical             Basement
# 94                     Elec_PowerSumpPump   Electrical             Basement
# 95                       Elec_PowerSpare1   Electrical             Basement
# 96                     Elec_PowerPlugsBA1   Electrical                Bath1
# 97              Elec_PowerGarbageDisposal  Electrical               Kitchen
# 98                Elec_PowerPlugsKitRange  Electrical               Kitchen
# 99            Elec_PowerPlugsKitPeninsula  Electrical               Kitchen
# 100                   Elec_PowerMicrowave  Electrical               Kitchen
# 101               Elec_PowerPlugs2ndFloor   Electrical                Bath2
# 102                      Elec_PowerSpare2   Electrical             Basement
# 103                    Elec_PowerPlugsBR2   Electrical             Bedroom2
# 104                    Elec_PowerPlugsMBR   Electrical             MBedroom
# 105                Elec_PowerPlugsMBAEast   Electrical                MBath
# 106                  Elec_PowerDishwasher   Electrical              Kitchen
# 107               Elec_PowerPlugsBA2South   Electrical                Bath2
# 108                Elec_PowerPlugsMBAWest   Electrical                MBath
# 109               Elec_PowerPlugsBA2North   Electrical                Bath2
# 110                    Elec_PowerPlugsBR3   Electrical             Bedroom3
# 111                Elec_PowerRefrigerator   Electrical              Kitchen
# 112                Elec_PowerPlugsKitSink  Electrical               Kitchen
# 113                    Elec_PowerPlugsDRB   Electrical          Dining Room
# 114                  Elec_PowerPlugsAttic   Electrical                Attic
# 115                        Elec_EnergyHRV         HVAC             Basement
# 116                         Elec_PowerHRV         HVAC             Basement
# 117              HVAC_DehumidifierAirflow         HVAC             Basement
# 118          HVAC_DehumidifierExitAirTemp         HVAC             Basement
# 119         HVAC_DehumidifierInletAirTemp         HVAC             Basement
# 120                HVAC_DehumidifierPower         HVAC             Basement
# 121          HVAC_HeatPumpIndoorUnitPower         HVAC             Basement
# 122         HVAC_HeatPumpOutdoorUnitPower        HVAC               Outdoor
# 123            HVAC_HVACDewpointReturnAir         HVAC             Basement
# 124            HVAC_HVACDewpointSupplyAir         HVAC             Basement
# 125                HVAC_HVACTempReturnAir         HVAC             Basement
# 126                HVAC_HVACTempSupplyAir         HVAC             Basement
# 127                     IndEnv_BasementRH       IndEnv             Basement
# 128                     IndEnv_Bedroom2RH       IndEnv             Bedroom2
# 129                     IndEnv_Bedroom3RH       IndEnv             Bedroom3
# 130                      IndEnv_KitchenRH       IndEnv              Kitchen
# 131                     IndEnv_LivingRmRH       IndEnv          Living Room
# 132                    IndEnv_MastBedRmRH       IndEnv       Master Bedroom
# 133                          IndEnv_MBARH       IndEnv                MBath
# 134                 IndEnv_RadiantTempBR2       IndEnv             Bedroom2
# 135                 IndEnv_RadiantTempBR3       IndEnv             Bedroom3
# 136             IndEnv_RadiantTempKitchen       IndEnv              Kitchen
# 137                  IndEnv_RadiantTempLR       IndEnv          Living Room
# 138                 IndEnv_RadiantTempMBR       IndEnv       Master Bedroom
# 139                IndEnv_RoomTempAtticNE       IndEnv                Attic
# 140                IndEnv_RoomTempAtticNW       IndEnv                Attic
# 141                IndEnv_RoomTempAtticSE       IndEnv                Attic
# 142                IndEnv_RoomTempAtticSW       IndEnv                Attic
# 143                IndEnv_RoomTempBA1Temp       IndEnv                Bath1
# 144                IndEnv_RoomTempBA2Temp       IndEnv                Bath2
# 145             IndEnv_RoomTempBasementNE       IndEnv             Basement
# 146             IndEnv_RoomTempBasementNW       IndEnv             Basement
# 147             IndEnv_RoomTempBasementSE       IndEnv             Basement
# 148             IndEnv_RoomTempBasementSW       IndEnv             Basement
# 149                IndEnv_RoomTempBR2Temp       IndEnv             Bedroom2
# 150                IndEnv_RoomTempBR3Temp       IndEnv             Bedroom3
# 151                IndEnv_RoomTempBR4Temp       IndEnv             Bedroom4
# 152                 IndEnv_RoomTempDRTemp       IndEnv          Dining Room
# 153           IndEnv_RoomTempHallLowerMid       IndEnv        Entry Hallway
# 154             IndEnv_RoomTempHallLowest       IndEnv        Entry Hallway
# 155             IndEnv_RoomTempHallMiddle       IndEnv        Entry Hallway
# 156              IndEnv_RoomTempHallUpper       IndEnv        Entry Hallway
# 157           IndEnv_RoomTempHallUpperMid       IndEnv        Entry Hallway
# 158            IndEnv_RoomTempKitchenTemp       IndEnv              Kitchen
# 159                 IndEnv_RoomTempLRTemp       IndEnv          Living Room
# 160                IndEnv_RoomTempMBATemp       IndEnv                MBath
# 161                IndEnv_RoomTempMBRTemp       IndEnv       Master Bedroom
# 162                 IndEnv_RoomTempWDTemp       IndEnv              Kitchen
# 163              Elec_EnergyPlugsInstBR4A        Instr             Bedroom4
# 164              Elec_EnergyPlugsInstBR4B        Instr             Bedroom4
# 165               Elec_EnergyPlugsInstLRA        Instr          Living Room
# 166               Elec_EnergyPlugsInstLRB        Instr          Living Room
# 167               Elec_EnergyPlugsInstBA2        Instr                Bath2
# 168              Elec_EnergyPlugsInstMBAB        Instr                MBath
# 169   Elec_EnergyPlugsGSHPInstrumentation        Instr             Basement
# 170              Elec_EnergyPlugsInstMBRA        Instr       Master Bedroom
# 171           Elec_EnergyPlugsInstBR2Hall        Instr            Bedroom 2
# 172              Elec_EnergyPlugsInstHall        Instr        Entry Hallway
# 173   Elec_EnergyLightingControlPanelRPS1        Instr             Basement
# 174               Elec_EnergyPlugsInstBR3        Instr             Bedroom3
# 175    Elec_EnergyHeatLoadforRefrigerator        Instr              Kitchen
# 176          Elec_EnergyPlugsInstMudroomA        Instr              Mudroom
# 177   Elec_EnergyLightingControlPanelRPS2        Instr             Basement
# 178   Elec_EnergyPlugsHVACInstrumentation        Instr             Basement
# 179              Elec_EnergyPlugsInstKitD        Instr              Kitchen
# 180               Elec_EnergyPlugsInstBA1        Instr                Bath1
# 181              Elec_EnergyPlugsInstKitA        Instr              Kitchen
# 182          Elec_EnergyPlugsInstMudroomB        Instr              Mudroom
# 183               Elec_EnergyPlugsInstDRA        Instr          Dining Room
# 184               Elec_PowerPlugsInstBR4A        Instr             Bedroom4
# 185               Elec_PowerPlugsInstBR4B        Instr             Bedroom4
# 186                Elec_PowerPlugsInstLRA        Instr          Living Room
# 187                Elec_PowerPlugsInstLRB        Instr          Living Room
# 188                Elec_PowerPlugsInstBA2        Instr                Bath2
# 189               Elec_PowerPlugsInstMBAB        Instr                MBath
# 190    Elec_PowerPlugsGSHPInstrumentation        Instr             Basement
# 191               Elec_PowerPlugsInstMBRA        Instr       Master Bedroom
# 192            Elec_PowerPlugsInstBR2Hall        Instr            Bedroom 2
# 193               Elec_PowerPlugsInstHall        Instr        Entry Hallway
# 194    Elec_PowerLightingControlPanelRPS1        Instr             Basement
# 195                Elec_PowerPlugsInstBR3        Instr             Bedroom3
# 196     Elec_PowerHeatLoadforRefrigerator        Instr              Kitchen
# 197           Elec_PowerPlugsInstMudroomA        Instr              Mudroom
# 198    Elec_PowerLightingControlPanelRPS2        Instr             Basement
# 199    Elec_PowerPlugsHVACInstrumentation        Instr             Basement
# 200               Elec_PowerPlugsInstKitD        Instr              Kitchen
# 201                Elec_PowerPlugsInstBA1        Instr                Bath1
# 202               Elec_PowerPlugsInstKitA        Instr              Kitchen
# 203           Elec_PowerPlugsInstMudroomB        Instr              Mudroom
# 204                Elec_PowerPlugsInstDRA        Instr          Dining Room
# 205        Elec_EnergyLightsBasementStair     Lighting             Basement
# 206             Elec_EnergyLights2ndFloor     Lighting                Bath2
# 207            Elec_EnergyLights1stFloorA     Lighting             Multiple
# 208            Elec_EnergyLights1stFloorB     Lighting             Multiple
# 209             Elec_EnergyLightsBasement     Lighting             Basement
# 210                Elec_EnergyLightsAttic     Lighting                Attic
# 211         Elec_PowerLightsBasementStair     Lighting             Basement
# 212              Elec_PowerLights2ndFloor     Lighting                Bath2
# 213             Elec_PowerLights1stFloorA     Lighting             Multiple
# 214             Elec_PowerLights1stFloorB     Lighting             Multiple
# 215              Elec_PowerLightsBasement     Lighting             Basement
# 216                 Elec_PowerLightsAttic     Lighting                Attic
# 217           Elec_EnergyChildBDownstairs        Loads          Dining Room
# 218           Elec_EnergyChildADownstairs        Loads          Living Room
# 219            Elec_EnergyParentAUpstairs        Loads       Master Bedroom
# 220             Elec_EnergyChildAUpstairs        Loads             Bedroom2
# 221             Elec_EnergyChildBUpstairs        Loads             Bedroom3
# 222            Elec_EnergyParentBUpstairs        Loads       Master Bedroom
# 223          Elec_EnergyParentBDownstairs        Loads          Dining Room
# 224          Elec_EnergyParentADownstairs        Loads              Kitchen
# 225            Elec_PowerChildBDownstairs        Loads          Dining Room
# 226            Elec_PowerChildADownstairs        Loads          Living Room
# 227             Elec_PowerParentAUpstairs        Loads       Master Bedroom
# 228              Elec_PowerChildAUpstairs        Loads             Bedroom2
# 229              Elec_PowerChildBUpstairs        Loads             Bedroom3
# 230             Elec_PowerParentBUpstairs        Loads       Master Bedroom
# 231           Elec_PowerParentBDownstairs        Loads          Dining Room
# 232           Elec_PowerParentADownstairs        Loads              Kitchen
# 233        Load_1stFloorLightsEnergyUsage        Loads             Multiple
# 234         Load_1stFloorLightsPowerUsage        Loads             Multiple
# 235      Load_1stFloorSensHeatEnergyUsage        Loads             Multiple
# 236       Load_1stFloorSensHeatPowerUsage        Loads             Multiple
# 237        Load_2ndFloorLightsEnergyUsage        Loads             Multiple
# 238         Load_2ndFloorLightsPowerUsage        Loads             Multiple
# 239      Load_2ndFloorSensHeatEnergyUsage        Loads             Multiple
# 240       Load_2ndFloorSensHeatPowerUsage        Loads             Multiple
# 241     Load_BasementPlugLoadsEnergyUsage       Loads              Basement
# 242      Load_BasementPlugLoadsPowerUsage       Loads              Basement
# 243          Load_BR2PlugLoadsEnergyUsage        Loads             Bedroom2
# 244           Load_BR2PlugLoadsPowerUsage        Loads             Bedroom2
# 245          Load_BR3PlugLoadsEnergyUsage        Loads             Bedroom3
# 246           Load_BR3PlugLoadsPowerUsage        Loads             Bedroom3
# 247          Load_BR4PlugLoadsEnergyUsage        Loads             Bedroom4
# 248           Load_BR4PlugLoadsPowerUsage        Loads             Bedroom4
# 249   Load_ClothesWasherEnergywithStandby       Loads               Utility
# 250    Load_ClothesWasherPowerWithStandby        Loads              Utility
# 251                 Load_DryerEnergyTotal        Loads              Utility
# 252                  Load_DryerPowerTotal        Loads              Utility
# 253                 Load_RefrigeratorTemp        Loads              Kitchen
# 254            Load_KPlugLoadsEnergyUsage        Loads              Kitchen
# 255             Load_KPlugLoadsPowerUsage        Loads              Kitchen
# 256            Load_LatentHeatEnergyUsage        Loads              Kitchen
# 257             Load_LatentHeatPowerUsage        Loads              Kitchen
# 258            Load_LatentHeatWaterVolume        Loads              Kitchen
# 259           Load_LRPlugLoadsEnergyUsage        Loads          Living Room
# 260            Load_LRPlugLoadsPowerUsage        Loads          Living Room
# 261          Load_MBRPlugLoadsEnergyUsage        Loads       Master Bedroom
# 262           Load_MBRPlugLoadsPowerUsage        Loads       Master Bedroom
# 263       Load_MicrowaveEnergywithStandby       Loads               Kitchen
# 264        Load_MicrowavePowerWithStandby        Loads              Kitchen
# 265                  Load_OvenEnergyTotal        Loads              Kitchen
# 266                   Load_OvenPowerTotal        Loads              Kitchen
# 267    Load_RefrigeratorEnergywithStandby       Loads               Kitchen
# 268     Load_RefrigeratorPowerWithStandby        Loads              Kitchen
# 269           Load_StatusApplianceCooktop        Loads              Kitchen
# 270        Load_StatusApplianceDishwasher        Loads              Kitchen
# 271              Load_StatusApplianceOven        Loads              Kitchen
# 272         Load_StatusApplianceRangeHood        Loads              Kitchen
# 273                 Load_StatusLatentload        Loads              Kitchen
# 274            Load_StatusPlugLoadBlender        Loads              Kitchen
# 275          Load_StatusPlugLoadBR2Laptop        Loads             Bedroom2
# 276          Load_StatusPlugLoadBR3Laptop        Loads             Bedroom3
# 277          Load_StatusPlugLoadCanOpener        Loads              Kitchen
# 278        Load_StatusPlugLoadCoffeeMaker        Loads              Kitchen
# 279   Load_StatusPlugLoadDesktopPCMonitor        Loads             Bedroom4
# 280                Load_StatusPlugLoadFan        Loads       Master Bedroom
# 281  Load_StatusPlugLoadHairDryerCurlIron        Loads                MBath
# 282          Load_StatusPlugLoadHandMixer        Loads              Kitchen
# 283         Load_StatusPlugLoadHeatingPad        Loads       Master Bedroom
# 284               Load_StatusPlugLoadIron        Loads       Master Bedroom
# 285          Load_StatusPlugLoadLRBlueRay        Loads          Living Room
# 286               Load_StatusPlugLoadLRTV        Loads          Living Room
# 287         Load_StatusPlugLoadMBRBlueRay        Loads       Master Bedroom
# 288              Load_StatusPlugLoadMBRTV        Loads       Master Bedroom
# 289         Load_StatusPlugLoadSlowCooker        Loads              Kitchen
# 290            Load_StatusPlugLoadToaster        Loads              Kitchen
# 291        Load_StatusPlugLoadToasterOven        Loads              Kitchen
# 292             Load_StatusPlugLoadVacuum        Loads             Bedroom4
# 293          Load_StatusPlugLoadVideoGame        Loads          Living Room
# 294                  Load_StatusBR4Lights        Loads             Bedroom4
# 295                  Load_StatusMBALights        Loads                MBath
# 296                 Load_StatusMBRLights1        Loads       Master Bedroom
# 297                 Load_StatusMBRLights2        Loads       Master Bedroom
# 298                  Load_StatusBA2Lights        Loads                Bath2
# 299                  Load_StatusBR2Lights        Loads             Bedroom2
# 300                  Load_StatusBA1Lights        Loads                Bath1
# 301                  Load_StatusBR3Lights        Loads             Bedroom3
# 302          Load_StatusSensHeatPrntBDOWN        Loads          Dining Room
# 303            Load_StatusSensHeatPrntAUP        Loads       Master Bedroom
# 304             Load_StatusKitchenLightsA        Loads              Kitchen
# 305            Load_StatusSensHeatPrntBUP        Loads       Master Bedroom
# 306           Load_StatusSensHeatChildAUP        Loads             Bedroom2
# 307           Load_StatusSensHeatChildBUP        Loads             Bedroom3
# 308            Load_StatusKitchen LightsB        Loads              Kitchen
# 309         Load_StatusSensHeatChildBDOWN        Loads          Dining Room
# 310                  Load_StatusLRLights1        Loads          Living Room
# 311          Load_StatusSensHeatPrntADOWN        Loads              Kitchen
# 312         Load_StatusSensHeatChildADOWN        Loads          Living Room
# 313             Load_StatusKitchenLightsC        Loads              Kitchen
# 314                  Load_StatusLRLights2        Loads          Living Room
# 315                   Load_StatusDRLights        Loads          Dining Room
# 316                  Load_StatusLRLights3        Loads          Living Room
# 317            Load_StatusEntryHallLights        Loads        Entry Hallway
# 318                 OutEnv_OutdoorAmbTemp       OutEnv              Outdoor
# 319           OutEnv_RooftopWindDirection       OutEnv              Outdoor
# 320               OutEnv_RooftopWindSpeed       OutEnv              Outdoor
# 321                     Elec_EnergyPV1of2           PV             Basement
# 322                     Elec_EnergyPV2of2           PV             Basement
# 323                      Elec_PowerPV1of2           PV             Basement
# 324                      Elec_PowerPV2of2           PV             Basement
# 325                           PV_AmpsAIA1           PV                Attic
# 326                           PV_AmpsAIA2           PV                Attic
# 327                           PV_AmpsBIB1           PV                Attic
# 328                           PV_AmpsBIB2           PV                Attic
# 329                        PV_FrequencyF1          PV                 Attic
# 330                        PV_FrequencyF2          PV                 Attic
# 331         PV_PowerFactor3PhTotalPF3PhT1           PV                Attic
# 332         PV_PowerFactor3PhTotalPF3PhT2           PV                Attic
# 333                    PV_PVBacksideTemp2           PV              Outdoor
# 334                    PV_PVBacksideTemp3           PV              Outdoor
# 335                    PV_PVBacksideTemp4           PV              Outdoor
# 336                    PV_PVBacksideTemp7           PV              Outdoor
# 337                 PV_PVInsolationHArray           PV              Outdoor
# 338        PV_PVSystem1ACEnergyOSEACPV1OS           PV                Attic
# 339         PV_PVSystem1ACPowerOSPACPV1OS           PV                Attic
# 340        PV_PVSystem2ACEnergyOSEACPV2OS           PV                Attic
# 341         PV_PVSystem2ACPowerOSPACPV2OS           PV                Attic
# 342                 PV_StringCurrentIStr1          PV                 Attic
# 343                 PV_StringCurrentIStr2          PV                 Attic
# 344                 PV_StringCurrentIStr3          PV                 Attic
# 345                 PV_StringCurrentIStr4          PV                 Attic
# 346                 PV_StringVoltageUStr2           PV                Attic
# 347                 PV_StringVoltageUStr4           PV                Attic
# 348                        PV_VoltsANUAN1           PV                Attic
# 349                        PV_VoltsANUAN2           PV                Attic
# 350                        PV_VoltsBNUBN1           PV                Attic
# 351                        PV_VoltsBNUBN2           PV                Attic
# 352                PV_Watts3PhTotalW3PhT1           PV                Attic
# 353                PV_Watts3PhTotalW3PhT2           PV                Attic
# 354                PV_WhoursDeliveredWhD1           PV                Attic
# 355                PV_WhoursDeliveredWhD2           PV                Attic
# 356      Elec_PowerPlugsBaseAHeliodyneHXs          SHW             Basement
# 357           SHW_GlycolFlowHXCoriolisSHW          SHW             Basement
# 358       SHW_GlycolFlowRateHXCoriolisSHW          SHW             Basement
# 359        SHW_GlycolTempSHWPanel80galOut          SHW              Outdoor
# 360                            SHW_PSPSHW          SHW              Outdoor
# 361               SHW_SHWHX80galWaterFlow          SHW             Basement
# 362            SHW_WaterFlowHXCoriolisSHW          SHW             Basement
# 363        SHW_WaterFlowRateHXCoriolisSHW          SHW             Basement
# 364            Elec_EnergyMakeUpAirDamper  Ventilation                Attic
# 365             Elec_PowerMakeUpAirDamper  Ventilation                Attic
# 366    Vent_HRVDewpointTemperatureExhaust  Ventilation             Basement
# 367    Vent_HRVDewpointTemperatureOutdoor  Ventilation             Basement
# 368     Vent_HRVDewpointTemperatureReturn  Ventilation             Basement
# 369     Vent_HRVDewpointTemperatureSupply  Ventilation             Basement
# 370               Vent_HRVexhaustflowrate  Ventilation             Basement
# 371  Vent_HRVfreshairpressuredifferential  Ventilation             Basement
# 372               Vent_HRVoutdoorflowrate  Ventilation             Basement
# 373                Vent_HRVreturnflowrate  Ventilation             Basement
# 374  Vent_HRVstaleairpressuredifferential  Ventilation             Basement
# 375                Vent_HRVTempExhaustOut  Ventilation             Basement
# 376                 Vent_HRVTempOutdoorin  Ventilation             Basement
# 377                  Vent_HRVTempReturnIn  Ventilation             Basement
# 378                 Vent_HRVTempSupplyOut  Ventilation             Basement
#
#          Measured Parameter  \
# 0                Flow_Water
# 1                Flow_Water
# 2                Flow_Water
# 3               Temp_Glycol
# 4               Temp_Glycol
# 5         Energy_Electrical
# 6          Power_Electrical
# 7                Flow_Water
# 8                Flow_Water
# 9                Flow_Water
# 10                 Temp_Air
# 11        Energy_Electrical
# 12         Power_Electrical
# 13             Status_OnOff
# 14             Status_OnOff
# 15             Status_OnOff
# 16             Status_OnOff
# 17             Status_OnOff
# 18             Status_OnOff
# 19               Temp_Water
# 20               Temp_Water
# 21               Temp_Water
# 22               Temp_Water
# 23               Temp_Water
# 24               Temp_Water
# 25               Temp_Water
# 26               Temp_Water
# 27               Temp_Water
# 28               Temp_Water
# 29               Temp_Water
# 30               Temp_Water
# 31               Temp_Water
# 32               Temp_Water
# 33               Temp_Water
# 34               Temp_Water
# 35               Temp_Water
# 36               Temp_Water
# 37               Temp_Water
# 38               Temp_Water
# 39               Temp_Water
# 40               Temp_Water
# 41               Temp_Water
# 42               Temp_Water
# 43               Temp_Water
# 44               Temp_Water
# 45               Temp_Water
# 46               Temp_Water
# 47               Temp_Water
# 48               Temp_Water
# 49               Temp_Water
# 50        Energy_Electrical
# 51        Energy_Electrical
# 52         Power_Electrical
# 53         Power_Electrical
# 54        Energy_Electrical
# 55        Energy_Electrical
# 56        Energy_Electrical
# 57        Energy_Electrical
# 58        Energy_Electrical
# 59        Energy_Electrical
# 60        Energy_Electrical
# 61        Energy_Electrical
# 62        Energy_Electrical
# 63        Energy_Electrical
# 64        Energy_Electrical
# 65        Energy_Electrical
# 66        Energy_Electrical
# 67        Energy_Electrical
# 68        Energy_Electrical
# 69        Energy_Electrical
# 70        Energy_Electrical
# 71        Energy_Electrical
# 72        Energy_Electrical
# 73        Energy_Electrical
# 74        Energy_Electrical
# 75        Energy_Electrical
# 76        Energy_Electrical
# 77        Energy_Electrical
# 78        Energy_Electrical
# 79        Energy_Electrical
# 80        Energy_Electrical
# 81        Energy_Electrical
# 82        Energy_Electrical
# 83        Energy_Electrical
# 84        Energy_Electrical
# 85         Power_Electrical
# 86         Power_Electrical
# 87         Power_Electrical
# 88         Power_Electrical
# 89         Power_Electrical
# 90         Power_Electrical
# 91         Power_Electrical
# 92         Power_Electrical
# 93         Power_Electrical
# 94         Power_Electrical
# 95         Power_Electrical
# 96         Power_Electrical
# 97         Power_Electrical
# 98         Power_Electrical
# 99         Power_Electrical
# 100        Power_Electrical
# 101        Power_Electrical
# 102        Power_Electrical
# 103        Power_Electrical
# 104        Power_Electrical
# 105        Power_Electrical
# 106        Power_Electrical
# 107        Power_Electrical
# 108        Power_Electrical
# 109        Power_Electrical
# 110        Power_Electrical
# 111        Power_Electrical
# 112        Power_Electrical
# 113        Power_Electrical
# 114        Power_Electrical
# 115       Energy_Electrical
# 116        Power_Electrical
# 117                Flow_Air
# 118                Temp_Air
# 119                Temp_Air
# 120        Power_Electrical
# 121        Power_Electrical
# 122        Power_Electrical
# 123               Temp_DewP
# 124               Temp_DewP
# 125                Temp_Air
# 126                Temp_Air
# 127                      RH
# 128                      RH
# 129                      RH
# 130                      RH
# 131                      RH
# 132                      RH
# 133                      RH
# 134                Temp_Rad
# 135                Temp_Rad
# 136                Temp_Rad
# 137                Temp_Rad
# 138                Temp_Rad
# 139                Temp_Air
# 140                Temp_Air
# 141                Temp_Air
# 142                Temp_Air
# 143                Temp_Air
# 144                Temp_Air
# 145                Temp_Air
# 146                Temp_Air
# 147                Temp_Air
# 148                Temp_Air
# 149                Temp_Air
# 150                Temp_Air
# 151                Temp_Air
# 152                Temp_Air
# 153                Temp_Air
# 154                Temp_Air
# 155                Temp_Air
# 156                Temp_Air
# 157                Temp_Air
# 158                Temp_Air
# 159                Temp_Air
# 160                Temp_Air
# 161                Temp_Air
# 162                Temp_Air
# 163       Energy_Electrical
# 164       Energy_Electrical
# 165       Energy_Electrical
# 166       Energy_Electrical
# 167       Energy_Electrical
# 168       Energy_Electrical
# 169       Energy_Electrical
# 170       Energy_Electrical
# 171       Energy_Electrical
# 172       Energy_Electrical
# 173       Energy_Electrical
# 174       Energy_Electrical
# 175          Energy_Thermal
# 176       Energy_Electrical
# 177       Energy_Electrical
# 178       Energy_Electrical
# 179       Energy_Electrical
# 180       Energy_Electrical
# 181       Energy_Electrical
# 182       Energy_Electrical
# 183       Energy_Electrical
# 184        Power_Electrical
# 185        Power_Electrical
# 186        Power_Electrical
# 187        Power_Electrical
# 188        Power_Electrical
# 189        Power_Electrical
# 190        Power_Electrical
# 191        Power_Electrical
# 192        Power_Electrical
# 193        Power_Electrical
# 194        Power_Electrical
# 195        Power_Electrical
# 196           Power_Thermal
# 197        Power_Electrical
# 198        Power_Electrical
# 199        Power_Electrical
# 200        Power_Electrical
# 201        Power_Electrical
# 202        Power_Electrical
# 203        Power_Electrical
# 204        Power_Electrical
# 205       Energy_Electrical
# 206       Energy_Electrical
# 207       Energy_Electrical
# 208       Energy_Electrical
# 209       Energy_Electrical
# 210       Energy_Electrical
# 211        Power_Electrical
# 212        Power_Electrical
# 213        Power_Electrical
# 214        Power_Electrical
# 215        Power_Electrical
# 216        Power_Electrical
# 217          Energy_Thermal
# 218          Energy_Thermal
# 219          Energy_Thermal
# 220          Energy_Thermal
# 221          Energy_Thermal
# 222          Energy_Thermal
# 223          Energy_Thermal
# 224          Energy_Thermal
# 225           Power_Thermal
# 226           Power_Thermal
# 227           Power_Thermal
# 228           Power_Thermal
# 229           Power_Thermal
# 230           Power_Thermal
# 231           Power_Thermal
# 232           Power_Thermal
# 233       Energy_Electrical
# 234        Power_Electrical
# 235          Energy_Thermal
# 236           Power_Thermal
# 237       Energy_Electrical
# 238        Power_Electrical
# 239          Energy_Thermal
# 240           Power_Thermal
# 241       Energy_Electrical
# 242        Power_Electrical
# 243       Energy_Electrical
# 244        Power_Electrical
# 245       Energy_Electrical
# 246        Power_Electrical
# 247       Energy_Electrical
# 248        Power_Electrical
# 249       Energy_Electrical
# 250        Power_Electrical
# 251       Energy_Electrical
# 252        Power_Electrical
# 253                Temp_Air
# 254       Energy_Electrical
# 255        Power_Electrical
# 256          Energy_Thermal
# 257           Power_Thermal
# 258              Flow_Water
# 259       Energy_Electrical
# 260        Power_Electrical
# 261       Energy_Electrical
# 262        Power_Electrical
# 263       Energy_Electrical
# 264        Power_Electrical
# 265       Energy_Electrical
# 266        Power_Electrical
# 267       Energy_Electrical
# 268        Power_Electrical
# 269            Status_OnOff
# 270            Status_OnOff
# 271            Status_OnOff
# 272            Status_OnOff
# 273            Status_OnOff
# 274            Status_OnOff
# 275            Status_OnOff
# 276            Status_OnOff
# 277            Status_OnOff
# 278            Status_OnOff
# 279            Status_OnOff
# 280            Status_OnOff
# 281            Status_OnOff
# 282            Status_OnOff
# 283            Status_OnOff
# 284            Status_OnOff
# 285            Status_OnOff
# 286            Status_OnOff
# 287            Status_OnOff
# 288            Status_OnOff
# 289            Status_OnOff
# 290            Status_OnOff
# 291            Status_OnOff
# 292            Status_OnOff
# 293            Status_OnOff
# 294            Status_OnOff
# 295            Status_OnOff
# 296            Status_OnOff
# 297            Status_OnOff
# 298            Status_OnOff
# 299            Status_OnOff
# 300            Status_OnOff
# 301            Status_OnOff
# 302            Status_OnOff
# 303            Status_OnOff
# 304            Status_OnOff
# 305            Status_OnOff
# 306            Status_OnOff
# 307            Status_OnOff
# 308            Status_OnOff
# 309            Status_OnOff
# 310            Status_OnOff
# 311            Status_OnOff
# 312            Status_OnOff
# 313            Status_OnOff
# 314            Status_OnOff
# 315            Status_OnOff
# 316            Status_OnOff
# 317            Status_OnOff
# 318                Temp_Air
# 319                Flow_Air
# 320                Flow_Air
# 321       Energy_Electrical
# 322       Energy_Electrical
# 323        Power_Electrical
# 324        Power_Electrical
# 325      Current_Electrical
# 326      Current_Electrical
# 327      Current_Electrical
# 328      Current_Electrical
# 329    Frequency_Electrical
# 330    Frequency_Electrical
# 331  PowerFactor_Electrical
# 332  PowerFactor_Electrical
# 333                 Temp_PV
# 334                 Temp_PV
# 335                 Temp_PV
# 336                 Temp_PV
# 337             Light_Solar
# 338       Energy_Electrical
# 339        Power_Electrical
# 340       Energy_Electrical
# 341        Power_Electrical
# 342      Current_Electrical
# 343      Current_Electrical
# 344      Current_Electrical
# 345      Current_Electrical
# 346      Voltage_Electrical
# 347      Voltage_Electrical
# 348      Voltage_Electrical
# 349      Voltage_Electrical
# 350      Voltage_Electrical
# 351      Voltage_Electrical
# 352        Power_Electrical
# 353        Power_Electrical
# 354       Energy_Electrical
# 355       Energy_Electrical
# 356        Power_Electrical
# 357             Flow_Glycol
# 358             Flow_Glycol
# 359             Temp_Glycol
# 360             Light_Solar
# 361              Flow_Water
# 362              Flow_Water
# 363              Flow_Water
# 364       Energy_Electrical
# 365        Power_Electrical
# 366               Temp_DewP
# 367               Temp_DewP
# 368               Temp_DewP
# 369               Temp_DewP
# 370                Flow_Air
# 371            Pressure_Air
# 372                Flow_Air
# 373                Flow_Air
# 374            Pressure_Air
# 375                Temp_Air
# 376                Temp_Air
# 377                Temp_Air
# 378                Temp_Air
#
#                                            Description               Units
# 0    The cumulative volume of cold water flowing in...             Gallons
# 1    The cumulative volume of hot water flowing int...             Gallons
# 2    The cumulative volume of hot water flowing int...             Gallons
# 3    The instantaneous temperature of the glycol-wa...                  °C
# 4    The instantaneous temperature of the glycol-wa...                  °C
# 5    Cumulative energy consumption by heat pump wat...                  Wh
# 6    Instantaneous power consumption by heat pump w...                   W
# 7    The cumulative volume of water flowing into th...             Gallons
# 8    The cumulative volume of water flowing into th...             Gallons
# 9    The cumulative volume of mains water flowing i...             Gallons
# 10   The dry bulb air temperature located two feet ...                  °C
# 11   Cumulative energy consumption by solar water h...                  Wh
# 12   Instantaneous power consumption by solar water...                   W
# 13   Number to indicate whether cold water is flowi...
# 14   Number to indicate whether cold water is flowi...
# 15   Number to indicate whether cold water is flowi...
# 16   Number to indicate whether hot water is flowin...
# 17   Number to indicate whether hot water is flowin...
# 18   Number to indicate whether hot water is flowin...
# 19   The instantaneous temperature of the water in ...                  °C
# 20   The instantaneous temperature of the water in ...                  °C
# 21   The instantaneous temperature of the water in ...                  °C
# 22   The instantaneous temperature of the water in ...                  °C
# 23   The instantaneous temperature of the water in ...                  °C
# 24   The instantaneous temperature of the water in ...                  °C
# 25   The instantaneous temperature of the water in ...                  °C
# 26   The instantaneous temperature of the water on ...                  °C
# 27   The instantaneous temperature of the water on ...                  °C
# 28   The instantaneous temperature of the water in ...                  °C
# 29   The instantaneous temperature of the water in ...                  °C
# 30   The instantaneous temperature of the water in ...                  °C
# 31   The instantaneous temperature of the water ent...                  °C
# 32   The instantaneous temperature of the water ent...                  °C
# 33   The instantaneous temperature of the water in ...                  °C
# 34   The instantaneous temperature of the water in ...                  °C
# 35   The instantaneous temperature of the water in ...                  °C
# 36   The instantaneous temperature of the water in ...                  °C
# 37   The instantaneous temperature of the water in ...                  °C
# 38   The instantaneous temperature of the water in ...                  °C
# 39   The instantaneous temperature of the water in ...                  °C
# 40   The instantaneous temperature of the water in ...                  °C
# 41   The instantaneous temperature of the water in ...                  °C
# 42   The instantaneous temperature of the water fro...                  °C
# 43   The instantaneous temperature of the water fro...                  °C
# 44   The instantaneous temperature of the potable w...                  °C
# 45   The instantaneous temperature of the potable w...                  °C
# 46   The instantaneous temperature of the water ent...                  °C
# 47   The instantaneous temperature of the water lea...                  °C
# 48   The instantaneous temperature of the water in ...                  °C
# 49   The instantaneous temperature of the water in ...                  °C
# 50   Cumulative energy consumption of one leg of el...                  Wh
# 51   Cumulative energy consumption of one leg of el...                  Wh
# 52   Instantaneous power consumption of one leg of ...                   W
# 53   Instantaneous power consumption of one leg of ...                   W
# 54   Cumulative energy used by solar water heater p...                  Wh
# 55   Cumulative energy consumption at receptacles o...                  Wh
# 56   Cumulative energy consumption at receptacles o...                  Wh
# 57   Cumulative energy consumption at receptacles i...                  Wh
# 58   Cumulative energy consumption at receptacles o...                  Wh
# 59   Cumulative energy consumption of clothes washe...                  Wh
# 60   Cumulative energy consumption of one leg of el...                  Wh
# 61   Cumulative energy consumption of one leg of el...                  Wh
# 62   Cumulative energy consumption at receptacle B ...                  Wh
# 63   Cumulative energy consumption at receptacle C ...                  Wh
# 64   Cumulative energy consumption of sump pump in ...                  Wh
# 65   Cumulative energy consumption of standby elect...                  Wh
# 66   Cumulative energy consumption at receptacles o...                  Wh
# 67   Cumulative energy consumption by garbage dispo...                  Wh
# 68   Cumulative energy consumption by blender from ...                  Wh
# 69   Cumulative energy consumption by hand mixer an...                  Wh
# 70   Cumulative energy consumption by microwave ove...                  Wh
# 71   Cumulative energy consumption from receptacles...                  Wh
# 72   Cumulative energy consumption by computer netw...                  Wh
# 73   Cumulative energy consumption from receptacles...                  Wh
# 74   Cumulative energy consumption from receptacles...                  Wh
# 75   Cumulative energy consumption from receptacles...                  Wh
# 76   Cumulative energy consumption by dishwasher fr...                  Wh
# 77   Cumulative energy consumption from receptacles...                  Wh
# 78   Cumulative energy consumption from receptacles...                  Wh
# ...
# 172  Cumulative energy consumption from midnight by...                  Wh
# 173  Cumulative energy consumption from midnight by...                  Wh
# 174  Cumulative energy consumption from midnight by...                  Wh
# 175  Cumulative heat energy added to compartment of...                  Wh
# 176  Cumulative energy consumption from midnight by...                  Wh
# 177  Cumulative energy consumption from midnight by...                  Wh
# 178  Cumulative energy consumption from midnight by...                  Wh
# 179  Cumulative energy consumption from midnight by...                  Wh
# 180  Cumulative energy consumption from midnight by...                  Wh
# 181  Cumulative energy consumption from midnight by...                  Wh
# 182  Cumulative energy consumption from midnight by...                  Wh
# 183  Cumulative energy consumption from midnight by...                  Wh
# 184  Instantaneous power consumption by instrumenta...                   W
# 185  Instantaneous power consumption by instrumenta...                   W
# 186  Instantaneous power consumption by instrumenta...                   W
# 187  Instantaneous power consumption by instrumenta...                   W
# 188  Instantaneous power consumption by instrumenta...                   W
# 189  Instantaneous power consumption by instrumenta...                   W
# 190  Instantaneous power consumption by instrumenta...                   W
# 191  Instantaneous power by instrumentation plugged...                   W
# 192  Instantaneous power consumption by instrumenta...                   W
# 193  Instantaneous power consumption by instrumenta...                   W
# 194  Instantaneous power consumption by lighting co...                   W
# 195  Instantaneous power consumption by instrumenta...                   W
# 196  Instantaneous power of heat load in refrigerat...                   W
# 197  Instantaneous power consumption by instrumenta...                   W
# 198  Instantaneous power consumption by lighting co...                   W
# 199  Instantaneous power consumption by instrumenta...                   W
# 200  Instantaneous power consumption by instrumenta...                   W
# 201  Instantaneous power consumption by instrumenta...                   W
# 202  Instantaneous power consumption by instrumenta...                   W
# 203  Instantaneous power consumption by instrumenta...                   W
# 204  Instantaneous power consumption by instrumenta...                   W
# 205  Cumulative energy consumption of lights over b...                  Wh
# 206  Cumulative energy consumption of lighting in b...                  Wh
# 207  Cumulative energy consumption by a subset of l...                  Wh
# 208  Cumulative energy consumption by a subset of l...                  Wh
# 209  Cumulative energy consumption from midnight by...                  Wh
# 210  Cumulative energy consumption from midnight by...                  Wh
# 211  Instantaneous power used by lights over baseme...                   W
# 212  Instantaneous power consumption of lighting in...                   W
# 213  Instantaneous power consumption by a subset of...                   W
# 214  Instantaneous power consumption by a subset of...                   W
# 215  Instantaneous power consumption by lights acti...                   W
# 216  Instantaneous power consumption by lights acti...                   W
# 217  Cumulative heat energy given off from midnight...                  Wh
# 218  Cumulative heat energy given off from midnight...                  Wh
# 219  Cumulative heat energy given off from midnight...                  Wh
# 220  Cumulative heat energy given off from midnight...                  Wh
# 221  Cumulative heat energy given off from midnight...                  Wh
# 222  Cumulative heat energy given off from midnight...                  Wh
# 223  Cumulative heat energy given off from midnight...                  Wh
# 224  Cumulative heat energy given off from midnight...                  Wh
# 225  Instantaneous power consumption by emulator of...                   W
# 226  Instantaneous power consumption by emulator of...                   W
# 227  Instantaneous power consumption by emulator of...                   W
# 228  Instantaneous power consumption by emulator of...                   W
# 229  Instantaneous power consumption by emulator of...                   W
# 230  Instantaneous power consumption by emulator of...                   W
# 231  Instantaneous power consumption by emulator of...                   W
# 232  Instantaneous power consumption by emulator of...                   W
# 233  Cumulative energy consumption starting at midn...                  Wh
# 234  Instantaneous power consumption by lights on f...                   W
# 235  Cumulative energy consumption starting at midn...                  Wh
# 236  Instantaneous power consumption by sensible he...                   W
# 237  Cumulative energy consumption starting at midn...                  Wh
# 238  Instantaneous power consumption by lights on s...                   W
# 239  Cumulative energy consumption starting at midn...                  Wh
# 240  Instantaneous power consumption by sensible he...                   W
# 241  Cumulative energy consumption starting at midn...                  Wh
# 242  Instantaneous power consumption by plug loads ...                   W
# 243  Cumulative energy consumption starting at midn...                  Wh
# 244  Instantaneous power consumption by plug loads ...                   W
# 245  Cumulative energy consumption starting at midn...                  Wh
# 246  Instantaneous power consumption by plug loads ...                   W
# 247  Cumulative energy consumption starting at midn...                  Wh
# 248  Instantaneous power consumption by plug loads ...                   W
# 249  Cumulative energy consumption starting at midn...                  Wh
# 250  Instantaneous power consumption by clothes washer                   W
# 251  Cumulative energy consumption starting at midn...                  Wh
# 252           Instantaneous power consumption by dryer                   W
# 253  Instantaneous temperature within refrigerator ...                  °C
# 254  Cumulative energy consumption starting at midn...                  Wh
# 255  Instantaneous power consumption by plug loads ...                   W
# 256  Cumulative energy consumption starting at midn...                  Wh
# 257  Instantaneous power consumption by moisture ge...                   W
# 258  Cumulative volume of water injected into space...             Gallons
# 259  Cumulative energy consumption starting at midn...                  Wh
# 260  Instantaneous power consumption by plug loads ...                   W
# 261  Cumulative energy consumption starting at midn...                  Wh
# 262  Instantaneous power consumption by plug loads ...                   W
# 263  Cumulative energy consumption starting at midn...                  Wh
# 264  Instantaneous power consumption by microwave oven                   W
# 265  Cumulative energy consumption starting at midn...                  Wh
# 266            Instantaneous power consumption by oven                   W
# 267  Cumulative energy consumption starting at midn...                  Wh
# 268    Instantaneous power consumption by refrigerator                   W
# 269  Number to indicate whether cooktop is activate...
# 270  Number to indicate whether dishwasher is activ...
# 271  Number to indicate whether oven is activated (...
# 272  Number to indicate whether range hood is activ...
# 273  Number to indicate whether moisture generator ...
# 274  Number to indicate whether blender is activate...
# 275  Number to indicate whether laptop computer in ...
# 276  Number to indicate whether laptop computer in ...
# 277  Number to indicate whether can opener is activ...
# 278  Number to indicate whether coffee maker is act...
# 279  Number to indicate whether desktop computer an...
# 280  Number to indicate whether fan in master bedro...
# 281  Number to indicate whether hair dryer or curli...
# 282  Number to indicate whether hand mixer is activ...
# 283  Number to indicate whether heating pad is acti...
# 284  Number to indicate whether iron is activated (...
# 285  Number to indicate whether BluRay player in li...
# 286  Number to indicate whether television in livin...
# 287  Number to indicate whether BluRay player in ma...
# 288  Number to indicate whether television in maste...
# 289  Number to indicate whether slow cooker is acti...
# 290  Number to indicate whether toaster is activate...
# 291  Number to indicate whether toaster oven is act...
# 292  Number to indicate whether vacuum is activated...
# 293  Number to indicate whether video game console ...
# 294  Number to indicate whether lights in bedroom 4...
# 295  Number to indicate whether lights in master ba...
# 296  Number to indicate whether lights A in master ...
# 297  Number to indicate whether lights B in master ...
# 298  Number to indicate whether lights 2nd floor ba...
# 299  Number to indicate whether lights in bedroom 2...
# 300  Number to indicate whether lights in 1st floor...
# 301  Number to indicate whether lights in bedroom 3...
# 302  Number to indicate whether parent B is simulat...
# 303  Number to indicate whether parent A is simulat...
# 304  Number to indicate whether lights A in kitchen...
# 305  Number to indicate whether parent B is simulat...
# 306  Number to indicate whether child A is simulate...
# 307  Number to indicate whether child B is simulate...
# 308  Number to indicate whether lights B in kitchen...
# 309  Number to indicate whether child B is simulate...
# 310  Number to indicate whether lights in living ro...
# 311  Number to indicate whether parent A is simulat...
# 312  Number to indicate whether child A is simulate...
# 313  Number to indicate whether lights C in kitchen...
# 314  Number to indicate whether lights in living ro...
# 315  Number to indicate whether lights in dining ro...
# 316  Number to indicate whether lights in living ro...
# 317  Number to indicate whether lights in entry hal...
# 318  Instantaneous dry bulb temperature measured ab...                  °C
# 319  Instantaneous wind direction measured above th...             degrees
# 320  Instantaneous wind speed measured above the ro...                 m/s
# 321  Cumulative energy fed into breaker panel by on...                  Wh
# 322  Cumulative energy fed into breaker panel by on...                  Wh
# 323  Instantaneous power fed into breaker panel by ...                   W
# 324  Instantaneous power fed into breaker panel by ...                   W
# 325  Instantaneous current produced from the Phase ...                   A
# 326  Instantaneous current produced from the Phase ...                   A
# 327  Instantaneous current produced from the Phase ...                   V
# 328  Instantaneous current produced from the Phase ...                   V
# 329  Instantaneous frequency of AC electricity outp...                  Hz
# 330  Instantaneous frequency of AC electricity outp...                  Hz
# 331  Instantaneous power factor of electricity outp...
# 332  Instantaneous power factor of electricity outp...
# 333  Instantaneous temperature on the backside of m...                  °C
# 334  Instantaneous temperature on the backside of m...                  °C
# 335  Instantaneous temperature on the backside of m...                  °C
# 336  Instantaneous temperature on the backside of m...                  °C
# 337  The amount of sunlight impacting the array dur...                 kWh
# 338  Cumulative AC energy generation out of inverte...                  Wh
# 339  Instantaneous AC power reading from inverter 1...                   W
# 340  Cumulative AC energy generation out of the inv...                  Wh
# 341  Instantaneous AC power reading from inverter 1...                   W
# 342  Instantaneous direct current from string 1 fee...                   A
# 343  Instantaneous direct current from string 2 fee...                   A
# 344  Instantaneous direct current from string 3 fee...                   A
# 345  Instantaneous direct current from string 4 fee...                   A
# 346  Instantaneous voltage from Strings 1 and 2 of ...                   V
# 347  Instantaneous voltage from Strings 3 and 4 of ...                   V
# 348  Instantaneous voltage difference between the P...                   V
# 349  Instantaneous voltage difference between the P...                   V
# 350  Instantaneous voltage difference between the P...                   V
# 351  Instantaneous voltage difference between the P...                   V
# 352  Instantaneous power produced from Inverter 1 (...                   W
# 353  Instantaneous power produced from Inverter 2 (...                   W
# 354  Cumulative energy delivered by inverter 1 from...                  Wh
# 355  Cumulative energy delivered by inverter 2 from...                  Wh
# 356  Instantaneous power used by solar water heater...                   W
# 357  Cumulative volume of glycol/water solution flo...             Gallons
# 358  Instantaneous flow rate of glycol/water soluti...  Gallons Per Minute
# 359  Instantaneous temperature of glycol/water solu...                  °C
# 360  Solar broadband insolation measured adjacent t...                W/m2
# 361  Cumulative volume of potable water flowing thr...             Gallons
# 362  Cumulative volume of potable water flowing thr...             Gallons
# 363  Instantaneous flow rate of potable water flowi...  Gallons Per Minute
# 364  Cumulative energy consumption of make-up air d...                  Wh
# 365  Instantaneous power consumption of make-up air...                   W
# 366  Instantaneous dew point temperature in the exh...                  °C
# 367  Instantaneous dew point temperature in the out...                  °C
# 368  Instantaneous dew point temperature in the ret...                  °C
# 369  Instantaneous dew point temperature in the sup...                  °C
# 370  Instantaneous flow rate of air in the exhaust ...             ft3/min
# 371  Instantaneous pressure differential across hea...          Inches H2O
# 372  Instantaneous flow rate of air in the outdoor ...             ft3/min
# 373  Instantaneous flow rate of air in the return f...             ft3/min
# 374  Instantaneous pressure differential across hea...          Inches H2O
# 375  Instantaneous dry bulb temperature in the exha...                  °C
# 376  Instantaneous dry bulb temperature in the outd...                  °C
# 377  Instantaneous dry bulb temperature in the retu...                  °C
# 378  Instantaneous dry bulb temperature in the supp...                  °C

# %%
Location_cols = ["Measurement Location"]
Description_cols = ["Subsystem","Measured Parameter","Description","Units"]
Data_Label_cols = ["Data Label"]

# %%
dataset.columns
# Out:
# Index(['Data Label', 'Subsystem', 'Measurement Location', 'Measured Parameter',
#        'Description', 'Units'],
#       dtype='object')

# %%
def get_a_merged_df(df, cols, colname):
    tmp = dataset[cols[0]]
    for i in range(1,len(cols)):
        tmp+=" "+ dataset[cols[i]]
    desc_df = pd.DataFrame(tmp)
    desc_df.columns =[colname]
    return desc_df

# %%
df_desc = get_a_merged_df(dataset, Description_cols, "Description")

# %%
df_data_label = get_a_merged_df(dataset, Data_Label_cols, "Data Label")

# %%
df_location = get_a_merged_df(dataset, Location_cols, "Location")

# %%
df_desc.values[0]
# Out:
# array(['DHW Flow_Water The cumulative volume of cold water flowing into the clothes washer starting at midnight Gallons'],
#       dtype=object)

# %%
metadata = pd.concat([df_data_label, df_location, df_desc], axis=1)

# %%
metadata.to_csv('NIST_metadata_cleaned.csv');

# %%
metadata['Description'].values[0]
# Out:
# 'DHW Flow_Water The cumulative volume of cold water flowing into the clothes washer starting at midnight Gallons'

# %%
list_of_rows = []
for index, row in metadata.iterrows():
    list_of_rows.append((row[0],row[1],row[2]))

# %% [markdown]
# ## Analyzing locations

# %%
locations = metadata['Location']
locations = list(set(locations.tolist()))

# %%
locations
# Out:
# ['Attic',
#  'Bath2',
#  'Kitchen',
#  'Entry Hallway',
#  'Bedroom3',
#  'Bedroom4',
#  'Mudroom',
#  'Dining Room',
#  'Master Bedroom',
#  'Basement',
#  'Outdoor',
#  'Bath1',
#  'Utility',
#  'MBath',
#  'Living Room',
#  'Bedroom2',
#  'Multiple',
#  'MBedroom',
#  'Bedroom 2']

# %%
list_of_locations = []
for triple in g:
    if "#Location" in triple[2] and "https://brickschema.org/schema/Brick#hasAssociatedTag" in triple[1]:
        list_of_locations.append(triple[0].replace("https://brickschema.org/schema/Brick#",""))
print(list_of_locations)
# Out:
# ['Pump_Room', 'Waste_Storage', 'Wing', 'Conference_Room', 'Janitor_Room', 'Environment_Box', 'Shower', 'Outside', 'Electrical_Room', 'Security_Service_Room', 'Lobby', 'Lounge', 'Zone', 'Control_Room', 'Freezer', 'Cold_Box', 'Massage_Room', 'Private_Office', 'Equipment_Room', 'Room', 'IDF', 'Generator_Room', 'Open_Office', 'Majlis', 'Switch_Room', 'Region', 'Laboratory', 'Ticketing_Booth', 'Plumbing_Room', 'Media_Production_Room', 'Server_Room', 'Common_Space', 'Mechanical_Room', 'Workshop', 'Distribution_Frame', 'Break_Room', 'Space', 'Battery_Room', 'Restroom', 'Energy_Zone', 'Hospitality_Box', 'Library', 'Elevator_Space', 'Employee_Entrance_Lobby', 'Riser', 'Team_Room', 'Exercise_Room', 'Elevator_Shaft', 'Ablutions_Room', 'TETRA_Room', 'Concession', 'Vertical_Space', 'Broadcast_Room', 'Reception', 'Enclosed_Office', 'Visitor_Lobby', 'Floor', 'Bench_Space', 'Basement', 'Office_Kitchen', 'Wardrobe', 'Rooftop', 'Fire_Zone', 'Gatehouse', 'Lighting_Zone', 'Sports_Service_Room', 'Water_Tank', 'Loading_Dock', 'Transformer_Room', 'Studio', 'Mail_Room', 'Tunnel', 'Auditorium', 'Food_Service_Room', 'Detention_Room', 'HVAC_Zone', 'Outdoor_Area', 'Information_Area', 'Parking_Structure', 'Entrance', 'Hallway', 'Copy_Room', 'Shared_Office', 'Site', 'Staircase', 'MDF', 'Hazardous_Materials_Storage', 'Breakroom', 'Parking_Level', 'Office', 'Rest_Room', 'First_Aid_Room', 'Media_Hot_Desk', 'Cubicle', 'Media_Room', 'Storey', 'Telecom_Room', 'Prayer_Room', 'Service_Room', 'Field_Of_Play', 'Storage_Room', 'Medical_Room', 'Cafeteria', 'Parking_Space', 'Building', 'Location', 'Retail_Room', 'Hot_Box']

# %%
def search_locations(query, topk=1):
    if "room" in query.lower():
        query+=" room"
    query_vec = vectorizer_class.transform([query])
    search_result = {}
    idx = 0
    for index, row in df_class.iterrows():
        class_name = list_of_classname[idx]
        similarity = cosine_similarity(row.values.reshape(1,len(row.values)), query_vec.toarray())[0][0]
        search_result[class_name]=similarity
        idx+=1

    search_result = dict(sorted(search_result.items(), key=lambda item: item[1], reverse=True))
    return_list = []
    rank=1
    for key in search_result.keys():
        if key in list_of_locations:
            return_list.append((key,search_result[key]))
            if rank==topk: break
            rank+=1
    if return_list[0][1]==0.0:
        return_list= [('Location', 1,0)]
    return return_list

# %%
## Suggesting Brick Location Classes based on Location Names
for location in locations:
    print(location, search_locations(location))
# Out:
# Attic [('Location', 1, 0)]
# Bath2 [('Location', 1, 0)]
# Kitchen [('Location', 1, 0)]
# Entry Hallway [('Hallway', 1.0)]
# Bedroom3 [('Room', 1.0)]
# Bedroom4 [('Room', 1.0)]
# Mudroom [('Room', 1.0)]
# Dining Room [('Room', 1.0)]
# Master Bedroom [('Room', 1.0)]
# Basement [('Basement', 1.0)]
# Outdoor [('Location', 1, 0)]
# Bath1 [('Location', 1, 0)]
# Utility [('Location', 1, 0)]
# MBath [('Location', 1, 0)]
# Living Room [('Room', 1.0)]
# Bedroom2 [('Room', 1.0)]
# Multiple [('Location', 1, 0)]
# MBedroom [('Room', 1.0)]
# Bedroom 2 [('Room', 1.0)]

# %% [markdown]
# ## Analyzing Column Names

# %%
data_labels = metadata['Data Label']
label_desc = metadata['Description']

# %%
data_labels
# Out:
# 0                 DHW_ClothesWasherColdFlow
# 1                  DHW_ClothesWasherHotFlow
# 2                     DHW_DishwasherHotFlow
# 3                       DHW_SHWGlycolTempIn
# 4                      DHW_SHWGlycolTempOut
# 5        DHW_HeatPumpWaterHeaterEnergyTotal
# 6         DHW_HeatPumpWaterHeaterPowerTotal
# 7                      DHW_ManifoldColdFlow
# 8                       DHW_ManifoldHotFlow
# 9                      DHW_MixValveColdFlow
# 10                 DHW_RoomTempBasementHPWH
# 11            DHW_SHWPumpsEnergywithStandby
# 12             DHW_SHWPumpsPowerwithStandby
# 13             DHW_StatusSolenoidColdMBATub
# 14          DHW_StatusSolenoidColdMBAShower
# 15        DHW_StatusSolenoidColdKitchenSink
# 16         DHW_StatusSolenoidHotKitchenSink
# 17              DHW_StatusSolenoidHotMBATub
# 18           DHW_StatusSolenoidHotMBAShower
# 19               DHW_WaterTempBAShowerMixed
# 20                   DHW_WaterTempBAShwCold
# 21                    DHW_WaterTempBAShwHot
# 22                  DHW_WaterTempBASinkCold
# 23                   DHW_WaterTempBASinkHot
# 24                 DHW_WaterTempBASinkMixed
# 25                  DHW_WaterTempDishwasher
# 26                      DHW_WaterTempHPWHIn
# 27                     DHW_WaterTempHPWHOut
# 28                   DHW_WaterTempKSinkCold
# 29                    DHW_WaterTempKSinkHot
# 30                    DHW_WaterTempKSinkMix
# 31              DHW_WaterTempManifoldColdIn
# 32               DHW_WaterTempManifoldHotIn
# 33                  DHW_WaterTempMBAShwCold
# 34                   DHW_WaterTempMBAShwHot
# 35                   DHW_WaterTempMBAShwMix
# 36               DHW_WaterTempMBASinkRMixed
# 37                DHW_WaterTempMBASinkRCold
# 38                 DHW_WaterTempMBASinkRHot
# 39                  DHW_WaterTempMBATubCold
# 40                   DHW_WaterTempMBATubHot
# 41                   DHW_WaterTempMBATubMix
# 42              DHW_WaterTempMixValveColdIn
# 43               DHW_WaterTempMixValveHotIn
# 44                DHW_WaterTempSHWHX80galIn
# 45               DHW_WaterTempSHWHX80galOut
# 46              DHW_WaterTempSHWTank80galIn
# 47             DHW_WaterTempSHWTank80galOut
# 48                  DHW_WaterTempWasherCold
# 49                   DHW_WaterTempWasherHot
# 50                Elec_EnergyHeatPumpWH1of2
# 51                Elec_EnergyHeatPumpWH2of2
# 52                 Elec_PowerHeatPumpWH1of2
# 53                 Elec_PowerHeatPumpWH2of2
# 54        Elec_EnergyPlugsBaseAHeliodyneHXs
# 55                       Elec_EnergyPlugsDR
# 56                      Elec_EnergyPlugsBR4
# 57                Elec_EnergyPlugsEntryHall
# 58                       Elec_EnergyPlugsLR
# 59                 Elec_EnergyClothesWasher
# 60                     Elec_EnergyDryer1of2
# 61                     Elec_EnergyDryer2of2
# 62                    Elec_EnergyPlugsBaseB
# 63                    Elec_EnergyPlugsBaseC
# 64                      Elec_EnergySumpPump
# 65                        Elec_EnergySpare1
# 66                      Elec_EnergyPlugsBA1
# 67               Elec_EnergyGarbageDisposal
# 68                 Elec_EnergyPlugsKitRange
# 69             Elec_EnergyPlugsKitPeninsula
# 70                     Elec_EnergyMicrowave
# 71                 Elec_EnergyPlugs2ndFloor
# 72                        Elec_EnergySpare2
# 73                      Elec_EnergyPlugsBR2
# 74                      Elec_EnergyPlugsMBR
# 75                  Elec_EnergyPlugsMBAEast
# 76                    Elec_EnergyDishwasher
# 77                 Elec_EnergyPlugsBA2South
# 78                  Elec_EnergyPlugsMBAWest
# 79                 Elec_EnergyPlugsBA2North
# 80                      Elec_EnergyPlugsBR3
# 81                  Elec_EnergyRefrigerator
# 82                  Elec_EnergyPlugsKitSink
# 83                      Elec_EnergyPlugsDRB
# 84                    Elec_EnergyPlugsAttic
# 85                        Elec_PowerPlugsDR
# 86                       Elec_PowerPlugsBR4
# 87                 Elec_PowerPlugsEntryHall
# 88                        Elec_PowerPlugsLR
# 89                  Elec_PowerClothesWasher
# 90                      Elec_PowerDryer1of2
# 91                      Elec_PowerDryer2of2
# 92                     Elec_PowerPlugsBaseB
# 93                     Elec_PowerPlugsBaseC
# 94                       Elec_PowerSumpPump
# 95                         Elec_PowerSpare1
# 96                       Elec_PowerPlugsBA1
# 97                Elec_PowerGarbageDisposal
# 98                  Elec_PowerPlugsKitRange
# 99              Elec_PowerPlugsKitPeninsula
# 100                     Elec_PowerMicrowave
# 101                 Elec_PowerPlugs2ndFloor
# 102                        Elec_PowerSpare2
# 103                      Elec_PowerPlugsBR2
# 104                      Elec_PowerPlugsMBR
# 105                  Elec_PowerPlugsMBAEast
# 106                    Elec_PowerDishwasher
# 107                 Elec_PowerPlugsBA2South
# 108                  Elec_PowerPlugsMBAWest
# 109                 Elec_PowerPlugsBA2North
# 110                      Elec_PowerPlugsBR3
# 111                  Elec_PowerRefrigerator
# 112                  Elec_PowerPlugsKitSink
# 113                      Elec_PowerPlugsDRB
# 114                    Elec_PowerPlugsAttic
# 115                          Elec_EnergyHRV
# 116                           Elec_PowerHRV
# 117                HVAC_DehumidifierAirflow
# 118            HVAC_DehumidifierExitAirTemp
# 119           HVAC_DehumidifierInletAirTemp
# 120                  HVAC_DehumidifierPower
# 121            HVAC_HeatPumpIndoorUnitPower
# 122           HVAC_HeatPumpOutdoorUnitPower
# 123              HVAC_HVACDewpointReturnAir
# 124              HVAC_HVACDewpointSupplyAir
# 125                  HVAC_HVACTempReturnAir
# 126                  HVAC_HVACTempSupplyAir
# 127                       IndEnv_BasementRH
# 128                       IndEnv_Bedroom2RH
# 129                       IndEnv_Bedroom3RH
# 130                        IndEnv_KitchenRH
# 131                       IndEnv_LivingRmRH
# 132                      IndEnv_MastBedRmRH
# 133                            IndEnv_MBARH
# 134                   IndEnv_RadiantTempBR2
# 135                   IndEnv_RadiantTempBR3
# 136               IndEnv_RadiantTempKitchen
# 137                    IndEnv_RadiantTempLR
# 138                   IndEnv_RadiantTempMBR
# 139                  IndEnv_RoomTempAtticNE
# 140                  IndEnv_RoomTempAtticNW
# 141                  IndEnv_RoomTempAtticSE
# 142                  IndEnv_RoomTempAtticSW
# 143                  IndEnv_RoomTempBA1Temp
# 144                  IndEnv_RoomTempBA2Temp
# 145               IndEnv_RoomTempBasementNE
# 146               IndEnv_RoomTempBasementNW
# 147               IndEnv_RoomTempBasementSE
# 148               IndEnv_RoomTempBasementSW
# 149                  IndEnv_RoomTempBR2Temp
# 150                  IndEnv_RoomTempBR3Temp
# 151                  IndEnv_RoomTempBR4Temp
# 152                   IndEnv_RoomTempDRTemp
# 153             IndEnv_RoomTempHallLowerMid
# 154               IndEnv_RoomTempHallLowest
# 155               IndEnv_RoomTempHallMiddle
# 156                IndEnv_RoomTempHallUpper
# 157             IndEnv_RoomTempHallUpperMid
# 158              IndEnv_RoomTempKitchenTemp
# 159                   IndEnv_RoomTempLRTemp
# 160                  IndEnv_RoomTempMBATemp
# 161                  IndEnv_RoomTempMBRTemp
# 162                   IndEnv_RoomTempWDTemp
# 163                Elec_EnergyPlugsInstBR4A
# 164                Elec_EnergyPlugsInstBR4B
# 165                 Elec_EnergyPlugsInstLRA
# 166                 Elec_EnergyPlugsInstLRB
# 167                 Elec_EnergyPlugsInstBA2
# 168                Elec_EnergyPlugsInstMBAB
# 169     Elec_EnergyPlugsGSHPInstrumentation
# 170                Elec_EnergyPlugsInstMBRA
# 171             Elec_EnergyPlugsInstBR2Hall
# 172                Elec_EnergyPlugsInstHall
# 173     Elec_EnergyLightingControlPanelRPS1
# 174                 Elec_EnergyPlugsInstBR3
# 175      Elec_EnergyHeatLoadforRefrigerator
# 176            Elec_EnergyPlugsInstMudroomA
# 177     Elec_EnergyLightingControlPanelRPS2
# 178     Elec_EnergyPlugsHVACInstrumentation
# 179                Elec_EnergyPlugsInstKitD
# 180                 Elec_EnergyPlugsInstBA1
# 181                Elec_EnergyPlugsInstKitA
# 182            Elec_EnergyPlugsInstMudroomB
# 183                 Elec_EnergyPlugsInstDRA
# 184                 Elec_PowerPlugsInstBR4A
# 185                 Elec_PowerPlugsInstBR4B
# 186                  Elec_PowerPlugsInstLRA
# 187                  Elec_PowerPlugsInstLRB
# 188                  Elec_PowerPlugsInstBA2
# 189                 Elec_PowerPlugsInstMBAB
# 190      Elec_PowerPlugsGSHPInstrumentation
# 191                 Elec_PowerPlugsInstMBRA
# 192              Elec_PowerPlugsInstBR2Hall
# 193                 Elec_PowerPlugsInstHall
# 194      Elec_PowerLightingControlPanelRPS1
# 195                  Elec_PowerPlugsInstBR3
# 196       Elec_PowerHeatLoadforRefrigerator
# 197             Elec_PowerPlugsInstMudroomA
# 198      Elec_PowerLightingControlPanelRPS2
# 199      Elec_PowerPlugsHVACInstrumentation
# 200                 Elec_PowerPlugsInstKitD
# 201                  Elec_PowerPlugsInstBA1
# 202                 Elec_PowerPlugsInstKitA
# 203             Elec_PowerPlugsInstMudroomB
# 204                  Elec_PowerPlugsInstDRA
# 205          Elec_EnergyLightsBasementStair
# 206               Elec_EnergyLights2ndFloor
# 207              Elec_EnergyLights1stFloorA
# 208              Elec_EnergyLights1stFloorB
# 209               Elec_EnergyLightsBasement
# 210                  Elec_EnergyLightsAttic
# 211           Elec_PowerLightsBasementStair
# 212                Elec_PowerLights2ndFloor
# 213               Elec_PowerLights1stFloorA
# 214               Elec_PowerLights1stFloorB
# 215                Elec_PowerLightsBasement
# 216                   Elec_PowerLightsAttic
# 217             Elec_EnergyChildBDownstairs
# 218             Elec_EnergyChildADownstairs
# 219              Elec_EnergyParentAUpstairs
# 220               Elec_EnergyChildAUpstairs
# 221               Elec_EnergyChildBUpstairs
# 222              Elec_EnergyParentBUpstairs
# 223            Elec_EnergyParentBDownstairs
# 224            Elec_EnergyParentADownstairs
# 225              Elec_PowerChildBDownstairs
# 226              Elec_PowerChildADownstairs
# 227               Elec_PowerParentAUpstairs
# 228                Elec_PowerChildAUpstairs
# 229                Elec_PowerChildBUpstairs
# 230               Elec_PowerParentBUpstairs
# 231             Elec_PowerParentBDownstairs
# 232             Elec_PowerParentADownstairs
# 233          Load_1stFloorLightsEnergyUsage
# 234           Load_1stFloorLightsPowerUsage
# 235        Load_1stFloorSensHeatEnergyUsage
# 236         Load_1stFloorSensHeatPowerUsage
# 237          Load_2ndFloorLightsEnergyUsage
# 238           Load_2ndFloorLightsPowerUsage
# 239        Load_2ndFloorSensHeatEnergyUsage
# 240         Load_2ndFloorSensHeatPowerUsage
# 241       Load_BasementPlugLoadsEnergyUsage
# 242        Load_BasementPlugLoadsPowerUsage
# 243            Load_BR2PlugLoadsEnergyUsage
# 244             Load_BR2PlugLoadsPowerUsage
# 245            Load_BR3PlugLoadsEnergyUsage
# 246             Load_BR3PlugLoadsPowerUsage
# 247            Load_BR4PlugLoadsEnergyUsage
# 248             Load_BR4PlugLoadsPowerUsage
# 249     Load_ClothesWasherEnergywithStandby
# 250      Load_ClothesWasherPowerWithStandby
# 251                   Load_DryerEnergyTotal
# 252                    Load_DryerPowerTotal
# 253                   Load_RefrigeratorTemp
# 254              Load_KPlugLoadsEnergyUsage
# 255               Load_KPlugLoadsPowerUsage
# 256              Load_LatentHeatEnergyUsage
# 257               Load_LatentHeatPowerUsage
# 258              Load_LatentHeatWaterVolume
# 259             Load_LRPlugLoadsEnergyUsage
# 260              Load_LRPlugLoadsPowerUsage
# 261            Load_MBRPlugLoadsEnergyUsage
# 262             Load_MBRPlugLoadsPowerUsage
# 263         Load_MicrowaveEnergywithStandby
# 264          Load_MicrowavePowerWithStandby
# 265                    Load_OvenEnergyTotal
# 266                     Load_OvenPowerTotal
# 267      Load_RefrigeratorEnergywithStandby
# 268       Load_RefrigeratorPowerWithStandby
# 269             Load_StatusApplianceCooktop
# 270          Load_StatusApplianceDishwasher
# 271                Load_StatusApplianceOven
# 272           Load_StatusApplianceRangeHood
# 273                   Load_StatusLatentload
# 274              Load_StatusPlugLoadBlender
# 275            Load_StatusPlugLoadBR2Laptop
# 276            Load_StatusPlugLoadBR3Laptop
# 277            Load_StatusPlugLoadCanOpener
# 278          Load_StatusPlugLoadCoffeeMaker
# 279     Load_StatusPlugLoadDesktopPCMonitor
# 280                  Load_StatusPlugLoadFan
# 281    Load_StatusPlugLoadHairDryerCurlIron
# 282            Load_StatusPlugLoadHandMixer
# 283           Load_StatusPlugLoadHeatingPad
# 284                 Load_StatusPlugLoadIron
# 285            Load_StatusPlugLoadLRBlueRay
# 286                 Load_StatusPlugLoadLRTV
# 287           Load_StatusPlugLoadMBRBlueRay
# 288                Load_StatusPlugLoadMBRTV
# 289           Load_StatusPlugLoadSlowCooker
# 290              Load_StatusPlugLoadToaster
# 291          Load_StatusPlugLoadToasterOven
# 292               Load_StatusPlugLoadVacuum
# 293            Load_StatusPlugLoadVideoGame
# 294                    Load_StatusBR4Lights
# 295                    Load_StatusMBALights
# 296                   Load_StatusMBRLights1
# 297                   Load_StatusMBRLights2
# 298                    Load_StatusBA2Lights
# 299                    Load_StatusBR2Lights
# 300                    Load_StatusBA1Lights
# 301                    Load_StatusBR3Lights
# 302            Load_StatusSensHeatPrntBDOWN
# 303              Load_StatusSensHeatPrntAUP
# 304               Load_StatusKitchenLightsA
# 305              Load_StatusSensHeatPrntBUP
# 306             Load_StatusSensHeatChildAUP
# 307             Load_StatusSensHeatChildBUP
# 308              Load_StatusKitchen LightsB
# 309           Load_StatusSensHeatChildBDOWN
# 310                    Load_StatusLRLights1
# 311            Load_StatusSensHeatPrntADOWN
# 312           Load_StatusSensHeatChildADOWN
# 313               Load_StatusKitchenLightsC
# 314                    Load_StatusLRLights2
# 315                     Load_StatusDRLights
# 316                    Load_StatusLRLights3
# 317              Load_StatusEntryHallLights
# 318                   OutEnv_OutdoorAmbTemp
# 319             OutEnv_RooftopWindDirection
# 320                 OutEnv_RooftopWindSpeed
# 321                       Elec_EnergyPV1of2
# 322                       Elec_EnergyPV2of2
# 323                        Elec_PowerPV1of2
# 324                        Elec_PowerPV2of2
# 325                             PV_AmpsAIA1
# 326                             PV_AmpsAIA2
# 327                             PV_AmpsBIB1
# 328                             PV_AmpsBIB2
# 329                          PV_FrequencyF1
# 330                          PV_FrequencyF2
# 331           PV_PowerFactor3PhTotalPF3PhT1
# 332           PV_PowerFactor3PhTotalPF3PhT2
# 333                      PV_PVBacksideTemp2
# 334                      PV_PVBacksideTemp3
# 335                      PV_PVBacksideTemp4
# 336                      PV_PVBacksideTemp7
# 337                   PV_PVInsolationHArray
# 338          PV_PVSystem1ACEnergyOSEACPV1OS
# 339           PV_PVSystem1ACPowerOSPACPV1OS
# 340          PV_PVSystem2ACEnergyOSEACPV2OS
# 341           PV_PVSystem2ACPowerOSPACPV2OS
# 342                   PV_StringCurrentIStr1
# 343                   PV_StringCurrentIStr2
# 344                   PV_StringCurrentIStr3
# 345                   PV_StringCurrentIStr4
# 346                   PV_StringVoltageUStr2
# 347                   PV_StringVoltageUStr4
# 348                          PV_VoltsANUAN1
# 349                          PV_VoltsANUAN2
# 350                          PV_VoltsBNUBN1
# 351                          PV_VoltsBNUBN2
# 352                  PV_Watts3PhTotalW3PhT1
# 353                  PV_Watts3PhTotalW3PhT2
# 354                  PV_WhoursDeliveredWhD1
# 355                  PV_WhoursDeliveredWhD2
# 356        Elec_PowerPlugsBaseAHeliodyneHXs
# 357             SHW_GlycolFlowHXCoriolisSHW
# 358         SHW_GlycolFlowRateHXCoriolisSHW
# 359          SHW_GlycolTempSHWPanel80galOut
# 360                              SHW_PSPSHW
# 361                 SHW_SHWHX80galWaterFlow
# 362              SHW_WaterFlowHXCoriolisSHW
# 363          SHW_WaterFlowRateHXCoriolisSHW
# 364              Elec_EnergyMakeUpAirDamper
# 365               Elec_PowerMakeUpAirDamper
# 366      Vent_HRVDewpointTemperatureExhaust
# 367      Vent_HRVDewpointTemperatureOutdoor
# 368       Vent_HRVDewpointTemperatureReturn
# 369       Vent_HRVDewpointTemperatureSupply
# 370                 Vent_HRVexhaustflowrate
# 371    Vent_HRVfreshairpressuredifferential
# 372                 Vent_HRVoutdoorflowrate
# 373                  Vent_HRVreturnflowrate
# 374    Vent_HRVstaleairpressuredifferential
# 375                  Vent_HRVTempExhaustOut
# 376                   Vent_HRVTempOutdoorin
# 377                    Vent_HRVTempReturnIn
# 378                   Vent_HRVTempSupplyOut
# Name: Data Label, dtype: object

# %%
import re
def parse_colname(term):
    parsed = re.sub('[^a-zA-Z0-9\n\.]', ' ', term)
    return parsed

def parse_label(label):
    terms = []
    parsed = par
    se_colname(label.replace("_",""))
    parsed =re.sub(r"(?<=\w)([A-Z])", r" \1", parsed)
    tmp=""
    for item in parsed.split(" "):
        if len(item)>1:
            terms.append(item)
            if tmp!="":
                terms.append(tmp)
                tmp=""
        else:
            tmp +=item
    if tmp!="":
        terms.append(tmp)
        tmp=""
    return ' '.join(terms)

# %%
def frequency_parse(data_labels):
    freq = {}
    terms = []
    for label in data_labels:
        parsed = parse_colname(label)
        parsed =re.sub(r"(?<=\w)([A-Z])", r" \1", parsed)
        tmp=""
        for item in parsed.split(" "):
            if len(item)>1:
                terms.append(item)
                if tmp!="":
                    terms.append(tmp)
                    tmp=""
            else:
                tmp +=item
        if tmp!="":
            terms.append(tmp)
            tmp=""
    
    for label in terms:
        try:
            freq[label]+=1
        except:
            freq[label]=1
    return freq

# %%
freq = frequency_parse(data_labels)

# %%
search("HVAC System")

# %%
freq_result = dict(sorted(freq.items(), key=lambda item: item[1], reverse=True))
rank = 1
for key in freq_result.keys():
    tmp = search(key)
    if tmp[0][1]==0:
        print(key, "not found")
    else:
        print(key, freq_result[key], tmp)

# %%
for i in range(0,len(data_labels)):
    query = parse_label(data_labels[i])+" "+label_desc[i]
    print(data_labels[i], search(query,topk=3))
