# %%
import pandas as pd
import numpy
import re

# %%
df = pd.read_csv('NIST_meta.csv')

# %%
def fix_location_name(location):
    fixed = location.replace(" ","_")
    if location=="Bath1":
        fixed = "Bathroom_1"
    elif location=="Bath2":
        fixed = "Bathroom_2"
    elif location=="MBath":
        fixed = "Master_Bathroom"
    elif location=="Bedroom2":
        fixed = "Bedroom_2"
    elif location=="Bedroom3":
        fixed = "Bedroom_3"
    elif location=="Bedroom4":
        fixed = "Bedroom_4"
    elif location=="MBedroom":
        fixed = "Master_Bedroom"
    return fixed

# %%
df.head(10)
# Out:
#                            Data Label Subsystem Measurement Location  \
# 0           DHW_ClothesWasherColdFlow       DHW              Utility
# 1            DHW_ClothesWasherHotFlow       DHW              Utility
# 2               DHW_DishwasherHotFlow       DHW              Kitchen
# 3                 DHW_SHWGlycolTempIn       DHW             Basement
# 4                DHW_SHWGlycolTempOut       DHW             Basement
# 5  DHW_HeatPumpWaterHeaterEnergyTotal       DHW             Basement
# 6   DHW_HeatPumpWaterHeaterPowerTotal       DHW             Basement
# 7                DHW_ManifoldColdFlow       DHW             Basement
# 8                 DHW_ManifoldHotFlow       DHW             Basement
# 9                DHW_MixValveColdFlow       DHW             Basement
#
#   Measured Parameter                                        Description  \
# 0         Flow_Water  The cumulative volume of cold water flowing in...
# 1         Flow_Water  The cumulative volume of hot water flowing int...
# 2         Flow_Water  The cumulative volume of hot water flowing int...
# 3        Temp_Glycol  The instantaneous temperature of the glycol-wa...
# 4        Temp_Glycol  The instantaneous temperature of the glycol-wa...
# 5  Energy_Electrical  Cumulative energy consumption by heat pump wat...
# 6   Power_Electrical  Instantaneous power consumption by heat pump w...
# 7         Flow_Water  The cumulative volume of water flowing into th...
# 8         Flow_Water  The cumulative volume of water flowing into th...
# 9         Flow_Water  The cumulative volume of mains water flowing i...
#
#      Units
# 0  Gallons
# 1  Gallons
# 2  Gallons
# 3       °C
# 4       °C
# 5       Wh
# 6        W
# 7  Gallons
# 8  Gallons
# 9  Gallons

# %%
header = """@prefix bldg: <https://pages.nist.gov/netzero/data.html#data_dictionary#> .
@prefix brick: <https://brickschema.org/schema/1.1/Brick#> . 
@prefix btag: <https://brickschema.org/schema/1.0.2/BrickTag#> .
@prefix gtc: <https://brickschema.org/schema/1.0.2/building_example#> .
@prefix owl: <http://www.w3.org/2002/07/owl#> .
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix tag: <https://brickschema.org/schema/1.1/BrickTag#> .
@prefix xml: <http://www.w3.org/XML/1998/namespace> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .

bldg:Hot_Water_Supply_Zone a brick:Location .
bldg:Thermal_Zone a brick:Location .
bldg:Living_Room a brick:Location .
bldg:Dining_Room a brick:Location .
bldg:Attic a brick:Location .
bldg:Kitchen a brick:Location .
bldg:Utility a brick:Location .
bldg:Entry_Hallway a brick:Location .
bldg:Master_Bedroom a brick:Location .
bldg:Bedroom_2 a brick:Location .
bldg:Bedroom_3 a brick:Location .
bldg:Bedroom_4 a brick:Location .
bldg:Mudroom a brick:Location .
bldg:Multiple a brick:Location .
bldg:Outdoor a brick:Location .
bldg:Master_Bathroom a brick:Location .
bldg:Bathroom_1 a brick:Location .
bldg:Bathroom_2 a brick:Location .
bldg:First_Floor a brick:Location .
bldg:Second_Floor a brick:Location .
bldg:Basement a brick:Location .
bldg:Lighting_Zone a brick:Location .
bldg:Lighting_Zone brick:hasPart bldg:Attic.
bldg:Lighting_Zone brick:hasPart bldg:Basement.
bldg:Lighting_Zone brick:hasPart bldg:First_Floor.
bldg:Lighting_Zone brick:hasPart bldg:Second_Floor.
bldg:First_Floor brick:hasPart bldg:Living_Room.
bldg:First_Floor brick:hasPart bldg:Entry_Hallway.
bldg:First_Floor brick:hasPart bldg:Bathroom_1.
bldg:First_Floor brick:hasPart bldg:Bedroom_4.
bldg:First_Floor brick:hasPart bldg:Dining_Room.
bldg:First_Floor brick:hasPart bldg:Kitchen.
bldg:First_Floor brick:hasPart bldg:Mudroom.
bldg:First_Floor brick:hasPart bldg:Utility.
bldg:Second_Floor brick:hasPart bldg:Bathroom_2.
bldg:Second_Floor brick:hasPart bldg:Bedroom_2.
bldg:Second_Floor brick:hasPart bldg:Bedroom_3.
bldg:Second_Floor brick:hasPart bldg:Master_Bedroom.
bldg:Second_Floor brick:hasPart bldg:Master_Bethroom.

bldg:AHU01 a brick:AHU ;

"""

# %%
def get_tail(room, df, ahu):
    tail = ahu +""" brick:feeds bldg:"""+fix_location_name(room)+""" . \n"""

    for index, row in df.iterrows():
        row_data_label = str(row['Data Label']).strip()
        row_measurement_location = str(row['Measurement Location']).strip()
        if row_measurement_location==room:
            parsed_row_data_label = row_data_label.split("_")
            sub_system = parsed_row_data_label[0]
            data_label = parsed_row_data_label[1]
            tail+=ahu+" brick:hasPoint bldg:"+data_label.replace(" ","")+" .\n"
    return tail[:-2]+"."

def parse():
    body = "\n"
    tail = "\n"
    
    for index, row in df.iterrows():
        row_data_label = str(row['Data Label']).strip()
        row_measurement_location = str(row['Measurement Location']).strip()
        
        #if row_measurement_location=="Living Room" or row_measurement_location=="Basement":
        if True:
            parsed_row_data_label = row_data_label.split("_")
            sub_system = parsed_row_data_label[0]
            data_label = parsed_row_data_label[1]
            body+="bldg:"+fix_location_name(row_measurement_location)+" brick:hasPoint "+"bldg:"+data_label.replace(" ","")+" .\n"
            if "DewpointSupplyAir" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Supply_Air_Dewpoint_Sensor .\n"
            elif "DewpointReturnAir" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Return_Air_Dewpoint_Sensor .\n"
            elif "Air" in data_label and "Temp" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Air_Temperature_Sensor .\n"
            elif "ColdFlow" in data_label or "HotFlow" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Water_Usage_Sensor .\n"
            elif "Flow" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Flow_Sensor .\n"
            elif "flowrate" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Air_Flow_Sensor .\n"
            elif "Airflow" in data_label:
                body+="bldg:"+data_label+ " a brick:Air_Flow_Sensor .\n"
            elif "EnergyTotal" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Energy_Usage_Sensor .\n"
            elif "EnergyPlugs" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Energy_Usage_Sensor .\n"
            elif "Energy" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Energy_Usage_Sensor .\n"
            elif "EnergywithStandby" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Energy_Usage_Sensor .\n"
            elif "PowerwithStandby" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Electrical_Power_Sensor .\n"
            elif "PowerTotal" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Energy_Usage_Sensor .\n"
            elif "Power" in data_label and "Plug" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Power_Sensor .\n"
            elif "Power" in data_label and "Plug" not in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Thermal_Power_Sensor .\n"
            elif "Status" in data_label in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:On_Off_Status .\n"
            elif "RH" in data_label in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Relative_Humidity_Sensor .\n"
            elif "RadiantTemp" in data_label in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Air_Temperature_Sensor .\n"
            elif "RoomTempBasementHPWH" in data_label in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Temperature_Sensor .\n"
            elif "RoomTemp" in data_label in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Zone_Air_Temperature_Sensor .\n"
            elif "WaterTemp" in data_label in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Water_Temperature_Sensor .\n"
            elif "Dewpoint" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Dewpoint_Sensor .\n"
            elif "pressuredifferential" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Differential_Pressure_Sensor .\n"
            elif "Temp" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Temperature_Sensor .\n"
            elif "WaterVolume" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Water_Level_Sensor .\n"
            elif "WindDirection" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Wind_Direction_Sensor .\n"
            elif "WindSpeed" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Wind_Speed_Sensor .\n"
            elif "Amps" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Current_Sensor .\n"
            elif "StringCurrent" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Current_Sensor .\n"
            elif "Frequency" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Frequency_Sensor .\n"
            elif "PVInsolation" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Solar_Radiance_Sensor .\n"
            elif "Frequency" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Frequency_Sensor .\n"
            elif "Voltage" in data_label or "Volts" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Voltage_Sensor .\n"
            elif "Watts" in data_label and "Total" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Power_Sensor .\n"
            elif "WhoursDelivered" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Energy_Usage_Sensor .\n"
            elif "PSPSHW" in data_label:
                body+="bldg:"+data_label.replace(" ","")+ " a brick:Solar_Radiance_Sensor .\n"
            else:
                print(" not found: ", data_label)
    
    ahu = "bldg:AHU01"
    tail = ahu + """ a brick:AHU ;\n"""
    tail += get_tail("Living Room", df, ahu)
    tail += "\n"+get_tail("Basement", df, ahu)
    tail += "\n"+get_tail("Kitchen", df, ahu)
    tail += "\n"+get_tail("Dining Room", df, ahu)
    tail += "\n"+get_tail("Utility", df, ahu)
    tail += "\n"+get_tail("Entry Hallway", df, ahu)
    tail += "\n"+get_tail("MBedroom", df, ahu)
    tail += "\n"+get_tail("Bedroom2", df, ahu)
    tail += "\n"+get_tail("Bedroom3", df, ahu)
    tail += "\n"+get_tail("Bedroom4", df, ahu)
    tail += "\n"+get_tail("Mudroom", df, ahu)
    tail += "\n"+get_tail("Multiple", df, ahu)
    tail += "\n"+get_tail("Outdoor", df, ahu)
    tail += "\n"+get_tail("MBath", df, ahu)
    tail += "\n"+get_tail("Bath1", df, ahu)
    tail += "\n"+get_tail("Bath2", df, ahu)

    return body,tail

# %%
body,tail = parse()
print()
print(header+"\n"+body+"\n"+tail)
# Out:
# @prefix bldg: <https://pages.nist.gov/netzero/data.html#data_dictionary#> .
# @prefix brick: <https://brickschema.org/schema/1.1/Brick#> .
# @prefix btag: <https://brickschema.org/schema/1.0.2/BrickTag#> .
# @prefix gtc: <https://brickschema.org/schema/1.0.2/building_example#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix tag: <https://brickschema.org/schema/1.1/BrickTag#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# bldg:Hot_Water_Supply_Zone a brick:Location .
# bldg:Thermal_Zone a brick:Location .
# bldg:Living_Room a brick:Location .
# bldg:Dining_Room a brick:Location .
# bldg:Attic a brick:Location .
# bldg:Kitchen a brick:Location .
# bldg:Utility a brick:Location .
# bldg:Entry_Hallway a brick:Location .
# bldg:Master_Bedroom a brick:Location .
# bldg:Bedroom_2 a brick:Location .
# bldg:Bedroom_3 a brick:Location .
# bldg:Bedroom_4 a brick:Location .
# bldg:Mudroom a brick:Location .
# bldg:Multiple a brick:Location .
# bldg:Outdoor a brick:Location .
# bldg:Master_Bathroom a brick:Location .
# bldg:Bathroom_1 a brick:Location .
# bldg:Bathroom_2 a brick:Location .
# bldg:First_Floor a brick:Location .
# bldg:Second_Floor a brick:Location .
# bldg:Basement a brick:Location .
# bldg:Lighting_Zone a brick:Location .
# bldg:Lighting_Zone brick:hasPart bldg:Attic.
# bldg:Lighting_Zone brick:hasPart bldg:Basement.
# bldg:Lighting_Zone brick:hasPart bldg:First_Floor.
# bldg:Lighting_Zone brick:hasPart bldg:Second_Floor.
# bldg:First_Floor brick:hasPart bldg:Living_Room.
# bldg:First_Floor brick:hasPart bldg:Entry_Hallway.
# bldg:First_Floor brick:hasPart bldg:Bathroom_1.
# bldg:First_Floor brick:hasPart bldg:Bedroom_4.
# bldg:First_Floor brick:hasPart bldg:Dining_Room.
# bldg:First_Floor brick:hasPart bldg:Kitchen.
# bldg:First_Floor brick:hasPart bldg:Mudroom.
# bldg:First_Floor brick:hasPart bldg:Utility.
# bldg:Second_Floor brick:hasPart bldg:Bathroom_2.
# bldg:Second_Floor brick:hasPart bldg:Bedroom_2.
# bldg:Second_Floor brick:hasPart bldg:Bedroom_3.
# bldg:Second_Floor brick:hasPart bldg:Master_Bedroom.
# bldg:Second_Floor brick:hasPart bldg:Master_Bethroom.
#
# bldg:AHU01 a brick:AHU ;
#
#
#
# bldg:Utility brick:hasPoint bldg:ClothesWasherColdFlow .
# bldg:ClothesWasherColdFlow a brick:Water_Usage_Sensor .
# bldg:Utility brick:hasPoint bldg:ClothesWasherHotFlow .
# bldg:ClothesWasherHotFlow a brick:Water_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:DishwasherHotFlow .
# bldg:DishwasherHotFlow a brick:Water_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:SHWGlycolTempIn .
# bldg:SHWGlycolTempIn a brick:Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:SHWGlycolTempOut .
# bldg:SHWGlycolTempOut a brick:Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:HeatPumpWaterHeaterEnergyTotal .
# bldg:HeatPumpWaterHeaterEnergyTotal a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:HeatPumpWaterHeaterPowerTotal .
# bldg:HeatPumpWaterHeaterPowerTotal a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:ManifoldColdFlow .
# bldg:ManifoldColdFlow a brick:Water_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:ManifoldHotFlow .
# bldg:ManifoldHotFlow a brick:Water_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:MixValveColdFlow .
# bldg:MixValveColdFlow a brick:Water_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:RoomTempBasementHPWH .
# bldg:RoomTempBasementHPWH a brick:Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:SHWPumpsEnergywithStandby .
# bldg:SHWPumpsEnergywithStandby a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:SHWPumpsPowerwithStandby .
# bldg:SHWPumpsPowerwithStandby a brick:Electrical_Power_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:StatusSolenoidColdMBATub .
# bldg:StatusSolenoidColdMBATub a brick:On_Off_Status .
# bldg:Master_Bathroom brick:hasPoint bldg:StatusSolenoidColdMBAShower .
# bldg:StatusSolenoidColdMBAShower a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusSolenoidColdKitchenSink .
# bldg:StatusSolenoidColdKitchenSink a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusSolenoidHotKitchenSink .
# bldg:StatusSolenoidHotKitchenSink a brick:On_Off_Status .
# bldg:Master_Bathroom brick:hasPoint bldg:StatusSolenoidHotMBATub .
# bldg:StatusSolenoidHotMBATub a brick:On_Off_Status .
# bldg:Master_Bathroom brick:hasPoint bldg:StatusSolenoidHotMBAShower .
# bldg:StatusSolenoidHotMBAShower a brick:On_Off_Status .
# bldg:Bathroom_2 brick:hasPoint bldg:WaterTempBAShowerMixed .
# bldg:WaterTempBAShowerMixed a brick:Water_Temperature_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:WaterTempBAShwCold .
# bldg:WaterTempBAShwCold a brick:Water_Temperature_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:WaterTempBAShwHot .
# bldg:WaterTempBAShwHot a brick:Water_Temperature_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:WaterTempBASinkCold .
# bldg:WaterTempBASinkCold a brick:Water_Temperature_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:WaterTempBASinkHot .
# bldg:WaterTempBASinkHot a brick:Water_Temperature_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:WaterTempBASinkMixed .
# bldg:WaterTempBASinkMixed a brick:Water_Temperature_Sensor .
# bldg:Kitchen brick:hasPoint bldg:WaterTempDishwasher .
# bldg:WaterTempDishwasher a brick:Water_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:WaterTempHPWHIn .
# bldg:WaterTempHPWHIn a brick:Water_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:WaterTempHPWHOut .
# bldg:WaterTempHPWHOut a brick:Water_Temperature_Sensor .
# bldg:Kitchen brick:hasPoint bldg:WaterTempKSinkCold .
# bldg:WaterTempKSinkCold a brick:Water_Temperature_Sensor .
# bldg:Kitchen brick:hasPoint bldg:WaterTempKSinkHot .
# bldg:WaterTempKSinkHot a brick:Water_Temperature_Sensor .
# bldg:Kitchen brick:hasPoint bldg:WaterTempKSinkMix .
# bldg:WaterTempKSinkMix a brick:Water_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:WaterTempManifoldColdIn .
# bldg:WaterTempManifoldColdIn a brick:Water_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:WaterTempManifoldHotIn .
# bldg:WaterTempManifoldHotIn a brick:Water_Temperature_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:WaterTempMBAShwCold .
# bldg:WaterTempMBAShwCold a brick:Water_Temperature_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:WaterTempMBAShwHot .
# bldg:WaterTempMBAShwHot a brick:Water_Temperature_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:WaterTempMBAShwMix .
# bldg:WaterTempMBAShwMix a brick:Water_Temperature_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:WaterTempMBASinkRMixed .
# bldg:WaterTempMBASinkRMixed a brick:Water_Temperature_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:WaterTempMBASinkRCold .
# bldg:WaterTempMBASinkRCold a brick:Water_Temperature_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:WaterTempMBASinkRHot .
# bldg:WaterTempMBASinkRHot a brick:Relative_Humidity_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:WaterTempMBATubCold .
# bldg:WaterTempMBATubCold a brick:Water_Temperature_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:WaterTempMBATubHot .
# bldg:WaterTempMBATubHot a brick:Water_Temperature_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:WaterTempMBATubMix .
# bldg:WaterTempMBATubMix a brick:Water_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:WaterTempMixValveColdIn .
# bldg:WaterTempMixValveColdIn a brick:Water_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:WaterTempMixValveHotIn .
# bldg:WaterTempMixValveHotIn a brick:Water_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:WaterTempSHWHX80galIn .
# bldg:WaterTempSHWHX80galIn a brick:Water_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:WaterTempSHWHX80galOut .
# bldg:WaterTempSHWHX80galOut a brick:Water_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:WaterTempSHWTank80galIn .
# bldg:WaterTempSHWTank80galIn a brick:Water_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:WaterTempSHWTank80galOut .
# bldg:WaterTempSHWTank80galOut a brick:Water_Temperature_Sensor .
# bldg:Utility brick:hasPoint bldg:WaterTempWasherCold .
# bldg:WaterTempWasherCold a brick:Water_Temperature_Sensor .
# bldg:Utility brick:hasPoint bldg:WaterTempWasherHot .
# bldg:WaterTempWasherHot a brick:Water_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyHeatPumpWH1of2 .
# bldg:EnergyHeatPumpWH1of2 a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyHeatPumpWH2of2 .
# bldg:EnergyHeatPumpWH2of2 a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerHeatPumpWH1of2 .
# bldg:PowerHeatPumpWH1of2 a brick:Thermal_Power_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerHeatPumpWH2of2 .
# bldg:PowerHeatPumpWH2of2 a brick:Thermal_Power_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyPlugsBaseAHeliodyneHXs .
# bldg:EnergyPlugsBaseAHeliodyneHXs a brick:Energy_Usage_Sensor .
# bldg:Dining_Room brick:hasPoint bldg:EnergyPlugsDR .
# bldg:EnergyPlugsDR a brick:Energy_Usage_Sensor .
# bldg:Bedroom_4 brick:hasPoint bldg:EnergyPlugsBR4 .
# bldg:EnergyPlugsBR4 a brick:Energy_Usage_Sensor .
# bldg:Entry_Hallway brick:hasPoint bldg:EnergyPlugsEntryHall .
# bldg:EnergyPlugsEntryHall a brick:Energy_Usage_Sensor .
# bldg:Living_Room brick:hasPoint bldg:EnergyPlugsLR .
# bldg:EnergyPlugsLR a brick:Energy_Usage_Sensor .
# bldg:Utility brick:hasPoint bldg:EnergyClothesWasher .
# bldg:EnergyClothesWasher a brick:Energy_Usage_Sensor .
# bldg:Utility brick:hasPoint bldg:EnergyDryer1of2 .
# bldg:EnergyDryer1of2 a brick:Energy_Usage_Sensor .
# bldg:Utility brick:hasPoint bldg:EnergyDryer2of2 .
# bldg:EnergyDryer2of2 a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyPlugsBaseB .
# bldg:EnergyPlugsBaseB a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyPlugsBaseC .
# bldg:EnergyPlugsBaseC a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergySumpPump .
# bldg:EnergySumpPump a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergySpare1 .
# bldg:EnergySpare1 a brick:Energy_Usage_Sensor .
# bldg:Bathroom_1 brick:hasPoint bldg:EnergyPlugsBA1 .
# bldg:EnergyPlugsBA1 a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:EnergyGarbageDisposal .
# bldg:EnergyGarbageDisposal a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:EnergyPlugsKitRange .
# bldg:EnergyPlugsKitRange a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:EnergyPlugsKitPeninsula .
# bldg:EnergyPlugsKitPeninsula a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:EnergyMicrowave .
# bldg:EnergyMicrowave a brick:Energy_Usage_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:EnergyPlugs2ndFloor .
# bldg:EnergyPlugs2ndFloor a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergySpare2 .
# bldg:EnergySpare2 a brick:Energy_Usage_Sensor .
# bldg:Bedroom_2 brick:hasPoint bldg:EnergyPlugsBR2 .
# bldg:EnergyPlugsBR2 a brick:Energy_Usage_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:EnergyPlugsMBR .
# bldg:EnergyPlugsMBR a brick:Energy_Usage_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:EnergyPlugsMBAEast .
# bldg:EnergyPlugsMBAEast a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:EnergyDishwasher .
# bldg:EnergyDishwasher a brick:Energy_Usage_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:EnergyPlugsBA2South .
# bldg:EnergyPlugsBA2South a brick:Energy_Usage_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:EnergyPlugsMBAWest .
# bldg:EnergyPlugsMBAWest a brick:Energy_Usage_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:EnergyPlugsBA2North .
# bldg:EnergyPlugsBA2North a brick:Energy_Usage_Sensor .
# bldg:Bedroom_3 brick:hasPoint bldg:EnergyPlugsBR3 .
# bldg:EnergyPlugsBR3 a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:EnergyRefrigerator .
# bldg:EnergyRefrigerator a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:EnergyPlugsKitSink .
# bldg:EnergyPlugsKitSink a brick:Energy_Usage_Sensor .
# bldg:Dining_Room brick:hasPoint bldg:EnergyPlugsDRB .
# bldg:EnergyPlugsDRB a brick:Energy_Usage_Sensor .
# bldg:Attic brick:hasPoint bldg:EnergyPlugsAttic .
# bldg:EnergyPlugsAttic a brick:Energy_Usage_Sensor .
# bldg:Dining_Room brick:hasPoint bldg:PowerPlugsDR .
# bldg:PowerPlugsDR a brick:Power_Sensor .
# bldg:Bedroom_4 brick:hasPoint bldg:PowerPlugsBR4 .
# bldg:PowerPlugsBR4 a brick:Power_Sensor .
# bldg:Entry_Hallway brick:hasPoint bldg:PowerPlugsEntryHall .
# bldg:PowerPlugsEntryHall a brick:Power_Sensor .
# bldg:Living_Room brick:hasPoint bldg:PowerPlugsLR .
# bldg:PowerPlugsLR a brick:Power_Sensor .
# bldg:Utility brick:hasPoint bldg:PowerClothesWasher .
# bldg:PowerClothesWasher a brick:Thermal_Power_Sensor .
# bldg:Utility brick:hasPoint bldg:PowerDryer1of2 .
# bldg:PowerDryer1of2 a brick:Thermal_Power_Sensor .
# bldg:Utility brick:hasPoint bldg:PowerDryer2of2 .
# bldg:PowerDryer2of2 a brick:Thermal_Power_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerPlugsBaseB .
# bldg:PowerPlugsBaseB a brick:Power_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerPlugsBaseC .
# bldg:PowerPlugsBaseC a brick:Power_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerSumpPump .
# bldg:PowerSumpPump a brick:Thermal_Power_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerSpare1 .
# bldg:PowerSpare1 a brick:Thermal_Power_Sensor .
# bldg:Bathroom_1 brick:hasPoint bldg:PowerPlugsBA1 .
# bldg:PowerPlugsBA1 a brick:Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:PowerGarbageDisposal .
# bldg:PowerGarbageDisposal a brick:Thermal_Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:PowerPlugsKitRange .
# bldg:PowerPlugsKitRange a brick:Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:PowerPlugsKitPeninsula .
# bldg:PowerPlugsKitPeninsula a brick:Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:PowerMicrowave .
# bldg:PowerMicrowave a brick:Thermal_Power_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:PowerPlugs2ndFloor .
# bldg:PowerPlugs2ndFloor a brick:Power_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerSpare2 .
# bldg:PowerSpare2 a brick:Thermal_Power_Sensor .
# bldg:Bedroom_2 brick:hasPoint bldg:PowerPlugsBR2 .
# bldg:PowerPlugsBR2 a brick:Power_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:PowerPlugsMBR .
# bldg:PowerPlugsMBR a brick:Power_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:PowerPlugsMBAEast .
# bldg:PowerPlugsMBAEast a brick:Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:PowerDishwasher .
# bldg:PowerDishwasher a brick:Thermal_Power_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:PowerPlugsBA2South .
# bldg:PowerPlugsBA2South a brick:Power_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:PowerPlugsMBAWest .
# bldg:PowerPlugsMBAWest a brick:Power_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:PowerPlugsBA2North .
# bldg:PowerPlugsBA2North a brick:Power_Sensor .
# bldg:Bedroom_3 brick:hasPoint bldg:PowerPlugsBR3 .
# bldg:PowerPlugsBR3 a brick:Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:PowerRefrigerator .
# bldg:PowerRefrigerator a brick:Thermal_Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:PowerPlugsKitSink .
# bldg:PowerPlugsKitSink a brick:Power_Sensor .
# bldg:Dining_Room brick:hasPoint bldg:PowerPlugsDRB .
# bldg:PowerPlugsDRB a brick:Power_Sensor .
# bldg:Attic brick:hasPoint bldg:PowerPlugsAttic .
# bldg:PowerPlugsAttic a brick:Power_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyHRV .
# bldg:EnergyHRV a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerHRV .
# bldg:PowerHRV a brick:Thermal_Power_Sensor .
# bldg:Basement brick:hasPoint bldg:DehumidifierAirflow .
# bldg:DehumidifierAirflow a brick:Air_Flow_Sensor .
# bldg:Basement brick:hasPoint bldg:DehumidifierExitAirTemp .
# bldg:DehumidifierExitAirTemp a brick:Air_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:DehumidifierInletAirTemp .
# bldg:DehumidifierInletAirTemp a brick:Air_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:DehumidifierPower .
# bldg:DehumidifierPower a brick:Thermal_Power_Sensor .
# bldg:Basement brick:hasPoint bldg:HeatPumpIndoorUnitPower .
# bldg:HeatPumpIndoorUnitPower a brick:Thermal_Power_Sensor .
# bldg:Outdoor brick:hasPoint bldg:HeatPumpOutdoorUnitPower .
# bldg:HeatPumpOutdoorUnitPower a brick:Thermal_Power_Sensor .
# bldg:Basement brick:hasPoint bldg:HVACDewpointReturnAir .
# bldg:HVACDewpointReturnAir a brick:Return_Air_Dewpoint_Sensor .
# bldg:Basement brick:hasPoint bldg:HVACDewpointSupplyAir .
# bldg:HVACDewpointSupplyAir a brick:Supply_Air_Dewpoint_Sensor .
# bldg:Basement brick:hasPoint bldg:HVACTempReturnAir .
# bldg:HVACTempReturnAir a brick:Air_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:HVACTempSupplyAir .
# bldg:HVACTempSupplyAir a brick:Air_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:BasementRH .
# bldg:BasementRH a brick:Relative_Humidity_Sensor .
# bldg:Bedroom_2 brick:hasPoint bldg:Bedroom2RH .
# bldg:Bedroom2RH a brick:Relative_Humidity_Sensor .
# bldg:Bedroom_3 brick:hasPoint bldg:Bedroom3RH .
# bldg:Bedroom3RH a brick:Relative_Humidity_Sensor .
# bldg:Kitchen brick:hasPoint bldg:KitchenRH .
# bldg:KitchenRH a brick:Relative_Humidity_Sensor .
# bldg:Living_Room brick:hasPoint bldg:LivingRmRH .
# bldg:LivingRmRH a brick:Relative_Humidity_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:MastBedRmRH .
# bldg:MastBedRmRH a brick:Relative_Humidity_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:MBARH .
# bldg:MBARH a brick:Relative_Humidity_Sensor .
# bldg:Bedroom_2 brick:hasPoint bldg:RadiantTempBR2 .
# bldg:RadiantTempBR2 a brick:Air_Temperature_Sensor .
# bldg:Bedroom_3 brick:hasPoint bldg:RadiantTempBR3 .
# bldg:RadiantTempBR3 a brick:Air_Temperature_Sensor .
# bldg:Kitchen brick:hasPoint bldg:RadiantTempKitchen .
# bldg:RadiantTempKitchen a brick:Air_Temperature_Sensor .
# bldg:Living_Room brick:hasPoint bldg:RadiantTempLR .
# bldg:RadiantTempLR a brick:Air_Temperature_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:RadiantTempMBR .
# bldg:RadiantTempMBR a brick:Air_Temperature_Sensor .
# bldg:Attic brick:hasPoint bldg:RoomTempAtticNE .
# bldg:RoomTempAtticNE a brick:Zone_Air_Temperature_Sensor .
# bldg:Attic brick:hasPoint bldg:RoomTempAtticNW .
# bldg:RoomTempAtticNW a brick:Zone_Air_Temperature_Sensor .
# bldg:Attic brick:hasPoint bldg:RoomTempAtticSE .
# bldg:RoomTempAtticSE a brick:Zone_Air_Temperature_Sensor .
# bldg:Attic brick:hasPoint bldg:RoomTempAtticSW .
# bldg:RoomTempAtticSW a brick:Zone_Air_Temperature_Sensor .
# bldg:Bathroom_1 brick:hasPoint bldg:RoomTempBA1Temp .
# bldg:RoomTempBA1Temp a brick:Zone_Air_Temperature_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:RoomTempBA2Temp .
# bldg:RoomTempBA2Temp a brick:Zone_Air_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:RoomTempBasementNE .
# bldg:RoomTempBasementNE a brick:Zone_Air_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:RoomTempBasementNW .
# bldg:RoomTempBasementNW a brick:Zone_Air_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:RoomTempBasementSE .
# bldg:RoomTempBasementSE a brick:Zone_Air_Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:RoomTempBasementSW .
# bldg:RoomTempBasementSW a brick:Zone_Air_Temperature_Sensor .
# bldg:Bedroom_2 brick:hasPoint bldg:RoomTempBR2Temp .
# bldg:RoomTempBR2Temp a brick:Zone_Air_Temperature_Sensor .
# bldg:Bedroom_3 brick:hasPoint bldg:RoomTempBR3Temp .
# bldg:RoomTempBR3Temp a brick:Zone_Air_Temperature_Sensor .
# bldg:Bedroom_4 brick:hasPoint bldg:RoomTempBR4Temp .
# bldg:RoomTempBR4Temp a brick:Zone_Air_Temperature_Sensor .
# bldg:Dining_Room brick:hasPoint bldg:RoomTempDRTemp .
# bldg:RoomTempDRTemp a brick:Zone_Air_Temperature_Sensor .
# bldg:Entry_Hallway brick:hasPoint bldg:RoomTempHallLowerMid .
# bldg:RoomTempHallLowerMid a brick:Zone_Air_Temperature_Sensor .
# bldg:Entry_Hallway brick:hasPoint bldg:RoomTempHallLowest .
# bldg:RoomTempHallLowest a brick:Zone_Air_Temperature_Sensor .
# bldg:Entry_Hallway brick:hasPoint bldg:RoomTempHallMiddle .
# bldg:RoomTempHallMiddle a brick:Zone_Air_Temperature_Sensor .
# bldg:Entry_Hallway brick:hasPoint bldg:RoomTempHallUpper .
# bldg:RoomTempHallUpper a brick:Zone_Air_Temperature_Sensor .
# bldg:Entry_Hallway brick:hasPoint bldg:RoomTempHallUpperMid .
# bldg:RoomTempHallUpperMid a brick:Zone_Air_Temperature_Sensor .
# bldg:Kitchen brick:hasPoint bldg:RoomTempKitchenTemp .
# bldg:RoomTempKitchenTemp a brick:Zone_Air_Temperature_Sensor .
# bldg:Living_Room brick:hasPoint bldg:RoomTempLRTemp .
# bldg:RoomTempLRTemp a brick:Zone_Air_Temperature_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:RoomTempMBATemp .
# bldg:RoomTempMBATemp a brick:Zone_Air_Temperature_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:RoomTempMBRTemp .
# bldg:RoomTempMBRTemp a brick:Zone_Air_Temperature_Sensor .
# bldg:Kitchen brick:hasPoint bldg:RoomTempWDTemp .
# bldg:RoomTempWDTemp a brick:Zone_Air_Temperature_Sensor .
# bldg:Bedroom_4 brick:hasPoint bldg:EnergyPlugsInstBR4A .
# bldg:EnergyPlugsInstBR4A a brick:Energy_Usage_Sensor .
# bldg:Bedroom_4 brick:hasPoint bldg:EnergyPlugsInstBR4B .
# bldg:EnergyPlugsInstBR4B a brick:Energy_Usage_Sensor .
# bldg:Living_Room brick:hasPoint bldg:EnergyPlugsInstLRA .
# bldg:EnergyPlugsInstLRA a brick:Energy_Usage_Sensor .
# bldg:Living_Room brick:hasPoint bldg:EnergyPlugsInstLRB .
# bldg:EnergyPlugsInstLRB a brick:Energy_Usage_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:EnergyPlugsInstBA2 .
# bldg:EnergyPlugsInstBA2 a brick:Energy_Usage_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:EnergyPlugsInstMBAB .
# bldg:EnergyPlugsInstMBAB a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyPlugsGSHPInstrumentation .
# bldg:EnergyPlugsGSHPInstrumentation a brick:Energy_Usage_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:EnergyPlugsInstMBRA .
# bldg:EnergyPlugsInstMBRA a brick:Energy_Usage_Sensor .
# bldg:Bedroom_2 brick:hasPoint bldg:EnergyPlugsInstBR2Hall .
# bldg:EnergyPlugsInstBR2Hall a brick:Energy_Usage_Sensor .
# bldg:Entry_Hallway brick:hasPoint bldg:EnergyPlugsInstHall .
# bldg:EnergyPlugsInstHall a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyLightingControlPanelRPS1 .
# bldg:EnergyLightingControlPanelRPS1 a brick:Energy_Usage_Sensor .
# bldg:Bedroom_3 brick:hasPoint bldg:EnergyPlugsInstBR3 .
# bldg:EnergyPlugsInstBR3 a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:EnergyHeatLoadforRefrigerator .
# bldg:EnergyHeatLoadforRefrigerator a brick:Energy_Usage_Sensor .
# bldg:Mudroom brick:hasPoint bldg:EnergyPlugsInstMudroomA .
# bldg:EnergyPlugsInstMudroomA a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyLightingControlPanelRPS2 .
# bldg:EnergyLightingControlPanelRPS2 a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyPlugsHVACInstrumentation .
# bldg:EnergyPlugsHVACInstrumentation a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:EnergyPlugsInstKitD .
# bldg:EnergyPlugsInstKitD a brick:Energy_Usage_Sensor .
# bldg:Bathroom_1 brick:hasPoint bldg:EnergyPlugsInstBA1 .
# bldg:EnergyPlugsInstBA1 a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:EnergyPlugsInstKitA .
# bldg:EnergyPlugsInstKitA a brick:Energy_Usage_Sensor .
# bldg:Mudroom brick:hasPoint bldg:EnergyPlugsInstMudroomB .
# bldg:EnergyPlugsInstMudroomB a brick:Energy_Usage_Sensor .
# bldg:Dining_Room brick:hasPoint bldg:EnergyPlugsInstDRA .
# bldg:EnergyPlugsInstDRA a brick:Energy_Usage_Sensor .
# bldg:Bedroom_4 brick:hasPoint bldg:PowerPlugsInstBR4A .
# bldg:PowerPlugsInstBR4A a brick:Power_Sensor .
# bldg:Bedroom_4 brick:hasPoint bldg:PowerPlugsInstBR4B .
# bldg:PowerPlugsInstBR4B a brick:Power_Sensor .
# bldg:Living_Room brick:hasPoint bldg:PowerPlugsInstLRA .
# bldg:PowerPlugsInstLRA a brick:Power_Sensor .
# bldg:Living_Room brick:hasPoint bldg:PowerPlugsInstLRB .
# bldg:PowerPlugsInstLRB a brick:Power_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:PowerPlugsInstBA2 .
# bldg:PowerPlugsInstBA2 a brick:Power_Sensor .
# bldg:Master_Bathroom brick:hasPoint bldg:PowerPlugsInstMBAB .
# bldg:PowerPlugsInstMBAB a brick:Power_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerPlugsGSHPInstrumentation .
# bldg:PowerPlugsGSHPInstrumentation a brick:Power_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:PowerPlugsInstMBRA .
# bldg:PowerPlugsInstMBRA a brick:Power_Sensor .
# bldg:Bedroom_2 brick:hasPoint bldg:PowerPlugsInstBR2Hall .
# bldg:PowerPlugsInstBR2Hall a brick:Power_Sensor .
# bldg:Entry_Hallway brick:hasPoint bldg:PowerPlugsInstHall .
# bldg:PowerPlugsInstHall a brick:Power_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerLightingControlPanelRPS1 .
# bldg:PowerLightingControlPanelRPS1 a brick:Thermal_Power_Sensor .
# bldg:Bedroom_3 brick:hasPoint bldg:PowerPlugsInstBR3 .
# bldg:PowerPlugsInstBR3 a brick:Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:PowerHeatLoadforRefrigerator .
# bldg:PowerHeatLoadforRefrigerator a brick:Thermal_Power_Sensor .
# bldg:Mudroom brick:hasPoint bldg:PowerPlugsInstMudroomA .
# bldg:PowerPlugsInstMudroomA a brick:Power_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerLightingControlPanelRPS2 .
# bldg:PowerLightingControlPanelRPS2 a brick:Thermal_Power_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerPlugsHVACInstrumentation .
# bldg:PowerPlugsHVACInstrumentation a brick:Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:PowerPlugsInstKitD .
# bldg:PowerPlugsInstKitD a brick:Power_Sensor .
# bldg:Bathroom_1 brick:hasPoint bldg:PowerPlugsInstBA1 .
# bldg:PowerPlugsInstBA1 a brick:Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:PowerPlugsInstKitA .
# bldg:PowerPlugsInstKitA a brick:Power_Sensor .
# bldg:Mudroom brick:hasPoint bldg:PowerPlugsInstMudroomB .
# bldg:PowerPlugsInstMudroomB a brick:Power_Sensor .
# bldg:Dining_Room brick:hasPoint bldg:PowerPlugsInstDRA .
# bldg:PowerPlugsInstDRA a brick:Power_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyLightsBasementStair .
# bldg:EnergyLightsBasementStair a brick:Energy_Usage_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:EnergyLights2ndFloor .
# bldg:EnergyLights2ndFloor a brick:Energy_Usage_Sensor .
# bldg:Multiple brick:hasPoint bldg:EnergyLights1stFloorA .
# bldg:EnergyLights1stFloorA a brick:Energy_Usage_Sensor .
# bldg:Multiple brick:hasPoint bldg:EnergyLights1stFloorB .
# bldg:EnergyLights1stFloorB a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyLightsBasement .
# bldg:EnergyLightsBasement a brick:Energy_Usage_Sensor .
# bldg:Attic brick:hasPoint bldg:EnergyLightsAttic .
# bldg:EnergyLightsAttic a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerLightsBasementStair .
# bldg:PowerLightsBasementStair a brick:Thermal_Power_Sensor .
# bldg:Bathroom_2 brick:hasPoint bldg:PowerLights2ndFloor .
# bldg:PowerLights2ndFloor a brick:Thermal_Power_Sensor .
# bldg:Multiple brick:hasPoint bldg:PowerLights1stFloorA .
# bldg:PowerLights1stFloorA a brick:Thermal_Power_Sensor .
# bldg:Multiple brick:hasPoint bldg:PowerLights1stFloorB .
# bldg:PowerLights1stFloorB a brick:Thermal_Power_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerLightsBasement .
# bldg:PowerLightsBasement a brick:Thermal_Power_Sensor .
# bldg:Attic brick:hasPoint bldg:PowerLightsAttic .
# bldg:PowerLightsAttic a brick:Thermal_Power_Sensor .
# bldg:Dining_Room brick:hasPoint bldg:EnergyChildBDownstairs .
# bldg:EnergyChildBDownstairs a brick:Energy_Usage_Sensor .
# bldg:Living_Room brick:hasPoint bldg:EnergyChildADownstairs .
# bldg:EnergyChildADownstairs a brick:Energy_Usage_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:EnergyParentAUpstairs .
# bldg:EnergyParentAUpstairs a brick:Energy_Usage_Sensor .
# bldg:Bedroom_2 brick:hasPoint bldg:EnergyChildAUpstairs .
# bldg:EnergyChildAUpstairs a brick:Energy_Usage_Sensor .
# bldg:Bedroom_3 brick:hasPoint bldg:EnergyChildBUpstairs .
# bldg:EnergyChildBUpstairs a brick:Energy_Usage_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:EnergyParentBUpstairs .
# bldg:EnergyParentBUpstairs a brick:Energy_Usage_Sensor .
# bldg:Dining_Room brick:hasPoint bldg:EnergyParentBDownstairs .
# bldg:EnergyParentBDownstairs a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:EnergyParentADownstairs .
# bldg:EnergyParentADownstairs a brick:Energy_Usage_Sensor .
# bldg:Dining_Room brick:hasPoint bldg:PowerChildBDownstairs .
# bldg:PowerChildBDownstairs a brick:Thermal_Power_Sensor .
# bldg:Living_Room brick:hasPoint bldg:PowerChildADownstairs .
# bldg:PowerChildADownstairs a brick:Thermal_Power_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:PowerParentAUpstairs .
# bldg:PowerParentAUpstairs a brick:Thermal_Power_Sensor .
# bldg:Bedroom_2 brick:hasPoint bldg:PowerChildAUpstairs .
# bldg:PowerChildAUpstairs a brick:Thermal_Power_Sensor .
# bldg:Bedroom_3 brick:hasPoint bldg:PowerChildBUpstairs .
# bldg:PowerChildBUpstairs a brick:Thermal_Power_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:PowerParentBUpstairs .
# bldg:PowerParentBUpstairs a brick:Thermal_Power_Sensor .
# bldg:Dining_Room brick:hasPoint bldg:PowerParentBDownstairs .
# bldg:PowerParentBDownstairs a brick:Thermal_Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:PowerParentADownstairs .
# bldg:PowerParentADownstairs a brick:Thermal_Power_Sensor .
# bldg:Multiple brick:hasPoint bldg:1stFloorLightsEnergyUsage .
# bldg:1stFloorLightsEnergyUsage a brick:Energy_Usage_Sensor .
# bldg:Multiple brick:hasPoint bldg:1stFloorLightsPowerUsage .
# bldg:1stFloorLightsPowerUsage a brick:Thermal_Power_Sensor .
# bldg:Multiple brick:hasPoint bldg:1stFloorSensHeatEnergyUsage .
# bldg:1stFloorSensHeatEnergyUsage a brick:Energy_Usage_Sensor .
# bldg:Multiple brick:hasPoint bldg:1stFloorSensHeatPowerUsage .
# bldg:1stFloorSensHeatPowerUsage a brick:Thermal_Power_Sensor .
# bldg:Multiple brick:hasPoint bldg:2ndFloorLightsEnergyUsage .
# bldg:2ndFloorLightsEnergyUsage a brick:Energy_Usage_Sensor .
# bldg:Multiple brick:hasPoint bldg:2ndFloorLightsPowerUsage .
# bldg:2ndFloorLightsPowerUsage a brick:Thermal_Power_Sensor .
# bldg:Multiple brick:hasPoint bldg:2ndFloorSensHeatEnergyUsage .
# bldg:2ndFloorSensHeatEnergyUsage a brick:Energy_Usage_Sensor .
# bldg:Multiple brick:hasPoint bldg:2ndFloorSensHeatPowerUsage .
# bldg:2ndFloorSensHeatPowerUsage a brick:Thermal_Power_Sensor .
# bldg:Basement brick:hasPoint bldg:BasementPlugLoadsEnergyUsage .
# bldg:BasementPlugLoadsEnergyUsage a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:BasementPlugLoadsPowerUsage .
# bldg:BasementPlugLoadsPowerUsage a brick:Power_Sensor .
# bldg:Bedroom_2 brick:hasPoint bldg:BR2PlugLoadsEnergyUsage .
# bldg:BR2PlugLoadsEnergyUsage a brick:Energy_Usage_Sensor .
# bldg:Bedroom_2 brick:hasPoint bldg:BR2PlugLoadsPowerUsage .
# bldg:BR2PlugLoadsPowerUsage a brick:Power_Sensor .
# bldg:Bedroom_3 brick:hasPoint bldg:BR3PlugLoadsEnergyUsage .
# bldg:BR3PlugLoadsEnergyUsage a brick:Energy_Usage_Sensor .
# bldg:Bedroom_3 brick:hasPoint bldg:BR3PlugLoadsPowerUsage .
# bldg:BR3PlugLoadsPowerUsage a brick:Power_Sensor .
# bldg:Bedroom_4 brick:hasPoint bldg:BR4PlugLoadsEnergyUsage .
# bldg:BR4PlugLoadsEnergyUsage a brick:Energy_Usage_Sensor .
# bldg:Bedroom_4 brick:hasPoint bldg:BR4PlugLoadsPowerUsage .
# bldg:BR4PlugLoadsPowerUsage a brick:Power_Sensor .
# bldg:Utility brick:hasPoint bldg:ClothesWasherEnergywithStandby .
# bldg:ClothesWasherEnergywithStandby a brick:Energy_Usage_Sensor .
# bldg:Utility brick:hasPoint bldg:ClothesWasherPowerWithStandby .
# bldg:ClothesWasherPowerWithStandby a brick:Thermal_Power_Sensor .
# bldg:Utility brick:hasPoint bldg:DryerEnergyTotal .
# bldg:DryerEnergyTotal a brick:Energy_Usage_Sensor .
# bldg:Utility brick:hasPoint bldg:DryerPowerTotal .
# bldg:DryerPowerTotal a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:RefrigeratorTemp .
# bldg:RefrigeratorTemp a brick:Temperature_Sensor .
# bldg:Kitchen brick:hasPoint bldg:KPlugLoadsEnergyUsage .
# bldg:KPlugLoadsEnergyUsage a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:KPlugLoadsPowerUsage .
# bldg:KPlugLoadsPowerUsage a brick:Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:LatentHeatEnergyUsage .
# bldg:LatentHeatEnergyUsage a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:LatentHeatPowerUsage .
# bldg:LatentHeatPowerUsage a brick:Thermal_Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:LatentHeatWaterVolume .
# bldg:LatentHeatWaterVolume a brick:Water_Level_Sensor .
# bldg:Living_Room brick:hasPoint bldg:LRPlugLoadsEnergyUsage .
# bldg:LRPlugLoadsEnergyUsage a brick:Energy_Usage_Sensor .
# bldg:Living_Room brick:hasPoint bldg:LRPlugLoadsPowerUsage .
# bldg:LRPlugLoadsPowerUsage a brick:Power_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:MBRPlugLoadsEnergyUsage .
# bldg:MBRPlugLoadsEnergyUsage a brick:Energy_Usage_Sensor .
# bldg:Master_Bedroom brick:hasPoint bldg:MBRPlugLoadsPowerUsage .
# bldg:MBRPlugLoadsPowerUsage a brick:Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:MicrowaveEnergywithStandby .
# bldg:MicrowaveEnergywithStandby a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:MicrowavePowerWithStandby .
# bldg:MicrowavePowerWithStandby a brick:Thermal_Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:OvenEnergyTotal .
# bldg:OvenEnergyTotal a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:OvenPowerTotal .
# bldg:OvenPowerTotal a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:RefrigeratorEnergywithStandby .
# bldg:RefrigeratorEnergywithStandby a brick:Energy_Usage_Sensor .
# bldg:Kitchen brick:hasPoint bldg:RefrigeratorPowerWithStandby .
# bldg:RefrigeratorPowerWithStandby a brick:Thermal_Power_Sensor .
# bldg:Kitchen brick:hasPoint bldg:StatusApplianceCooktop .
# bldg:StatusApplianceCooktop a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusApplianceDishwasher .
# bldg:StatusApplianceDishwasher a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusApplianceOven .
# bldg:StatusApplianceOven a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusApplianceRangeHood .
# bldg:StatusApplianceRangeHood a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusLatentload .
# bldg:StatusLatentload a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusPlugLoadBlender .
# bldg:StatusPlugLoadBlender a brick:On_Off_Status .
# bldg:Bedroom_2 brick:hasPoint bldg:StatusPlugLoadBR2Laptop .
# bldg:StatusPlugLoadBR2Laptop a brick:On_Off_Status .
# bldg:Bedroom_3 brick:hasPoint bldg:StatusPlugLoadBR3Laptop .
# bldg:StatusPlugLoadBR3Laptop a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusPlugLoadCanOpener .
# bldg:StatusPlugLoadCanOpener a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusPlugLoadCoffeeMaker .
# bldg:StatusPlugLoadCoffeeMaker a brick:On_Off_Status .
# bldg:Bedroom_4 brick:hasPoint bldg:StatusPlugLoadDesktopPCMonitor .
# bldg:StatusPlugLoadDesktopPCMonitor a brick:On_Off_Status .
# bldg:Master_Bedroom brick:hasPoint bldg:StatusPlugLoadFan .
# bldg:StatusPlugLoadFan a brick:On_Off_Status .
# bldg:Master_Bathroom brick:hasPoint bldg:StatusPlugLoadHairDryerCurlIron .
# bldg:StatusPlugLoadHairDryerCurlIron a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusPlugLoadHandMixer .
# bldg:StatusPlugLoadHandMixer a brick:On_Off_Status .
# bldg:Master_Bedroom brick:hasPoint bldg:StatusPlugLoadHeatingPad .
# bldg:StatusPlugLoadHeatingPad a brick:On_Off_Status .
# bldg:Master_Bedroom brick:hasPoint bldg:StatusPlugLoadIron .
# bldg:StatusPlugLoadIron a brick:On_Off_Status .
# bldg:Living_Room brick:hasPoint bldg:StatusPlugLoadLRBlueRay .
# bldg:StatusPlugLoadLRBlueRay a brick:On_Off_Status .
# bldg:Living_Room brick:hasPoint bldg:StatusPlugLoadLRTV .
# bldg:StatusPlugLoadLRTV a brick:On_Off_Status .
# bldg:Master_Bedroom brick:hasPoint bldg:StatusPlugLoadMBRBlueRay .
# bldg:StatusPlugLoadMBRBlueRay a brick:On_Off_Status .
# bldg:Master_Bedroom brick:hasPoint bldg:StatusPlugLoadMBRTV .
# bldg:StatusPlugLoadMBRTV a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusPlugLoadSlowCooker .
# bldg:StatusPlugLoadSlowCooker a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusPlugLoadToaster .
# bldg:StatusPlugLoadToaster a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusPlugLoadToasterOven .
# bldg:StatusPlugLoadToasterOven a brick:On_Off_Status .
# bldg:Bedroom_4 brick:hasPoint bldg:StatusPlugLoadVacuum .
# bldg:StatusPlugLoadVacuum a brick:On_Off_Status .
# bldg:Living_Room brick:hasPoint bldg:StatusPlugLoadVideoGame .
# bldg:StatusPlugLoadVideoGame a brick:On_Off_Status .
# bldg:Bedroom_4 brick:hasPoint bldg:StatusBR4Lights .
# bldg:StatusBR4Lights a brick:On_Off_Status .
# bldg:Master_Bathroom brick:hasPoint bldg:StatusMBALights .
# bldg:StatusMBALights a brick:On_Off_Status .
# bldg:Master_Bedroom brick:hasPoint bldg:StatusMBRLights1 .
# bldg:StatusMBRLights1 a brick:On_Off_Status .
# bldg:Master_Bedroom brick:hasPoint bldg:StatusMBRLights2 .
# bldg:StatusMBRLights2 a brick:On_Off_Status .
# bldg:Bathroom_2 brick:hasPoint bldg:StatusBA2Lights .
# bldg:StatusBA2Lights a brick:On_Off_Status .
# bldg:Bedroom_2 brick:hasPoint bldg:StatusBR2Lights .
# bldg:StatusBR2Lights a brick:On_Off_Status .
# bldg:Bathroom_1 brick:hasPoint bldg:StatusBA1Lights .
# bldg:StatusBA1Lights a brick:On_Off_Status .
# bldg:Bedroom_3 brick:hasPoint bldg:StatusBR3Lights .
# bldg:StatusBR3Lights a brick:On_Off_Status .
# bldg:Dining_Room brick:hasPoint bldg:StatusSensHeatPrntBDOWN .
# bldg:StatusSensHeatPrntBDOWN a brick:On_Off_Status .
# bldg:Master_Bedroom brick:hasPoint bldg:StatusSensHeatPrntAUP .
# bldg:StatusSensHeatPrntAUP a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusKitchenLightsA .
# bldg:StatusKitchenLightsA a brick:On_Off_Status .
# bldg:Master_Bedroom brick:hasPoint bldg:StatusSensHeatPrntBUP .
# bldg:StatusSensHeatPrntBUP a brick:On_Off_Status .
# bldg:Bedroom_2 brick:hasPoint bldg:StatusSensHeatChildAUP .
# bldg:StatusSensHeatChildAUP a brick:On_Off_Status .
# bldg:Bedroom_3 brick:hasPoint bldg:StatusSensHeatChildBUP .
# bldg:StatusSensHeatChildBUP a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusKitchenLightsB .
# bldg:StatusKitchenLightsB a brick:On_Off_Status .
# bldg:Dining_Room brick:hasPoint bldg:StatusSensHeatChildBDOWN .
# bldg:StatusSensHeatChildBDOWN a brick:On_Off_Status .
# bldg:Living_Room brick:hasPoint bldg:StatusLRLights1 .
# bldg:StatusLRLights1 a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusSensHeatPrntADOWN .
# bldg:StatusSensHeatPrntADOWN a brick:On_Off_Status .
# bldg:Living_Room brick:hasPoint bldg:StatusSensHeatChildADOWN .
# bldg:StatusSensHeatChildADOWN a brick:On_Off_Status .
# bldg:Kitchen brick:hasPoint bldg:StatusKitchenLightsC .
# bldg:StatusKitchenLightsC a brick:On_Off_Status .
# bldg:Living_Room brick:hasPoint bldg:StatusLRLights2 .
# bldg:StatusLRLights2 a brick:On_Off_Status .
# bldg:Dining_Room brick:hasPoint bldg:StatusDRLights .
# bldg:StatusDRLights a brick:On_Off_Status .
# bldg:Living_Room brick:hasPoint bldg:StatusLRLights3 .
# bldg:StatusLRLights3 a brick:On_Off_Status .
# bldg:Entry_Hallway brick:hasPoint bldg:StatusEntryHallLights .
# bldg:StatusEntryHallLights a brick:On_Off_Status .
# bldg:Outdoor brick:hasPoint bldg:OutdoorAmbTemp .
# bldg:OutdoorAmbTemp a brick:Temperature_Sensor .
# bldg:Outdoor brick:hasPoint bldg:RooftopWindDirection .
# bldg:RooftopWindDirection a brick:Wind_Direction_Sensor .
# bldg:Outdoor brick:hasPoint bldg:RooftopWindSpeed .
# bldg:RooftopWindSpeed a brick:Wind_Speed_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyPV1of2 .
# bldg:EnergyPV1of2 a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:EnergyPV2of2 .
# bldg:EnergyPV2of2 a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerPV1of2 .
# bldg:PowerPV1of2 a brick:Thermal_Power_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerPV2of2 .
# bldg:PowerPV2of2 a brick:Thermal_Power_Sensor .
# bldg:Attic brick:hasPoint bldg:AmpsAIA1 .
# bldg:AmpsAIA1 a brick:Current_Sensor .
# bldg:Attic brick:hasPoint bldg:AmpsAIA2 .
# bldg:AmpsAIA2 a brick:Current_Sensor .
# bldg:Attic brick:hasPoint bldg:AmpsBIB1 .
# bldg:AmpsBIB1 a brick:Current_Sensor .
# bldg:Attic brick:hasPoint bldg:AmpsBIB2 .
# bldg:AmpsBIB2 a brick:Current_Sensor .
# bldg:Attic brick:hasPoint bldg:FrequencyF1 .
# bldg:FrequencyF1 a brick:Frequency_Sensor .
# bldg:Attic brick:hasPoint bldg:FrequencyF2 .
# bldg:FrequencyF2 a brick:Frequency_Sensor .
# bldg:Attic brick:hasPoint bldg:PowerFactor3PhTotalPF3PhT1 .
# bldg:PowerFactor3PhTotalPF3PhT1 a brick:Thermal_Power_Sensor .
# bldg:Attic brick:hasPoint bldg:PowerFactor3PhTotalPF3PhT2 .
# bldg:PowerFactor3PhTotalPF3PhT2 a brick:Thermal_Power_Sensor .
# bldg:Outdoor brick:hasPoint bldg:PVBacksideTemp2 .
# bldg:PVBacksideTemp2 a brick:Temperature_Sensor .
# bldg:Outdoor brick:hasPoint bldg:PVBacksideTemp3 .
# bldg:PVBacksideTemp3 a brick:Temperature_Sensor .
# bldg:Outdoor brick:hasPoint bldg:PVBacksideTemp4 .
# bldg:PVBacksideTemp4 a brick:Temperature_Sensor .
# bldg:Outdoor brick:hasPoint bldg:PVBacksideTemp7 .
# bldg:PVBacksideTemp7 a brick:Temperature_Sensor .
# bldg:Outdoor brick:hasPoint bldg:PVInsolationHArray .
# bldg:PVInsolationHArray a brick:Solar_Radiance_Sensor .
# bldg:Attic brick:hasPoint bldg:PVSystem1ACEnergyOSEACPV1OS .
# bldg:PVSystem1ACEnergyOSEACPV1OS a brick:Energy_Usage_Sensor .
# bldg:Attic brick:hasPoint bldg:PVSystem1ACPowerOSPACPV1OS .
# bldg:PVSystem1ACPowerOSPACPV1OS a brick:Thermal_Power_Sensor .
# bldg:Attic brick:hasPoint bldg:PVSystem2ACEnergyOSEACPV2OS .
# bldg:PVSystem2ACEnergyOSEACPV2OS a brick:Energy_Usage_Sensor .
# bldg:Attic brick:hasPoint bldg:PVSystem2ACPowerOSPACPV2OS .
# bldg:PVSystem2ACPowerOSPACPV2OS a brick:Thermal_Power_Sensor .
# bldg:Attic brick:hasPoint bldg:StringCurrentIStr1 .
# bldg:StringCurrentIStr1 a brick:Current_Sensor .
# bldg:Attic brick:hasPoint bldg:StringCurrentIStr2 .
# bldg:StringCurrentIStr2 a brick:Current_Sensor .
# bldg:Attic brick:hasPoint bldg:StringCurrentIStr3 .
# bldg:StringCurrentIStr3 a brick:Current_Sensor .
# bldg:Attic brick:hasPoint bldg:StringCurrentIStr4 .
# bldg:StringCurrentIStr4 a brick:Current_Sensor .
# bldg:Attic brick:hasPoint bldg:StringVoltageUStr2 .
# bldg:StringVoltageUStr2 a brick:Voltage_Sensor .
# bldg:Attic brick:hasPoint bldg:StringVoltageUStr4 .
# bldg:StringVoltageUStr4 a brick:Voltage_Sensor .
# bldg:Attic brick:hasPoint bldg:VoltsANUAN1 .
# bldg:VoltsANUAN1 a brick:Voltage_Sensor .
# bldg:Attic brick:hasPoint bldg:VoltsANUAN2 .
# bldg:VoltsANUAN2 a brick:Voltage_Sensor .
# bldg:Attic brick:hasPoint bldg:VoltsBNUBN1 .
# bldg:VoltsBNUBN1 a brick:Voltage_Sensor .
# bldg:Attic brick:hasPoint bldg:VoltsBNUBN2 .
# bldg:VoltsBNUBN2 a brick:Voltage_Sensor .
# bldg:Attic brick:hasPoint bldg:Watts3PhTotalW3PhT1 .
# bldg:Watts3PhTotalW3PhT1 a brick:Power_Sensor .
# bldg:Attic brick:hasPoint bldg:Watts3PhTotalW3PhT2 .
# bldg:Watts3PhTotalW3PhT2 a brick:Power_Sensor .
# bldg:Attic brick:hasPoint bldg:WhoursDeliveredWhD1 .
# bldg:WhoursDeliveredWhD1 a brick:Energy_Usage_Sensor .
# bldg:Attic brick:hasPoint bldg:WhoursDeliveredWhD2 .
# bldg:WhoursDeliveredWhD2 a brick:Energy_Usage_Sensor .
# bldg:Basement brick:hasPoint bldg:PowerPlugsBaseAHeliodyneHXs .
# bldg:PowerPlugsBaseAHeliodyneHXs a brick:Power_Sensor .
# bldg:Basement brick:hasPoint bldg:GlycolFlowHXCoriolisSHW .
# bldg:GlycolFlowHXCoriolisSHW a brick:Flow_Sensor .
# bldg:Basement brick:hasPoint bldg:GlycolFlowRateHXCoriolisSHW .
# bldg:GlycolFlowRateHXCoriolisSHW a brick:Flow_Sensor .
# bldg:Outdoor brick:hasPoint bldg:GlycolTempSHWPanel80galOut .
# bldg:GlycolTempSHWPanel80galOut a brick:Temperature_Sensor .
# bldg:Outdoor brick:hasPoint bldg:PSPSHW .
# bldg:PSPSHW a brick:Solar_Radiance_Sensor .
# bldg:Basement brick:hasPoint bldg:SHWHX80galWaterFlow .
# bldg:SHWHX80galWaterFlow a brick:Flow_Sensor .
# bldg:Basement brick:hasPoint bldg:WaterFlowHXCoriolisSHW .
# bldg:WaterFlowHXCoriolisSHW a brick:Flow_Sensor .
# bldg:Basement brick:hasPoint bldg:WaterFlowRateHXCoriolisSHW .
# bldg:WaterFlowRateHXCoriolisSHW a brick:Flow_Sensor .
# bldg:Attic brick:hasPoint bldg:EnergyMakeUpAirDamper .
# bldg:EnergyMakeUpAirDamper a brick:Energy_Usage_Sensor .
# bldg:Attic brick:hasPoint bldg:PowerMakeUpAirDamper .
# bldg:PowerMakeUpAirDamper a brick:Thermal_Power_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVDewpointTemperatureExhaust .
# bldg:HRVDewpointTemperatureExhaust a brick:Dewpoint_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVDewpointTemperatureOutdoor .
# bldg:HRVDewpointTemperatureOutdoor a brick:Dewpoint_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVDewpointTemperatureReturn .
# bldg:HRVDewpointTemperatureReturn a brick:Dewpoint_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVDewpointTemperatureSupply .
# bldg:HRVDewpointTemperatureSupply a brick:Dewpoint_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVexhaustflowrate .
# bldg:HRVexhaustflowrate a brick:Air_Flow_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVfreshairpressuredifferential .
# bldg:HRVfreshairpressuredifferential a brick:Differential_Pressure_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVoutdoorflowrate .
# bldg:HRVoutdoorflowrate a brick:Air_Flow_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVreturnflowrate .
# bldg:HRVreturnflowrate a brick:Air_Flow_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVstaleairpressuredifferential .
# bldg:HRVstaleairpressuredifferential a brick:Differential_Pressure_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVTempExhaustOut .
# bldg:HRVTempExhaustOut a brick:Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVTempOutdoorin .
# bldg:HRVTempOutdoorin a brick:Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVTempReturnIn .
# bldg:HRVTempReturnIn a brick:Temperature_Sensor .
# bldg:Basement brick:hasPoint bldg:HRVTempSupplyOut .
# bldg:HRVTempSupplyOut a brick:Temperature_Sensor .
#
# bldg:AHU01 a brick:AHU ;
# bldg:AHU01 brick:feeds bldg:Living_Room .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsLR .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsLR .
# bldg:AHU01 brick:hasPoint bldg:LivingRmRH .
# bldg:AHU01 brick:hasPoint bldg:RadiantTempLR .
# bldg:AHU01 brick:hasPoint bldg:RoomTempLRTemp .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstLRA .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstLRB .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstLRA .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstLRB .
# bldg:AHU01 brick:hasPoint bldg:EnergyChildADownstairs .
# bldg:AHU01 brick:hasPoint bldg:PowerChildADownstairs .
# bldg:AHU01 brick:hasPoint bldg:LRPlugLoadsEnergyUsage .
# bldg:AHU01 brick:hasPoint bldg:LRPlugLoadsPowerUsage .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadLRBlueRay .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadLRTV .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadVideoGame .
# bldg:AHU01 brick:hasPoint bldg:StatusLRLights1 .
# bldg:AHU01 brick:hasPoint bldg:StatusSensHeatChildADOWN .
# bldg:AHU01 brick:hasPoint bldg:StatusLRLights2 .
# bldg:AHU01 brick:hasPoint bldg:StatusLRLights3 .
# bldg:AHU01 brick:feeds bldg:Basement .
# bldg:AHU01 brick:hasPoint bldg:SHWGlycolTempIn .
# bldg:AHU01 brick:hasPoint bldg:SHWGlycolTempOut .
# bldg:AHU01 brick:hasPoint bldg:HeatPumpWaterHeaterEnergyTotal .
# bldg:AHU01 brick:hasPoint bldg:HeatPumpWaterHeaterPowerTotal .
# bldg:AHU01 brick:hasPoint bldg:ManifoldColdFlow .
# bldg:AHU01 brick:hasPoint bldg:ManifoldHotFlow .
# bldg:AHU01 brick:hasPoint bldg:MixValveColdFlow .
# bldg:AHU01 brick:hasPoint bldg:RoomTempBasementHPWH .
# bldg:AHU01 brick:hasPoint bldg:SHWPumpsEnergywithStandby .
# bldg:AHU01 brick:hasPoint bldg:SHWPumpsPowerwithStandby .
# bldg:AHU01 brick:hasPoint bldg:WaterTempHPWHIn .
# bldg:AHU01 brick:hasPoint bldg:WaterTempHPWHOut .
# bldg:AHU01 brick:hasPoint bldg:WaterTempManifoldColdIn .
# bldg:AHU01 brick:hasPoint bldg:WaterTempManifoldHotIn .
# bldg:AHU01 brick:hasPoint bldg:WaterTempMixValveColdIn .
# bldg:AHU01 brick:hasPoint bldg:WaterTempMixValveHotIn .
# bldg:AHU01 brick:hasPoint bldg:WaterTempSHWHX80galIn .
# bldg:AHU01 brick:hasPoint bldg:WaterTempSHWHX80galOut .
# bldg:AHU01 brick:hasPoint bldg:WaterTempSHWTank80galIn .
# bldg:AHU01 brick:hasPoint bldg:WaterTempSHWTank80galOut .
# bldg:AHU01 brick:hasPoint bldg:EnergyHeatPumpWH1of2 .
# bldg:AHU01 brick:hasPoint bldg:EnergyHeatPumpWH2of2 .
# bldg:AHU01 brick:hasPoint bldg:PowerHeatPumpWH1of2 .
# bldg:AHU01 brick:hasPoint bldg:PowerHeatPumpWH2of2 .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsBaseAHeliodyneHXs .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsBaseB .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsBaseC .
# bldg:AHU01 brick:hasPoint bldg:EnergySumpPump .
# bldg:AHU01 brick:hasPoint bldg:EnergySpare1 .
# bldg:AHU01 brick:hasPoint bldg:EnergySpare2 .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsBaseB .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsBaseC .
# bldg:AHU01 brick:hasPoint bldg:PowerSumpPump .
# bldg:AHU01 brick:hasPoint bldg:PowerSpare1 .
# bldg:AHU01 brick:hasPoint bldg:PowerSpare2 .
# bldg:AHU01 brick:hasPoint bldg:EnergyHRV .
# bldg:AHU01 brick:hasPoint bldg:PowerHRV .
# bldg:AHU01 brick:hasPoint bldg:DehumidifierAirflow .
# bldg:AHU01 brick:hasPoint bldg:DehumidifierExitAirTemp .
# bldg:AHU01 brick:hasPoint bldg:DehumidifierInletAirTemp .
# bldg:AHU01 brick:hasPoint bldg:DehumidifierPower .
# bldg:AHU01 brick:hasPoint bldg:HeatPumpIndoorUnitPower .
# bldg:AHU01 brick:hasPoint bldg:HVACDewpointReturnAir .
# bldg:AHU01 brick:hasPoint bldg:HVACDewpointSupplyAir .
# bldg:AHU01 brick:hasPoint bldg:HVACTempReturnAir .
# bldg:AHU01 brick:hasPoint bldg:HVACTempSupplyAir .
# bldg:AHU01 brick:hasPoint bldg:BasementRH .
# bldg:AHU01 brick:hasPoint bldg:RoomTempBasementNE .
# bldg:AHU01 brick:hasPoint bldg:RoomTempBasementNW .
# bldg:AHU01 brick:hasPoint bldg:RoomTempBasementSE .
# bldg:AHU01 brick:hasPoint bldg:RoomTempBasementSW .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsGSHPInstrumentation .
# bldg:AHU01 brick:hasPoint bldg:EnergyLightingControlPanelRPS1 .
# bldg:AHU01 brick:hasPoint bldg:EnergyLightingControlPanelRPS2 .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsHVACInstrumentation .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsGSHPInstrumentation .
# bldg:AHU01 brick:hasPoint bldg:PowerLightingControlPanelRPS1 .
# bldg:AHU01 brick:hasPoint bldg:PowerLightingControlPanelRPS2 .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsHVACInstrumentation .
# bldg:AHU01 brick:hasPoint bldg:EnergyLightsBasementStair .
# bldg:AHU01 brick:hasPoint bldg:EnergyLightsBasement .
# bldg:AHU01 brick:hasPoint bldg:PowerLightsBasementStair .
# bldg:AHU01 brick:hasPoint bldg:PowerLightsBasement .
# bldg:AHU01 brick:hasPoint bldg:BasementPlugLoadsEnergyUsage .
# bldg:AHU01 brick:hasPoint bldg:BasementPlugLoadsPowerUsage .
# bldg:AHU01 brick:hasPoint bldg:EnergyPV1of2 .
# bldg:AHU01 brick:hasPoint bldg:EnergyPV2of2 .
# bldg:AHU01 brick:hasPoint bldg:PowerPV1of2 .
# bldg:AHU01 brick:hasPoint bldg:PowerPV2of2 .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsBaseAHeliodyneHXs .
# bldg:AHU01 brick:hasPoint bldg:GlycolFlowHXCoriolisSHW .
# bldg:AHU01 brick:hasPoint bldg:GlycolFlowRateHXCoriolisSHW .
# bldg:AHU01 brick:hasPoint bldg:SHWHX80galWaterFlow .
# bldg:AHU01 brick:hasPoint bldg:WaterFlowHXCoriolisSHW .
# bldg:AHU01 brick:hasPoint bldg:WaterFlowRateHXCoriolisSHW .
# bldg:AHU01 brick:hasPoint bldg:HRVDewpointTemperatureExhaust .
# bldg:AHU01 brick:hasPoint bldg:HRVDewpointTemperatureOutdoor .
# bldg:AHU01 brick:hasPoint bldg:HRVDewpointTemperatureReturn .
# bldg:AHU01 brick:hasPoint bldg:HRVDewpointTemperatureSupply .
# bldg:AHU01 brick:hasPoint bldg:HRVexhaustflowrate .
# bldg:AHU01 brick:hasPoint bldg:HRVfreshairpressuredifferential .
# bldg:AHU01 brick:hasPoint bldg:HRVoutdoorflowrate .
# bldg:AHU01 brick:hasPoint bldg:HRVreturnflowrate .
# bldg:AHU01 brick:hasPoint bldg:HRVstaleairpressuredifferential .
# bldg:AHU01 brick:hasPoint bldg:HRVTempExhaustOut .
# bldg:AHU01 brick:hasPoint bldg:HRVTempOutdoorin .
# bldg:AHU01 brick:hasPoint bldg:HRVTempReturnIn .
# bldg:AHU01 brick:hasPoint bldg:HRVTempSupplyOut .
# bldg:AHU01 brick:feeds bldg:Kitchen .
# bldg:AHU01 brick:hasPoint bldg:DishwasherHotFlow .
# bldg:AHU01 brick:hasPoint bldg:StatusSolenoidColdKitchenSink .
# bldg:AHU01 brick:hasPoint bldg:StatusSolenoidHotKitchenSink .
# bldg:AHU01 brick:hasPoint bldg:WaterTempDishwasher .
# bldg:AHU01 brick:hasPoint bldg:WaterTempKSinkCold .
# bldg:AHU01 brick:hasPoint bldg:WaterTempKSinkHot .
# bldg:AHU01 brick:hasPoint bldg:WaterTempKSinkMix .
# bldg:AHU01 brick:hasPoint bldg:EnergyGarbageDisposal .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsKitRange .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsKitPeninsula .
# bldg:AHU01 brick:hasPoint bldg:EnergyMicrowave .
# bldg:AHU01 brick:hasPoint bldg:EnergyDishwasher .
# bldg:AHU01 brick:hasPoint bldg:EnergyRefrigerator .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsKitSink .
# bldg:AHU01 brick:hasPoint bldg:PowerGarbageDisposal .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsKitRange .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsKitPeninsula .
# bldg:AHU01 brick:hasPoint bldg:PowerMicrowave .
# bldg:AHU01 brick:hasPoint bldg:PowerDishwasher .
# bldg:AHU01 brick:hasPoint bldg:PowerRefrigerator .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsKitSink .
# bldg:AHU01 brick:hasPoint bldg:KitchenRH .
# bldg:AHU01 brick:hasPoint bldg:RadiantTempKitchen .
# bldg:AHU01 brick:hasPoint bldg:RoomTempKitchenTemp .
# bldg:AHU01 brick:hasPoint bldg:RoomTempWDTemp .
# bldg:AHU01 brick:hasPoint bldg:EnergyHeatLoadforRefrigerator .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstKitD .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstKitA .
# bldg:AHU01 brick:hasPoint bldg:PowerHeatLoadforRefrigerator .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstKitD .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstKitA .
# bldg:AHU01 brick:hasPoint bldg:EnergyParentADownstairs .
# bldg:AHU01 brick:hasPoint bldg:PowerParentADownstairs .
# bldg:AHU01 brick:hasPoint bldg:RefrigeratorTemp .
# bldg:AHU01 brick:hasPoint bldg:KPlugLoadsEnergyUsage .
# bldg:AHU01 brick:hasPoint bldg:KPlugLoadsPowerUsage .
# bldg:AHU01 brick:hasPoint bldg:LatentHeatEnergyUsage .
# bldg:AHU01 brick:hasPoint bldg:LatentHeatPowerUsage .
# bldg:AHU01 brick:hasPoint bldg:LatentHeatWaterVolume .
# bldg:AHU01 brick:hasPoint bldg:MicrowaveEnergywithStandby .
# bldg:AHU01 brick:hasPoint bldg:MicrowavePowerWithStandby .
# bldg:AHU01 brick:hasPoint bldg:OvenEnergyTotal .
# bldg:AHU01 brick:hasPoint bldg:OvenPowerTotal .
# bldg:AHU01 brick:hasPoint bldg:RefrigeratorEnergywithStandby .
# bldg:AHU01 brick:hasPoint bldg:RefrigeratorPowerWithStandby .
# bldg:AHU01 brick:hasPoint bldg:StatusApplianceCooktop .
# bldg:AHU01 brick:hasPoint bldg:StatusApplianceDishwasher .
# bldg:AHU01 brick:hasPoint bldg:StatusApplianceOven .
# bldg:AHU01 brick:hasPoint bldg:StatusApplianceRangeHood .
# bldg:AHU01 brick:hasPoint bldg:StatusLatentload .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadBlender .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadCanOpener .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadCoffeeMaker .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadHandMixer .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadSlowCooker .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadToaster .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadToasterOven .
# bldg:AHU01 brick:hasPoint bldg:StatusKitchenLightsA .
# bldg:AHU01 brick:hasPoint bldg:StatusKitchenLightsB .
# bldg:AHU01 brick:hasPoint bldg:StatusSensHeatPrntADOWN .
# bldg:AHU01 brick:hasPoint bldg:StatusKitchenLightsC .
# bldg:AHU01 brick:feeds bldg:Dining_Room .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsDR .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsDRB .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsDR .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsDRB .
# bldg:AHU01 brick:hasPoint bldg:RoomTempDRTemp .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstDRA .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstDRA .
# bldg:AHU01 brick:hasPoint bldg:EnergyChildBDownstairs .
# bldg:AHU01 brick:hasPoint bldg:EnergyParentBDownstairs .
# bldg:AHU01 brick:hasPoint bldg:PowerChildBDownstairs .
# bldg:AHU01 brick:hasPoint bldg:PowerParentBDownstairs .
# bldg:AHU01 brick:hasPoint bldg:StatusSensHeatPrntBDOWN .
# bldg:AHU01 brick:hasPoint bldg:StatusSensHeatChildBDOWN .
# bldg:AHU01 brick:hasPoint bldg:StatusDRLights .
# bldg:AHU01 brick:feeds bldg:Utility .
# bldg:AHU01 brick:hasPoint bldg:ClothesWasherColdFlow .
# bldg:AHU01 brick:hasPoint bldg:ClothesWasherHotFlow .
# bldg:AHU01 brick:hasPoint bldg:WaterTempWasherCold .
# bldg:AHU01 brick:hasPoint bldg:WaterTempWasherHot .
# bldg:AHU01 brick:hasPoint bldg:EnergyClothesWasher .
# bldg:AHU01 brick:hasPoint bldg:EnergyDryer1of2 .
# bldg:AHU01 brick:hasPoint bldg:EnergyDryer2of2 .
# bldg:AHU01 brick:hasPoint bldg:PowerClothesWasher .
# bldg:AHU01 brick:hasPoint bldg:PowerDryer1of2 .
# bldg:AHU01 brick:hasPoint bldg:PowerDryer2of2 .
# bldg:AHU01 brick:hasPoint bldg:ClothesWasherEnergywithStandby .
# bldg:AHU01 brick:hasPoint bldg:ClothesWasherPowerWithStandby .
# bldg:AHU01 brick:hasPoint bldg:DryerEnergyTotal .
# bldg:AHU01 brick:hasPoint bldg:DryerPowerTotal .
# bldg:AHU01 brick:feeds bldg:Entry_Hallway .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsEntryHall .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsEntryHall .
# bldg:AHU01 brick:hasPoint bldg:RoomTempHallLowerMid .
# bldg:AHU01 brick:hasPoint bldg:RoomTempHallLowest .
# bldg:AHU01 brick:hasPoint bldg:RoomTempHallMiddle .
# bldg:AHU01 brick:hasPoint bldg:RoomTempHallUpper .
# bldg:AHU01 brick:hasPoint bldg:RoomTempHallUpperMid .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstHall .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstHall .
# bldg:AHU01 brick:hasPoint bldg:StatusEntryHallLights .
# bldg:AHU01 brick:feeds bldg:Master_Bedroom .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsMBR .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsMBR .
# bldg:AHU01 brick:feeds bldg:Bedroom_2 .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsBR2 .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsBR2 .
# bldg:AHU01 brick:hasPoint bldg:Bedroom2RH .
# bldg:AHU01 brick:hasPoint bldg:RadiantTempBR2 .
# bldg:AHU01 brick:hasPoint bldg:RoomTempBR2Temp .
# bldg:AHU01 brick:hasPoint bldg:EnergyChildAUpstairs .
# bldg:AHU01 brick:hasPoint bldg:PowerChildAUpstairs .
# bldg:AHU01 brick:hasPoint bldg:BR2PlugLoadsEnergyUsage .
# bldg:AHU01 brick:hasPoint bldg:BR2PlugLoadsPowerUsage .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadBR2Laptop .
# bldg:AHU01 brick:hasPoint bldg:StatusBR2Lights .
# bldg:AHU01 brick:hasPoint bldg:StatusSensHeatChildAUP .
# bldg:AHU01 brick:feeds bldg:Bedroom_3 .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsBR3 .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsBR3 .
# bldg:AHU01 brick:hasPoint bldg:Bedroom3RH .
# bldg:AHU01 brick:hasPoint bldg:RadiantTempBR3 .
# bldg:AHU01 brick:hasPoint bldg:RoomTempBR3Temp .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstBR3 .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstBR3 .
# bldg:AHU01 brick:hasPoint bldg:EnergyChildBUpstairs .
# bldg:AHU01 brick:hasPoint bldg:PowerChildBUpstairs .
# bldg:AHU01 brick:hasPoint bldg:BR3PlugLoadsEnergyUsage .
# bldg:AHU01 brick:hasPoint bldg:BR3PlugLoadsPowerUsage .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadBR3Laptop .
# bldg:AHU01 brick:hasPoint bldg:StatusBR3Lights .
# bldg:AHU01 brick:hasPoint bldg:StatusSensHeatChildBUP .
# bldg:AHU01 brick:feeds bldg:Bedroom_4 .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsBR4 .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsBR4 .
# bldg:AHU01 brick:hasPoint bldg:RoomTempBR4Temp .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstBR4A .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstBR4B .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstBR4A .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstBR4B .
# bldg:AHU01 brick:hasPoint bldg:BR4PlugLoadsEnergyUsage .
# bldg:AHU01 brick:hasPoint bldg:BR4PlugLoadsPowerUsage .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadDesktopPCMonitor .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadVacuum .
# bldg:AHU01 brick:hasPoint bldg:StatusBR4Lights .
# bldg:AHU01 brick:feeds bldg:Mudroom .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstMudroomA .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstMudroomB .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstMudroomA .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstMudroomB .
# bldg:AHU01 brick:feeds bldg:Multiple .
# bldg:AHU01 brick:hasPoint bldg:EnergyLights1stFloorA .
# bldg:AHU01 brick:hasPoint bldg:EnergyLights1stFloorB .
# bldg:AHU01 brick:hasPoint bldg:PowerLights1stFloorA .
# bldg:AHU01 brick:hasPoint bldg:PowerLights1stFloorB .
# bldg:AHU01 brick:hasPoint bldg:1stFloorLightsEnergyUsage .
# bldg:AHU01 brick:hasPoint bldg:1stFloorLightsPowerUsage .
# bldg:AHU01 brick:hasPoint bldg:1stFloorSensHeatEnergyUsage .
# bldg:AHU01 brick:hasPoint bldg:1stFloorSensHeatPowerUsage .
# bldg:AHU01 brick:hasPoint bldg:2ndFloorLightsEnergyUsage .
# bldg:AHU01 brick:hasPoint bldg:2ndFloorLightsPowerUsage .
# bldg:AHU01 brick:hasPoint bldg:2ndFloorSensHeatEnergyUsage .
# bldg:AHU01 brick:hasPoint bldg:2ndFloorSensHeatPowerUsage .
# bldg:AHU01 brick:feeds bldg:Outdoor .
# bldg:AHU01 brick:hasPoint bldg:HeatPumpOutdoorUnitPower .
# bldg:AHU01 brick:hasPoint bldg:OutdoorAmbTemp .
# bldg:AHU01 brick:hasPoint bldg:RooftopWindDirection .
# bldg:AHU01 brick:hasPoint bldg:RooftopWindSpeed .
# bldg:AHU01 brick:hasPoint bldg:PVBacksideTemp2 .
# bldg:AHU01 brick:hasPoint bldg:PVBacksideTemp3 .
# bldg:AHU01 brick:hasPoint bldg:PVBacksideTemp4 .
# bldg:AHU01 brick:hasPoint bldg:PVBacksideTemp7 .
# bldg:AHU01 brick:hasPoint bldg:PVInsolationHArray .
# bldg:AHU01 brick:hasPoint bldg:GlycolTempSHWPanel80galOut .
# bldg:AHU01 brick:hasPoint bldg:PSPSHW .
# bldg:AHU01 brick:feeds bldg:Master_Bathroom .
# bldg:AHU01 brick:hasPoint bldg:StatusSolenoidColdMBATub .
# bldg:AHU01 brick:hasPoint bldg:StatusSolenoidColdMBAShower .
# bldg:AHU01 brick:hasPoint bldg:StatusSolenoidHotMBATub .
# bldg:AHU01 brick:hasPoint bldg:StatusSolenoidHotMBAShower .
# bldg:AHU01 brick:hasPoint bldg:WaterTempMBAShwCold .
# bldg:AHU01 brick:hasPoint bldg:WaterTempMBAShwHot .
# bldg:AHU01 brick:hasPoint bldg:WaterTempMBAShwMix .
# bldg:AHU01 brick:hasPoint bldg:WaterTempMBASinkRMixed .
# bldg:AHU01 brick:hasPoint bldg:WaterTempMBASinkRCold .
# bldg:AHU01 brick:hasPoint bldg:WaterTempMBASinkRHot .
# bldg:AHU01 brick:hasPoint bldg:WaterTempMBATubCold .
# bldg:AHU01 brick:hasPoint bldg:WaterTempMBATubHot .
# bldg:AHU01 brick:hasPoint bldg:WaterTempMBATubMix .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsMBAEast .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsMBAWest .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsMBAEast .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsMBAWest .
# bldg:AHU01 brick:hasPoint bldg:MBARH .
# bldg:AHU01 brick:hasPoint bldg:RoomTempMBATemp .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstMBAB .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstMBAB .
# bldg:AHU01 brick:hasPoint bldg:StatusPlugLoadHairDryerCurlIron .
# bldg:AHU01 brick:hasPoint bldg:StatusMBALights .
# bldg:AHU01 brick:feeds bldg:Bathroom_1 .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsBA1 .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsBA1 .
# bldg:AHU01 brick:hasPoint bldg:RoomTempBA1Temp .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstBA1 .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstBA1 .
# bldg:AHU01 brick:hasPoint bldg:StatusBA1Lights .
# bldg:AHU01 brick:feeds bldg:Bathroom_2 .
# bldg:AHU01 brick:hasPoint bldg:WaterTempBAShowerMixed .
# bldg:AHU01 brick:hasPoint bldg:WaterTempBAShwCold .
# bldg:AHU01 brick:hasPoint bldg:WaterTempBAShwHot .
# bldg:AHU01 brick:hasPoint bldg:WaterTempBASinkCold .
# bldg:AHU01 brick:hasPoint bldg:WaterTempBASinkHot .
# bldg:AHU01 brick:hasPoint bldg:WaterTempBASinkMixed .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugs2ndFloor .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsBA2South .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsBA2North .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugs2ndFloor .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsBA2South .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsBA2North .
# bldg:AHU01 brick:hasPoint bldg:RoomTempBA2Temp .
# bldg:AHU01 brick:hasPoint bldg:EnergyPlugsInstBA2 .
# bldg:AHU01 brick:hasPoint bldg:PowerPlugsInstBA2 .
# bldg:AHU01 brick:hasPoint bldg:EnergyLights2ndFloor .
# bldg:AHU01 brick:hasPoint bldg:PowerLights2ndFloor .
# bldg:AHU01 brick:hasPoint bldg:StatusBA2Lights .
