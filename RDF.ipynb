# %%
import pandas as pd
import numpy
import re

# %%
df = pd.read_csv('NIST_meta.csv')

# %%
df.head()
# Out:
#                   Data Label Subsystem Measurement Location  \
# 0  DHW_ClothesWasherColdFlow       DHW              Utility
# 1   DHW_ClothesWasherHotFlow       DHW              Utility
# 2      DHW_DishwasherHotFlow       DHW              Kitchen
# 3        DHW_SHWGlycolTempIn       DHW             Basement
# 4       DHW_SHWGlycolTempOut       DHW             Basement
#
#   Measured Parameter                                        Description  \
# 0         Flow_Water  The cumulative volume of cold water flowing in...
# 1         Flow_Water  The cumulative volume of hot water flowing int...
# 2         Flow_Water  The cumulative volume of hot water flowing int...
# 3        Temp_Glycol  The instantaneous temperature of the glycol-wa...
# 4        Temp_Glycol  The instantaneous temperature of the glycol-wa...
#
#      Units
# 0  Gallons
# 1  Gallons
# 2  Gallons
# 3       °C
# 4       °C

# %%
def splitUppers(given_str):
    parsed = re.findall('[A-Z][^A-Z]*', given_str)
    return parsed

# %%
def get_location_terms(df, col_name):
    vals = df[col_name].dropna().unique()
    vals_ = []
    for val in vals:
        val = val.replace(" "," ")
        if val=="MBedroom":
            val = "Master Bedroom"
        if val=="MBath":
            val = "Master Bathroom"
        if val=="Bath1":
            val = "Bathroom 1"
        if val=="Bath2":
            val = "Bathroom 2"
        if val=="Bedroom3":
            val = "Bedroom 3"
        if val=="Bedroom4":
            val = "Bedroom 4"
        if val=="Bedroom2":
            val = "Bedroom 2"
        vals_.append(val.strip())
    return list(set(vals_))

def get_data_label_terms(df, col_name):
    vals = df[col_name].dropna().unique()
    vals_ = []
    for val in vals:
        val = val.split("_")[1]
        vals_.append(val.strip())
    return list(set(vals_))

def get_terms(df, col_name):
    vals = df[col_name].dropna().unique()
    vals_ = []
    for val in vals:
        val = val.replace(" "," ")
        vals_.append(val.strip())
    return list(set(vals_))

# %%
get_location_terms(df, 'Measurement Location')
# Out:
# ['Mudroom',
#  'Bedroom 3',
#  'Kitchen',
#  'Bathroom 2',
#  'Multiple',
#  'Utility',
#  'Living Room',
#  'Master Bathroom',
#  'Outdoor',
#  'Master Bedroom',
#  'Attic',
#  'Bedroom 4',
#  'Bedroom 2',
#  'Dining Room',
#  'Bathroom 1',
#  'Entry Hallway',
#  'Basement']

# %%
get_terms(df, 'Subsystem')
# Out:
# ['HVAC',
#  'Electrical',
#  'PV',
#  'SHW',
#  'Ventilation',
#  'Lighting',
#  'OutEnv',
#  'Instr',
#  'Elec',
#  'Loads',
#  'IndEnv',
#  'DHW']

# %%
list_of_data_label = get_data_label_terms(df, 'Data Label')
list_of_data_label
# Out:
# ['PowerParentADownstairs',
#  'StatusApplianceOven',
#  'EnergyLights1stFloorB',
#  'StatusLRLights3',
#  'PowerPlugsDRB',
#  'DehumidifierExitAirTemp',
#  'RoomTempAtticSE',
#  'SHWHX80galWaterFlow',
#  'EnergyPlugsInstKitA',
#  'DishwasherHotFlow',
#  'HRVexhaustflowrate',
#  'DryerEnergyTotal',
#  'PowerPlugs2ndFloor',
#  'PowerHeatLoadforRefrigerator',
#  'ManifoldColdFlow',
#  'FrequencyF2',
#  'WaterTempSHWTank80galIn',
#  'StatusPlugLoadBR3Laptop',
#  'RooftopWindSpeed',
#  'EnergySumpPump',
#  'WaterTempMixValveHotIn',
#  'ClothesWasherHotFlow',
#  'HRVDewpointTemperatureOutdoor',
#  'KitchenRH',
#  'RoomTempMBATemp',
#  'MastBedRmRH',
#  '2ndFloorSensHeatEnergyUsage',
#  'EnergyPlugsInstDRA',
#  'EnergyHeatLoadforRefrigerator',
#  'PowerPlugsInstBA2',
#  'EnergyPlugsInstMBRA',
#  'StatusPlugLoadCanOpener',
#  'PowerPlugsInstHall',
#  'RoomTempBA2Temp',
#  'StatusSensHeatPrntBUP',
#  'RoomTempHallLowerMid',
#  'PowerLights1stFloorB',
#  'EnergyDryer2of2',
#  'EnergyPlugsKitRange',
#  'StatusSensHeatPrntAUP',
#  'RoomTempAtticNW',
#  'EnergyParentBUpstairs',
#  'HVACTempReturnAir',
#  'PowerChildBUpstairs',
#  'PowerHeatPumpWH1of2',
#  'PVSystem1ACEnergyOSEACPV1OS',
#  'HeatPumpWaterHeaterPowerTotal',
#  'EnergyPlugsInstBR4A',
#  'StatusSolenoidHotMBATub',
#  'EnergyPlugs2ndFloor',
#  'PowerChildBDownstairs',
#  'EnergyGarbageDisposal',
#  'StatusMBRLights1',
#  'Watts3PhTotalW3PhT2',
#  'PowerSumpPump',
#  'AmpsAIA2',
#  'ClothesWasherPowerWithStandby',
#  'PowerDryer2of2',
#  'PowerPlugsBR3',
#  'VoltsANUAN2',
#  'StatusPlugLoadBlender',
#  'EnergyPlugsLR',
#  'WaterTempHPWHIn',
#  '2ndFloorLightsEnergyUsage',
#  'WaterTempMBAShwHot',
#  'Watts3PhTotalW3PhT1',
#  'LatentHeatWaterVolume',
#  'RadiantTempKitchen',
#  'MicrowaveEnergywithStandby',
#  'PowerPlugsBR4',
#  'EnergyPlugsInstMudroomB',
#  'HRVDewpointTemperatureExhaust',
#  'PowerDryer1of2',
#  'WaterTempSHWHX80galIn',
#  'BasementRH',
#  'StatusPlugLoadFan',
#  'AmpsBIB2',
#  'EnergyPlugsBaseAHeliodyneHXs',
#  'EnergyPlugsDR',
#  'EnergyPlugsAttic',
#  '2ndFloorLightsPowerUsage',
#  'RooftopWindDirection',
#  'EnergyPlugsDRB',
#  'PowerPlugsInstBR4A',
#  'PowerPlugsHVACInstrumentation',
#  'EnergyPlugsInstLRA',
#  '1stFloorSensHeatEnergyUsage',
#  'RoomTempWDTemp',
#  'StatusPlugLoadVacuum',
#  'EnergyPlugsInstMBAB',
#  'StatusPlugLoadHeatingPad',
#  'WaterTempManifoldHotIn',
#  'RefrigeratorTemp',
#  'WhoursDeliveredWhD1',
#  'HeatPumpIndoorUnitPower',
#  'EnergyPlugsBR2',
#  'WaterTempKSinkCold',
#  'PowerHRV',
#  'EnergyLightsAttic',
#  'EnergySpare2',
#  'EnergyMicrowave',
#  'RoomTempLRTemp',
#  'RoomTempBA1Temp',
#  'StatusPlugLoadSlowCooker',
#  'StatusBA2Lights',
#  'PowerRefrigerator',
#  'EnergyChildBUpstairs',
#  'PowerPlugsInstBR4B',
#  'StatusSensHeatPrntBDOWN',
#  'HRVstaleairpressuredifferential',
#  'BR3PlugLoadsEnergyUsage',
#  'WaterTempBAShowerMixed',
#  'EnergyPlugsInstBA2',
#  'RoomTempAtticSW',
#  'PowerLightingControlPanelRPS1',
#  'EnergyHeatPumpWH1of2',
#  'StatusSensHeatPrntADOWN',
#  'HRVreturnflowrate',
#  'WaterTempDishwasher',
#  'WaterTempMBATubMix',
#  'EnergySpare1',
#  'WaterTempSHWHX80galOut',
#  'RoomTempBasementNE',
#  'PowerPlugsBA2South',
#  'WaterTempMBATubHot',
#  'EnergyPlugsBaseB',
#  'StatusLatentload',
#  'PowerPlugsKitRange',
#  'PowerMicrowave',
#  'StatusBA1Lights',
#  'PowerLights2ndFloor',
#  'EnergyLightsBasement',
#  'StatusSolenoidColdKitchenSink',
#  'WaterTempHPWHOut',
#  'StatusBR4Lights',
#  'RoomTempMBRTemp',
#  'StatusBR2Lights',
#  'PowerLights1stFloorA',
#  'PowerDishwasher',
#  'WaterTempMBASinkRHot',
#  'PowerPlugsBR2',
#  'PVSystem2ACEnergyOSEACPV2OS',
#  'Bedroom2RH',
#  'PowerPlugsInstKitA',
#  'StatusPlugLoadToasterOven',
#  'StatusPlugLoadCoffeeMaker',
#  'PVSystem2ACPowerOSPACPV2OS',
#  'EnergyPlugsGSHPInstrumentation',
#  'RadiantTempBR2',
#  'StatusPlugLoadHairDryerCurlIron',
#  '2ndFloorSensHeatPowerUsage',
#  'BR3PlugLoadsPowerUsage',
#  'EnergyPlugsMBAWest',
#  'StringCurrentIStr3',
#  'HRVTempReturnIn',
#  'SHWPumpsPowerwithStandby',
#  'LRPlugLoadsEnergyUsage',
#  'LRPlugLoadsPowerUsage',
#  'WaterTempBASinkMixed',
#  'StatusPlugLoadToaster',
#  'EnergyHeatPumpWH2of2',
#  'PowerChildAUpstairs',
#  'BR2PlugLoadsPowerUsage',
#  'EnergyParentAUpstairs',
#  'PowerClothesWasher',
#  'MixValveColdFlow',
#  'AmpsBIB1',
#  'PowerGarbageDisposal',
#  'EnergyLights1stFloorA',
#  'RoomTempAtticNE',
#  'EnergyPlugsInstBR3',
#  'PowerLightsBasement',
#  'RefrigeratorEnergywithStandby',
#  'PowerPlugsBA1',
#  'MBRPlugLoadsPowerUsage',
#  'MBRPlugLoadsEnergyUsage',
#  'PowerFactor3PhTotalPF3PhT2',
#  'StatusSolenoidColdMBATub',
#  'KPlugLoadsPowerUsage',
#  'StatusSensHeatChildAUP',
#  'StatusApplianceCooktop',
#  'StatusSolenoidColdMBAShower',
#  'PVBacksideTemp2',
#  'PVInsolationHArray',
#  'EnergyMakeUpAirDamper',
#  'StatusPlugLoadLRTV',
#  'OvenEnergyTotal',
#  'GlycolFlowRateHXCoriolisSHW',
#  'DehumidifierInletAirTemp',
#  'PowerPlugsMBAWest',
#  'StatusEntryHallLights',
#  'HRVDewpointTemperatureSupply',
#  'EnergyPlugsInstLRB',
#  'ClothesWasherColdFlow',
#  'EnergyPlugsBaseC',
#  'PowerParentAUpstairs',
#  'HeatPumpOutdoorUnitPower',
#  'PowerPlugsBA2North',
#  'RadiantTempLR',
#  'EnergyClothesWasher',
#  'StatusSolenoidHotKitchenSink',
#  'PowerMakeUpAirDamper',
#  'RoomTempHallLowest',
#  'EnergyPV2of2',
#  'LatentHeatEnergyUsage',
#  'WaterTempBASinkCold',
#  'WaterTempManifoldColdIn',
#  'RoomTempBasementNW',
#  'PowerPlugsBaseC',
#  'StatusPlugLoadLRBlueRay',
#  'EnergyPlugsMBAEast',
#  'StatusPlugLoadHandMixer',
#  'SHWGlycolTempOut',
#  'RoomTempKitchenTemp',
#  'HVACDewpointReturnAir',
#  'StatusBR3Lights',
#  'VoltsBNUBN1',
#  'GlycolFlowHXCoriolisSHW',
#  'PowerPlugsKitPeninsula',
#  'SHWPumpsEnergywithStandby',
#  'EnergyPV1of2',
#  'HeatPumpWaterHeaterEnergyTotal',
#  'WaterTempWasherHot',
#  'PowerPlugsInstBR2Hall',
#  'EnergyPlugsInstHall',
#  'VoltsANUAN1',
#  'EnergyPlugsInstBA1',
#  'RoomTempBasementHPWH',
#  '1stFloorLightsEnergyUsage',
#  'PowerSpare1',
#  'PowerPlugsInstLRB',
#  'StatusPlugLoadDesktopPCMonitor',
#  'VoltsBNUBN2',
#  'StatusPlugLoadMBRTV',
#  'StatusMBRLights2',
#  'ManifoldHotFlow',
#  'StringVoltageUStr2',
#  'ClothesWasherEnergywithStandby',
#  'RoomTempBR3Temp',
#  'FrequencyF1',
#  'PowerHeatPumpWH2of2',
#  'WaterTempMBATubCold',
#  'EnergyPlugsInstBR4B',
#  'EnergyPlugsBA2South',
#  'PowerPV2of2',
#  'PowerPlugsGSHPInstrumentation',
#  'EnergyParentADownstairs',
#  'StatusApplianceRangeHood',
#  'OvenPowerTotal',
#  'PVSystem1ACPowerOSPACPV1OS',
#  'PVBacksideTemp7',
#  'HRVoutdoorflowrate',
#  'PowerPlugsInstDRA',
#  'StatusKitchenLightsC',
#  'WaterFlowRateHXCoriolisSHW',
#  'EnergyLights2ndFloor',
#  'StatusPlugLoadVideoGame',
#  'Bedroom3RH',
#  'GlycolTempSHWPanel80galOut',
#  'PowerPlugsInstMBRA',
#  'StatusLRLights2',
#  'PowerPlugsDR',
#  'PVBacksideTemp3',
#  'StringVoltageUStr4',
#  'WaterFlowHXCoriolisSHW',
#  'HRVfreshairpressuredifferential',
#  'LatentHeatPowerUsage',
#  'PowerSpare2',
#  'EnergyPlugsBR3',
#  'PowerPlugsAttic',
#  'BR4PlugLoadsEnergyUsage',
#  'StatusPlugLoadMBRBlueRay',
#  'HRVTempOutdoorin',
#  'DehumidifierAirflow',
#  'RadiantTempBR3',
#  'DryerPowerTotal',
#  'EnergyPlugsBR4',
#  'PowerPlugsBaseB',
#  'StatusSensHeatChildBUP',
#  'WaterTempKSinkHot',
#  'RefrigeratorPowerWithStandby',
#  'EnergyPlugsEntryHall',
#  'EnergyRefrigerator',
#  'WaterTempBAShwHot',
#  'WaterTempSHWTank80galOut',
#  'StatusMBALights',
#  'StatusDRLights',
#  'StatusKitchenLightsA',
#  'StatusKitchen LightsB',
#  'PowerPlugsInstBR3',
#  'StringCurrentIStr4',
#  'DehumidifierPower',
#  'PowerParentBUpstairs',
#  'PowerPlugsEntryHall',
#  'StatusPlugLoadBR2Laptop',
#  'PowerPlugsMBAEast',
#  'StatusApplianceDishwasher',
#  'WaterTempBASinkHot',
#  'EnergyDryer1of2',
#  'OutdoorAmbTemp',
#  'StringCurrentIStr2',
#  'StatusPlugLoadIron',
#  'EnergyChildAUpstairs',
#  'StatusSensHeatChildBDOWN',
#  'WaterTempMBASinkRMixed',
#  'PowerLightsBasementStair',
#  'RoomTempBR2Temp',
#  'PowerParentBDownstairs',
#  'RoomTempHallUpperMid',
#  'StatusLRLights1',
#  'PowerLightingControlPanelRPS2',
#  'PowerLightsAttic',
#  'RoomTempHallMiddle',
#  'PowerFactor3PhTotalPF3PhT1',
#  'PowerPlugsBaseAHeliodyneHXs',
#  'PVBacksideTemp4',
#  'EnergyPlugsBA2North',
#  'AmpsAIA1',
#  'PSPSHW',
#  'HRVTempExhaustOut',
#  'MBARH',
#  'WaterTempMBAShwMix',
#  'PowerPlugsInstBA1',
#  'EnergyParentBDownstairs',
#  'EnergyPlugsHVACInstrumentation',
#  'WaterTempMixValveColdIn',
#  'WaterTempMBAShwCold',
#  'HVACDewpointSupplyAir',
#  'WaterTempKSinkMix',
#  'EnergyLightingControlPanelRPS1',
#  'EnergyPlugsInstMudroomA',
#  'PowerChildADownstairs',
#  'BR2PlugLoadsEnergyUsage',
#  'PowerPlugsInstMudroomA',
#  'BasementPlugLoadsPowerUsage',
#  'BasementPlugLoadsEnergyUsage',
#  'EnergyChildBDownstairs',
#  '1stFloorLightsPowerUsage',
#  'WaterTempMBASinkRCold',
#  'WaterTempBAShwCold',
#  'EnergyPlugsInstBR2Hall',
#  'RoomTempBasementSW',
#  'SHWGlycolTempIn',
#  '1stFloorSensHeatPowerUsage',
#  'EnergyPlugsInstKitD',
#  'PowerPlugsMBR',
#  'EnergyPlugsKitSink',
#  'RoomTempDRTemp',
#  'EnergyHRV',
#  'PowerPlugsInstMBAB',
#  'PowerPlugsKitSink',
#  'KPlugLoadsEnergyUsage',
#  'HRVDewpointTemperatureReturn',
#  'MicrowavePowerWithStandby',
#  'BR4PlugLoadsPowerUsage',
#  'EnergyPlugsKitPeninsula',
#  'PowerPlugsInstKitD',
#  'PowerPlugsLR',
#  'WaterTempWasherCold',
#  'StringCurrentIStr1',
#  'RoomTempBR4Temp',
#  'EnergyLightsBasementStair',
#  'EnergyLightingControlPanelRPS2',
#  'EnergyChildADownstairs',
#  'HVACTempSupplyAir',
#  'EnergyDishwasher',
#  'RoomTempHallUpper',
#  'LivingRmRH',
#  'RadiantTempMBR',
#  'PowerPlugsInstMudroomB',
#  'StatusSolenoidHotMBAShower',
#  'PowerPlugsInstLRA',
#  'EnergyPlugsBA1',
#  'RoomTempBasementSE',
#  'PowerPV1of2',
#  'HRVTempSupplyOut',
#  'WhoursDeliveredWhD2',
#  'EnergyPlugsMBR',
#  'StatusSensHeatChildADOWN']

# %%
dict_cnt = {}
for terms in list_of_data_label:
    parsed = splitUppers(terms)
    for term in parsed:
        try:
            dict_cnt[term]+=1
        except:
            dict_cnt[term]=1
print(dict_cnt)
# Out:
# {'Power': 97, 'Parent': 8, 'A': 77, 'Downstairs': 8, 'Status': 55, 'Appliance': 4, 'Oven': 4, 'Energy': 89, 'Lights1st': 4, 'Floor': 16, 'B': 117, 'L': 15, 'R': 64, 'Lights3': 1, 'Plugs': 76, 'D': 15, 'Dehumidifier': 4, 'Exit': 1, 'Air': 8, 'Temp': 85, 'Room': 25, 'Attic': 8, 'S': 30, 'E': 6, 'H': 61, 'W': 31, 'X80gal': 3, 'Water': 37, 'Flow': 11, 'Inst': 32, 'Kit': 10, 'Dishwasher': 5, 'Hot': 15, 'Vexhaustflowrate': 1, 'Dryer': 3, 'Total': 10, 'Plugs2nd': 2, 'Heat': 25, 'Loadfor': 2, 'Refrigerator': 7, 'Manifold': 4, 'Cold': 15, 'Frequency': 2, 'F2': 1, 'Tank80gal': 2, 'In': 9, 'Plug': 34, 'Load': 20, 'R3': 10, 'Laptop': 2, 'Rooftop': 2, 'Wind': 2, 'Speed': 1, 'Sump': 2, 'Pump': 10, 'Mix': 6, 'Valve': 3, 'Clothes': 6, 'Washer': 8, 'V': 27, 'Dewpoint': 6, 'Temperature': 4, 'Outdoor': 3, 'Kitchen': 7, 'M': 34, 'Mast': 1, 'Bed': 1, 'Rm': 2, 'Sens': 12, 'Usage': 24, 'A2': 9, 'Can': 1, 'Opener': 1, 'Hall': 12, 'Prnt': 4, 'U': 10, 'P': 37, 'Lower': 1, 'Mid': 2, 'Dryer2of2': 2, 'Range': 3, 'N': 12, 'Upstairs': 8, 'C': 18, 'Return': 4, 'Child': 12, 'H1of2': 2, 'System1': 2, 'O': 12, 'V1': 2, 'Heater': 2, 'R4': 10, 'Solenoid': 6, 'Tub': 5, 'Garbage': 2, 'Disposal': 2, 'Lights1': 2, 'Watts3': 2, 'Ph': 8, 'W3': 2, 'T2': 2, 'Amps': 4, 'I': 8, 'With': 3, 'Standby': 8, 'Volts': 4, 'N2': 2, 'Blender': 1, 'Lights': 21, 'Shw': 5, 'T1': 2, 'Latent': 3, 'Volume': 1, 'Radiant': 5, 'Microwave': 4, 'Energywith': 4, 'Mudroom': 4, 'Exhaust': 2, 'Dryer1of2': 2, 'Basement': 12, 'Fan': 1, 'B2': 1, 'Base': 6, 'Heliodyne': 2, 'Xs': 2, 'Direction': 1, 'Instrumentation': 4, 'Vacuum': 1, 'Heating': 1, 'Pad': 1, 'Whours': 2, 'Delivered': 2, 'Wh': 2, 'D1': 1, 'Indoor': 1, 'Unit': 2, 'R2': 10, 'K': 5, 'Sink': 13, 'Spare2': 2, 'A1': 7, 'Slow': 1, 'Cooker': 1, 'Vstaleairpressuredifferential': 1, 'Loads': 14, 'Shower': 3, 'Mixed': 3, 'Lighting': 4, 'Control': 4, 'Panel': 4, 'S1': 2, 'Vreturnflowrate': 1, 'Spare1': 2, 'Out': 7, 'South': 2, 'Latentload': 1, 'Lights2nd': 2, 'System2': 2, 'V2': 2, 'Bedroom2': 1, 'Toaster': 2, 'Coffee': 1, 'Maker': 1, 'G': 2, 'Hair': 1, 'Curl': 1, 'Iron': 2, 'West': 2, 'String': 6, 'Current': 4, 'Str3': 1, 'Pumps': 2, 'Powerwith': 1, 'H2of2': 2, 'B1': 1, 'Factor3': 2, 'F3': 2, 'Cooktop': 1, 'Backside': 4, 'Temp2': 1, 'Insolation': 1, 'Array': 1, 'Make': 2, 'Up': 2, 'Damper': 2, 'T': 2, 'Glycol': 5, 'Rate': 2, 'X': 4, 'Coriolis': 4, 'Inlet': 1, 'Entry': 3, 'Supply': 4, 'North': 2, 'Lowest': 1, 'V2of2': 2, 'Blue': 2, 'Ray': 2, 'East': 2, 'Hand': 1, 'Mixer': 1, 'N1': 2, 'Peninsula': 2, 'V1of2': 2, 'Desktop': 1, 'Monitor': 1, 'Lights2': 2, 'Voltage': 2, 'Str2': 2, 'F1': 1, 'Hood': 1, 'Temp7': 1, 'Voutdoorflowrate': 1, 'Video': 1, 'Game': 1, 'Bedroom3': 1, 'Panel80gal': 1, 'Temp3': 1, 'Str4': 2, 'Vfreshairpressuredifferential': 1, 'Outdoorin': 1, 'Airflow': 1, 'Kitchen ': 1, 'Amb': 1, 'Stair': 2, 'Upper': 2, 'S2': 2, 'Middle': 1, 'Temp4': 1, 'Str1': 1, 'Living': 1, 'D2': 1}

# %%
get_terms(df, 'Measured Parameter')
# Out:
# ['Temp_Rad',
#  'Flow_Water',
#  'Pressure_Air',
#  'Energy_Electrical',
#  'Temp_DewP',
#  'PowerFactor_Electrical',
#  'Temp_PV',
#  'RH',
#  'Flow_Glycol',
#  'Status_OnOff',
#  'Current_Electrical',
#  'Power_Electrical',
#  'Frequency_Electrical',
#  'Voltage_Electrical',
#  'Flow_Air',
#  'Temp_Glycol',
#  'Temp_Water',
#  'Light_Solar',
#  'Power_Thermal',
#  'Temp_Air',
#  'Energy_Thermal']

# %%
def get_distinct_rel(col_a,col_b):
    vals = []
    for index, row in df.iterrows():
        a = str(row[col_a]).strip()
        b = str(row[col_b]).strip()
        if a!="nan" and b!="nan":
            vals.append(a+","+b)

    vals = list(set(vals))
    vals.sort()

    for rel in vals:
        parsed_rel = rel.split(",")
        a = parsed_rel[0]
        if a == "Bedroom 2":
            a = "Bedroom2"
        if a == "MBedroom":
            a = "Master Bedroom"
        b = parsed_rel[1]
        print(a,b)

# %%
get_distinct_rel('Measurement Location','Subsystem')
# Out:
# Attic Electrical
# Attic IndEnv
# Attic Lighting
# Attic PV
# Attic Ventilation
# Basement DHW
# Basement Elec
# Basement Electrical
# Basement HVAC
# Basement IndEnv
# Basement Instr
# Basement Lighting
# Basement Loads
# Basement PV
# Basement SHW
# Basement Ventilation
# Bath1 Electrical
# Bath1 IndEnv
# Bath1 Instr
# Bath1 Loads
# Bath2 DHW
# Bath2 Electrical
# Bath2 IndEnv
# Bath2 Instr
# Bath2 Lighting
# Bath2 Loads
# Bedroom2 Instr
# Bedroom2 Electrical
# Bedroom2 IndEnv
# Bedroom2 Loads
# Bedroom3 Electrical
# Bedroom3 IndEnv
# Bedroom3 Instr
# Bedroom3 Loads
# Bedroom4 Electrical
# Bedroom4 IndEnv
# Bedroom4 Instr
# Bedroom4 Loads
# Dining Room Electrical
# Dining Room IndEnv
# Dining Room Instr
# Dining Room Loads
# Entry Hallway Electrical
# Entry Hallway IndEnv
# Entry Hallway Instr
# Entry Hallway Loads
# Kitchen DHW
# Kitchen Electrical
# Kitchen IndEnv
# Kitchen Instr
# Kitchen Loads
# Living Room Electrical
# Living Room IndEnv
# Living Room Instr
# Living Room Loads
# MBath DHW
# MBath Electrical
# MBath IndEnv
# MBath Instr
# MBath Loads
# Master Bedroom Electrical
# Master Bedroom IndEnv
# Master Bedroom Instr
# Master Bedroom Loads
# Mudroom Instr
# Multiple Lighting
# Multiple Loads
# Outdoor HVAC
# Outdoor OutEnv
# Outdoor PV
# Outdoor SHW
# Utility DHW
# Utility Electrical
# Utility Loads

# %%
get_distinct_rel('Measurement Location', 'Data Label')
# Out:
# Attic Elec_EnergyLightsAttic
# Attic Elec_EnergyMakeUpAirDamper
# Attic Elec_EnergyPlugsAttic
# Attic Elec_PowerLightsAttic
# Attic Elec_PowerMakeUpAirDamper
# Attic Elec_PowerPlugsAttic
# Attic IndEnv_RoomTempAtticNE
# Attic IndEnv_RoomTempAtticNW
# Attic IndEnv_RoomTempAtticSE
# Attic IndEnv_RoomTempAtticSW
# Attic PV_AmpsAIA1
# Attic PV_AmpsAIA2
# Attic PV_AmpsBIB1
# Attic PV_AmpsBIB2
# Attic PV_FrequencyF1
# Attic PV_FrequencyF2
# Attic PV_PVSystem1ACEnergyOSEACPV1OS
# Attic PV_PVSystem1ACPowerOSPACPV1OS
# Attic PV_PVSystem2ACEnergyOSEACPV2OS
# Attic PV_PVSystem2ACPowerOSPACPV2OS
# Attic PV_PowerFactor3PhTotalPF3PhT1
# Attic PV_PowerFactor3PhTotalPF3PhT2
# Attic PV_StringCurrentIStr1
# Attic PV_StringCurrentIStr2
# Attic PV_StringCurrentIStr3
# Attic PV_StringCurrentIStr4
# Attic PV_StringVoltageUStr2
# Attic PV_StringVoltageUStr4
# Attic PV_VoltsANUAN1
# Attic PV_VoltsANUAN2
# Attic PV_VoltsBNUBN1
# Attic PV_VoltsBNUBN2
# Attic PV_Watts3PhTotalW3PhT1
# Attic PV_Watts3PhTotalW3PhT2
# Attic PV_WhoursDeliveredWhD1
# Attic PV_WhoursDeliveredWhD2
# Basement DHW_HeatPumpWaterHeaterEnergyTotal
# Basement DHW_HeatPumpWaterHeaterPowerTotal
# Basement DHW_ManifoldColdFlow
# Basement DHW_ManifoldHotFlow
# Basement DHW_MixValveColdFlow
# Basement DHW_RoomTempBasementHPWH
# Basement DHW_SHWGlycolTempIn
# Basement DHW_SHWGlycolTempOut
# Basement DHW_SHWPumpsEnergywithStandby
# Basement DHW_SHWPumpsPowerwithStandby
# Basement DHW_WaterTempHPWHIn
# Basement DHW_WaterTempHPWHOut
# Basement DHW_WaterTempManifoldColdIn
# Basement DHW_WaterTempManifoldHotIn
# Basement DHW_WaterTempMixValveColdIn
# Basement DHW_WaterTempMixValveHotIn
# Basement DHW_WaterTempSHWHX80galIn
# Basement DHW_WaterTempSHWHX80galOut
# Basement DHW_WaterTempSHWTank80galIn
# Basement DHW_WaterTempSHWTank80galOut
# Basement Elec_EnergyHRV
# Basement Elec_EnergyHeatPumpWH1of2
# Basement Elec_EnergyHeatPumpWH2of2
# Basement Elec_EnergyLightingControlPanelRPS1
# Basement Elec_EnergyLightingControlPanelRPS2
# Basement Elec_EnergyLightsBasement
# Basement Elec_EnergyLightsBasementStair
# Basement Elec_EnergyPV1of2
# Basement Elec_EnergyPV2of2
# Basement Elec_EnergyPlugsBaseAHeliodyneHXs
# Basement Elec_EnergyPlugsBaseB
# Basement Elec_EnergyPlugsBaseC
# Basement Elec_EnergyPlugsGSHPInstrumentation
# Basement Elec_EnergyPlugsHVACInstrumentation
# Basement Elec_EnergySpare1
# Basement Elec_EnergySpare2
# Basement Elec_EnergySumpPump
# Basement Elec_PowerHRV
# Basement Elec_PowerHeatPumpWH1of2
# Basement Elec_PowerHeatPumpWH2of2
# Basement Elec_PowerLightingControlPanelRPS1
# Basement Elec_PowerLightingControlPanelRPS2
# Basement Elec_PowerLightsBasement
# Basement Elec_PowerLightsBasementStair
# Basement Elec_PowerPV1of2
# Basement Elec_PowerPV2of2
# Basement Elec_PowerPlugsBaseAHeliodyneHXs
# Basement Elec_PowerPlugsBaseB
# Basement Elec_PowerPlugsBaseC
# Basement Elec_PowerPlugsGSHPInstrumentation
# Basement Elec_PowerPlugsHVACInstrumentation
# Basement Elec_PowerSpare1
# Basement Elec_PowerSpare2
# Basement Elec_PowerSumpPump
# Basement HVAC_DehumidifierAirflow
# Basement HVAC_DehumidifierExitAirTemp
# Basement HVAC_DehumidifierInletAirTemp
# Basement HVAC_DehumidifierPower
# Basement HVAC_HVACDewpointReturnAir
# Basement HVAC_HVACDewpointSupplyAir
# Basement HVAC_HVACTempReturnAir
# Basement HVAC_HVACTempSupplyAir
# Basement HVAC_HeatPumpIndoorUnitPower
# Basement IndEnv_BasementRH
# Basement IndEnv_RoomTempBasementNE
# Basement IndEnv_RoomTempBasementNW
# Basement IndEnv_RoomTempBasementSE
# Basement IndEnv_RoomTempBasementSW
# Basement Load_BasementPlugLoadsEnergyUsage
# Basement Load_BasementPlugLoadsPowerUsage
# Basement SHW_GlycolFlowHXCoriolisSHW
# Basement SHW_GlycolFlowRateHXCoriolisSHW
# Basement SHW_SHWHX80galWaterFlow
# Basement SHW_WaterFlowHXCoriolisSHW
# Basement SHW_WaterFlowRateHXCoriolisSHW
# Basement Vent_HRVDewpointTemperatureExhaust
# Basement Vent_HRVDewpointTemperatureOutdoor
# Basement Vent_HRVDewpointTemperatureReturn
# Basement Vent_HRVDewpointTemperatureSupply
# Basement Vent_HRVTempExhaustOut
# Basement Vent_HRVTempOutdoorin
# Basement Vent_HRVTempReturnIn
# Basement Vent_HRVTempSupplyOut
# Basement Vent_HRVexhaustflowrate
# Basement Vent_HRVfreshairpressuredifferential
# Basement Vent_HRVoutdoorflowrate
# Basement Vent_HRVreturnflowrate
# Basement Vent_HRVstaleairpressuredifferential
# Bath1 Elec_EnergyPlugsBA1
# Bath1 Elec_EnergyPlugsInstBA1
# Bath1 Elec_PowerPlugsBA1
# Bath1 Elec_PowerPlugsInstBA1
# Bath1 IndEnv_RoomTempBA1Temp
# Bath1 Load_StatusBA1Lights
# Bath2 DHW_WaterTempBAShowerMixed
# Bath2 DHW_WaterTempBAShwCold
# Bath2 DHW_WaterTempBAShwHot
# Bath2 DHW_WaterTempBASinkCold
# Bath2 DHW_WaterTempBASinkHot
# Bath2 DHW_WaterTempBASinkMixed
# Bath2 Elec_EnergyLights2ndFloor
# Bath2 Elec_EnergyPlugs2ndFloor
# Bath2 Elec_EnergyPlugsBA2North
# Bath2 Elec_EnergyPlugsBA2South
# Bath2 Elec_EnergyPlugsInstBA2
# Bath2 Elec_PowerLights2ndFloor
# Bath2 Elec_PowerPlugs2ndFloor
# Bath2 Elec_PowerPlugsBA2North
# Bath2 Elec_PowerPlugsBA2South
# Bath2 Elec_PowerPlugsInstBA2
# Bath2 IndEnv_RoomTempBA2Temp
# Bath2 Load_StatusBA2Lights
# Bedroom2 Elec_EnergyPlugsInstBR2Hall
# Bedroom2 Elec_PowerPlugsInstBR2Hall
# Bedroom2 Elec_EnergyChildAUpstairs
# Bedroom2 Elec_EnergyPlugsBR2
# Bedroom2 Elec_PowerChildAUpstairs
# Bedroom2 Elec_PowerPlugsBR2
# Bedroom2 IndEnv_Bedroom2RH
# Bedroom2 IndEnv_RadiantTempBR2
# Bedroom2 IndEnv_RoomTempBR2Temp
# Bedroom2 Load_BR2PlugLoadsEnergyUsage
# Bedroom2 Load_BR2PlugLoadsPowerUsage
# Bedroom2 Load_StatusBR2Lights
# Bedroom2 Load_StatusPlugLoadBR2Laptop
# Bedroom2 Load_StatusSensHeatChildAUP
# Bedroom3 Elec_EnergyChildBUpstairs
# Bedroom3 Elec_EnergyPlugsBR3
# Bedroom3 Elec_EnergyPlugsInstBR3
# Bedroom3 Elec_PowerChildBUpstairs
# Bedroom3 Elec_PowerPlugsBR3
# Bedroom3 Elec_PowerPlugsInstBR3
# Bedroom3 IndEnv_Bedroom3RH
# Bedroom3 IndEnv_RadiantTempBR3
# Bedroom3 IndEnv_RoomTempBR3Temp
# Bedroom3 Load_BR3PlugLoadsEnergyUsage
# Bedroom3 Load_BR3PlugLoadsPowerUsage
# Bedroom3 Load_StatusBR3Lights
# Bedroom3 Load_StatusPlugLoadBR3Laptop
# Bedroom3 Load_StatusSensHeatChildBUP
# Bedroom4 Elec_EnergyPlugsBR4
# Bedroom4 Elec_EnergyPlugsInstBR4A
# Bedroom4 Elec_EnergyPlugsInstBR4B
# Bedroom4 Elec_PowerPlugsBR4
# Bedroom4 Elec_PowerPlugsInstBR4A
# Bedroom4 Elec_PowerPlugsInstBR4B
# Bedroom4 IndEnv_RoomTempBR4Temp
# Bedroom4 Load_BR4PlugLoadsEnergyUsage
# Bedroom4 Load_BR4PlugLoadsPowerUsage
# Bedroom4 Load_StatusBR4Lights
# Bedroom4 Load_StatusPlugLoadDesktopPCMonitor
# Bedroom4 Load_StatusPlugLoadVacuum
# Dining Room Elec_EnergyChildBDownstairs
# Dining Room Elec_EnergyParentBDownstairs
# Dining Room Elec_EnergyPlugsDR
# Dining Room Elec_EnergyPlugsDRB
# Dining Room Elec_EnergyPlugsInstDRA
# Dining Room Elec_PowerChildBDownstairs
# Dining Room Elec_PowerParentBDownstairs
# Dining Room Elec_PowerPlugsDR
# Dining Room Elec_PowerPlugsDRB
# Dining Room Elec_PowerPlugsInstDRA
# Dining Room IndEnv_RoomTempDRTemp
# Dining Room Load_StatusDRLights
# Dining Room Load_StatusSensHeatChildBDOWN
# Dining Room Load_StatusSensHeatPrntBDOWN
# Entry Hallway Elec_EnergyPlugsEntryHall
# Entry Hallway Elec_EnergyPlugsInstHall
# Entry Hallway Elec_PowerPlugsEntryHall
# Entry Hallway Elec_PowerPlugsInstHall
# Entry Hallway IndEnv_RoomTempHallLowerMid
# Entry Hallway IndEnv_RoomTempHallLowest
# Entry Hallway IndEnv_RoomTempHallMiddle
# Entry Hallway IndEnv_RoomTempHallUpper
# Entry Hallway IndEnv_RoomTempHallUpperMid
# Entry Hallway Load_StatusEntryHallLights
# Kitchen DHW_DishwasherHotFlow
# Kitchen DHW_StatusSolenoidColdKitchenSink
# Kitchen DHW_StatusSolenoidHotKitchenSink
# Kitchen DHW_WaterTempDishwasher
# Kitchen DHW_WaterTempKSinkCold
# Kitchen DHW_WaterTempKSinkHot
# Kitchen DHW_WaterTempKSinkMix
# Kitchen Elec_EnergyDishwasher
# Kitchen Elec_EnergyGarbageDisposal
# Kitchen Elec_EnergyHeatLoadforRefrigerator
# Kitchen Elec_EnergyMicrowave
# Kitchen Elec_EnergyParentADownstairs
# Kitchen Elec_EnergyPlugsInstKitA
# Kitchen Elec_EnergyPlugsInstKitD
# Kitchen Elec_EnergyPlugsKitPeninsula
# Kitchen Elec_EnergyPlugsKitRange
# Kitchen Elec_EnergyPlugsKitSink
# Kitchen Elec_EnergyRefrigerator
# Kitchen Elec_PowerDishwasher
# Kitchen Elec_PowerGarbageDisposal
# Kitchen Elec_PowerHeatLoadforRefrigerator
# Kitchen Elec_PowerMicrowave
# Kitchen Elec_PowerParentADownstairs
# Kitchen Elec_PowerPlugsInstKitA
# Kitchen Elec_PowerPlugsInstKitD
# Kitchen Elec_PowerPlugsKitPeninsula
# Kitchen Elec_PowerPlugsKitRange
# Kitchen Elec_PowerPlugsKitSink
# Kitchen Elec_PowerRefrigerator
# Kitchen IndEnv_KitchenRH
# Kitchen IndEnv_RadiantTempKitchen
# Kitchen IndEnv_RoomTempKitchenTemp
# Kitchen IndEnv_RoomTempWDTemp
# Kitchen Load_KPlugLoadsEnergyUsage
# Kitchen Load_KPlugLoadsPowerUsage
# Kitchen Load_LatentHeatEnergyUsage
# Kitchen Load_LatentHeatPowerUsage
# Kitchen Load_LatentHeatWaterVolume
# Kitchen Load_MicrowaveEnergywithStandby
# Kitchen Load_MicrowavePowerWithStandby
# Kitchen Load_OvenEnergyTotal
# Kitchen Load_OvenPowerTotal
# Kitchen Load_RefrigeratorEnergywithStandby
# Kitchen Load_RefrigeratorPowerWithStandby
# Kitchen Load_RefrigeratorTemp
# Kitchen Load_StatusApplianceCooktop
# Kitchen Load_StatusApplianceDishwasher
# Kitchen Load_StatusApplianceOven
# Kitchen Load_StatusApplianceRangeHood
# Kitchen Load_StatusKitchen LightsB
# Kitchen Load_StatusKitchenLightsA
# Kitchen Load_StatusKitchenLightsC
# Kitchen Load_StatusLatentload
# Kitchen Load_StatusPlugLoadBlender
# Kitchen Load_StatusPlugLoadCanOpener
# Kitchen Load_StatusPlugLoadCoffeeMaker
# Kitchen Load_StatusPlugLoadHandMixer
# Kitchen Load_StatusPlugLoadSlowCooker
# Kitchen Load_StatusPlugLoadToaster
# Kitchen Load_StatusPlugLoadToasterOven
# Kitchen Load_StatusSensHeatPrntADOWN
# Living Room Elec_EnergyChildADownstairs
# Living Room Elec_EnergyPlugsInstLRA
# Living Room Elec_EnergyPlugsInstLRB
# Living Room Elec_EnergyPlugsLR
# Living Room Elec_PowerChildADownstairs
# Living Room Elec_PowerPlugsInstLRA
# Living Room Elec_PowerPlugsInstLRB
# Living Room Elec_PowerPlugsLR
# Living Room IndEnv_LivingRmRH
# Living Room IndEnv_RadiantTempLR
# Living Room IndEnv_RoomTempLRTemp
# Living Room Load_LRPlugLoadsEnergyUsage
# Living Room Load_LRPlugLoadsPowerUsage
# Living Room Load_StatusLRLights1
# Living Room Load_StatusLRLights2
# Living Room Load_StatusLRLights3
# Living Room Load_StatusPlugLoadLRBlueRay
# Living Room Load_StatusPlugLoadLRTV
# Living Room Load_StatusPlugLoadVideoGame
# Living Room Load_StatusSensHeatChildADOWN
# MBath DHW_StatusSolenoidColdMBAShower
# MBath DHW_StatusSolenoidColdMBATub
# MBath DHW_StatusSolenoidHotMBAShower
# MBath DHW_StatusSolenoidHotMBATub
# MBath DHW_WaterTempMBAShwCold
# MBath DHW_WaterTempMBAShwHot
# MBath DHW_WaterTempMBAShwMix
# MBath DHW_WaterTempMBASinkRCold
# MBath DHW_WaterTempMBASinkRHot
# MBath DHW_WaterTempMBASinkRMixed
# MBath DHW_WaterTempMBATubCold
# MBath DHW_WaterTempMBATubHot
# MBath DHW_WaterTempMBATubMix
# MBath Elec_EnergyPlugsInstMBAB
# MBath Elec_EnergyPlugsMBAEast
# MBath Elec_EnergyPlugsMBAWest
# MBath Elec_PowerPlugsInstMBAB
# MBath Elec_PowerPlugsMBAEast
# MBath Elec_PowerPlugsMBAWest
# MBath IndEnv_MBARH
# MBath IndEnv_RoomTempMBATemp
# MBath Load_StatusMBALights
# MBath Load_StatusPlugLoadHairDryerCurlIron
# Master Bedroom Elec_EnergyPlugsMBR
# Master Bedroom Elec_PowerPlugsMBR
# Master Bedroom Elec_EnergyParentAUpstairs
# Master Bedroom Elec_EnergyParentBUpstairs
# Master Bedroom Elec_EnergyPlugsInstMBRA
# Master Bedroom Elec_PowerParentAUpstairs
# Master Bedroom Elec_PowerParentBUpstairs
# Master Bedroom Elec_PowerPlugsInstMBRA
# Master Bedroom IndEnv_MastBedRmRH
# Master Bedroom IndEnv_RadiantTempMBR
# Master Bedroom IndEnv_RoomTempMBRTemp
# Master Bedroom Load_MBRPlugLoadsEnergyUsage
# Master Bedroom Load_MBRPlugLoadsPowerUsage
# Master Bedroom Load_StatusMBRLights1
# Master Bedroom Load_StatusMBRLights2
# Master Bedroom Load_StatusPlugLoadFan
# Master Bedroom Load_StatusPlugLoadHeatingPad
# Master Bedroom Load_StatusPlugLoadIron
# Master Bedroom Load_StatusPlugLoadMBRBlueRay
# Master Bedroom Load_StatusPlugLoadMBRTV
# Master Bedroom Load_StatusSensHeatPrntAUP
# Master Bedroom Load_StatusSensHeatPrntBUP
# Mudroom Elec_EnergyPlugsInstMudroomA
# Mudroom Elec_EnergyPlugsInstMudroomB
# Mudroom Elec_PowerPlugsInstMudroomA
# Mudroom Elec_PowerPlugsInstMudroomB
# Multiple Elec_EnergyLights1stFloorA
# Multiple Elec_EnergyLights1stFloorB
# Multiple Elec_PowerLights1stFloorA
# Multiple Elec_PowerLights1stFloorB
# Multiple Load_1stFloorLightsEnergyUsage
# Multiple Load_1stFloorLightsPowerUsage
# Multiple Load_1stFloorSensHeatEnergyUsage
# Multiple Load_1stFloorSensHeatPowerUsage
# Multiple Load_2ndFloorLightsEnergyUsage
# Multiple Load_2ndFloorLightsPowerUsage
# Multiple Load_2ndFloorSensHeatEnergyUsage
# Multiple Load_2ndFloorSensHeatPowerUsage
# Outdoor HVAC_HeatPumpOutdoorUnitPower
# Outdoor OutEnv_OutdoorAmbTemp
# Outdoor OutEnv_RooftopWindDirection
# Outdoor OutEnv_RooftopWindSpeed
# Outdoor PV_PVBacksideTemp2
# Outdoor PV_PVBacksideTemp3
# Outdoor PV_PVBacksideTemp4
# Outdoor PV_PVBacksideTemp7
# Outdoor PV_PVInsolationHArray
# Outdoor SHW_GlycolTempSHWPanel80galOut
# Outdoor SHW_PSPSHW
# Utility DHW_ClothesWasherColdFlow
# Utility DHW_ClothesWasherHotFlow
# Utility DHW_WaterTempWasherCold
# Utility DHW_WaterTempWasherHot
# Utility Elec_EnergyClothesWasher
# Utility Elec_EnergyDryer1of2
# Utility Elec_EnergyDryer2of2
# Utility Elec_PowerClothesWasher
# Utility Elec_PowerDryer1of2
# Utility Elec_PowerDryer2of2
# Utility Load_ClothesWasherEnergywithStandby
# Utility Load_ClothesWasherPowerWithStandby
# Utility Load_DryerEnergyTotal
# Utility Load_DryerPowerTotal
